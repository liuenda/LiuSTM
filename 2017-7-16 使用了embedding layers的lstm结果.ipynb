# %%
run keras_title_emb.py
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 20.0% of memory, cuDNN 4007)
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# maxlen 30 epoch 10 dim_lstm 200
# dim_Dense 800
# dropout_rate 0.0 , LSTM type: bi-lstm mul
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading english Data: 59999
# Reading english Data: 59999
# ...

# %%
df_pairs_sample
# Out:
#                                              en_article  \
# 0     update north korean leader say purge be cleans...
# 1     update china factory growth slow resilient yea...
# 2     table breakdown china dec official manufacturi...
# 3     china final hsbc factory pmi dip month low dec...
# 4     update hyundai kia see weak annual car sale gr...
# 5     update hyundai kia face fade growth currency t...
# 6     singapore gdp contract hurt sluggish manufactu...
# 7     market eye indian share gain rate sensitive ba...
# 8     update fiat reach deal uaw trust buy rest chry...
# 9             update fiat strike deal buy rest chrysler
# 10                  pboc skip repos drain bln yuan week
# 11      china clear batch ipo end listing freeze report
# 12         s.korea share dip pct start large cap tumble
# 13    taiwan stock hit month intraday high auto bank...
# 14     update latvia cap year austerity euro membership
# 15                china share slide dec pmi underwhelms
# ...

# %%
run keras_title_emb.py
# Out:
# maxlen 30 epoch 10 dim_lstm 200
# dim_Dense 800
# dropout_rate 0.0 , LSTM type: bi-lstm mul
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading english Data: 59999
# Reading english Data: 59999
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    59987
# True        12
# Name: en_article, dtype: int64
# keras_title_emb.py:422: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # ---- Create dictionary ---- #
# keras_title_emb.py:423: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
