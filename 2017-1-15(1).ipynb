# %%
# maxlen =100
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 3: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Now the maxlen = 100
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.253719985485
# Training_correct error 0.318427056074
# Testing_correct error: 0.32622563839
# top- 1 = [1] : 1
# top- 5 = [15] : 15
# top- 10 = [29] : 29
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     443.876376
# std      270.163425
# min        1.000000
# 25%      227.500000
# 50%      431.000000
# 75%      646.500000
# max      975.000000
# dtype: float64
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('MSE distribution')
plt.plot(sls.mse,'ro-', label="Training data (similarity = 1 + similarity = 2)")
plt.plot(sls.mse_train,'bo-', label="Training data (similarity = 1)")
plt.plot(sls.mse_test,'go-', label="Testing data (similarity = 1)")
plt.legend()

plt.ylabel('MSE')
plt.xlabel('Epoches Times')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.tops[1],'ro-', label = "TOP-1 @ Trianing data (similarity = 1)")
plt.plot(sls.tops[5],'bo-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot(sls.tops[10],'go-', label = "TOP-10 @ Trianing data (similarity = 1)")
plt.plot(sls.tops_test[1],'ro--', label = "TOP-1 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[5],'bo--', label = "TOP-5 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[10],'go--', label = "TOP-10 @ Test data (similarity = 1)")
plt.ylabel('Amount of documents belongs to top[1,5,10]')
plt.xlabel('Epoches')
plt.title('Tendancy of accuracy during training')
plt.legend(loc = 2)
plt.show()

# %%
mse_maxlen = {}
mse_maxlen_train = {}
mse_maxlen_test = {}
def save_mse_maxlen(maxlen):
    mse_maxlen[maxlen] = list(sls.mse)
    mse_maxlen_train[maxlen] = list(sls.mse_train)
    mse_maxlen_test[maxlen] = list(sls.mse_test)

# %%
save_mse_maxlen(100)

# %%
#  maxlen = 200
run main.py
# Out:
# Now the maxlen = 200
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.253890484571
# Training_correct error 0.251886665821
# Testing_correct error: 0.253201782703
# top- 1 = [2] : 2
# top- 5 = [17] : 17
# top- 10 = [26] : 26
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     463.505506
# std      287.261226
# min        1.000000
# 25%      207.000000
# 50%      460.000000
# 75%      714.000000
# max      978.000000
# dtype: float64
# top- 1 = [3] : 3
# top- 5 = [15] : 15
# top- 10 = [27] : 27
# Discription of evaluation (ranking) for testing data:
# count    1000.0000
# mean      479.9660
# std       287.2279
# min         1.0000
# 25%       235.1250
# 50%       477.5000
# 75%       734.5000
# max       979.5000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.256850302219
# ...

# %%
run main.py

# %%
save_mse_maxlen(200)

# %%
run main.py
# Out:
# Now the maxlen = 500
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.267804771662
# Training_correct error 0.339647322893
# Testing_correct error: 0.324162662029
# top- 1 = [3] : 3
# top- 5 = [14] : 14
# top- 10 = [20] : 20
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     515.213213
# std      285.045542
# min        1.000000
# 25%      276.000000
# 50%      531.000000
# 75%      760.500000
# max      989.000000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [11] : 11
# top- 10 = [17] : 17
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      521.391500
# std       286.257028
# min         1.000000
# 25%       289.500000
# 50%       528.250000
# 75%       777.000000
# max       994.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.213970780373
# ...

# %%
save_mse_maxlen(500)

# %%
mse_maxlen_train.keys()
# Out:
# [200, 500, 100]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot([100, 200, 500], [min(mse_maxlen[100]), min(mse_maxlen[200]), min(mse_maxlen[500])],'bo-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot([100, 200, 500], [min(mse_maxlen_train[100]), min(mse_maxlen_train[200]), min(mse_maxlen_train[500])],'ro-', label = "TOP-5 @ Testing data (similarity = 1)" )
plt.plot([100, 200, 500], [min(mse_maxlen_test[100]), min(mse_maxlen_test[200]), min(mse_maxlen_test[500])],'go-', label = "TOP-5 @ Trianing data (similarity = 1)" )
# plt.ylabel('Amount of documents belongs to top[1,5,10]')
# plt.xlabel('Epoches')
# plt.title('Tendancy of accuracy during training')
# plt.legend(loc = 2)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(mse_maxlen[100],'bo-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot(mse_maxlen[200],'ro-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot(mse_maxlen[500],'go-', label = "TOP-5 @ Trianing data (similarity = 1)" )
# plt.ylabel('Amount of documents belongs to top[1,5,10]')
# plt.xlabel('Epoches')
# plt.title('Tendancy of accuracy during training')
# plt.legend(loc = 2)
plt.show()

# %%
run main.py
# Out:
# Now the maxlen = 800
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.249325498939
# Training_correct error 0.335093706846
# Testing_correct error: 0.3520809412
# top- 1 = [1] : 1
# top- 5 = [20] : 20
# top- 10 = [44] : 44
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     346.099099
# std      254.919753
# min        1.000000
# 25%      123.500000
# 50%      312.500000
# 75%      527.000000
# max      976.000000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [15] : 15
# top- 10 = [33] : 33
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      380.965000
# std       257.386131
# min         1.000000
# 25%       150.875000
# 50%       360.500000
# 75%       584.250000
# max       985.500000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.220811873674
# ...

# %%
save_mse_maxlen(800)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sorted(mse_maxlen), [min(mse_maxlen[k]) for k in sorted(mse_maxlen)], 'ro-', label = "Trainig data (similarity = 1 + similairty = 0)" )
plt.plot(sorted(mse_maxlen_train), [min(mse_maxlen_train[k]) for k in sorted(mse_maxlen_train)], 'bo-', label = "Trainig data (similarity = 1)" )
plt.plot(sorted(mse_maxlen_test), [ min(mse_maxlen_test[k]) for k in sorted(mse_maxlen_test)],'go-', label = "Testing data (similarity = 1)" )
# plt.plot(sorted(mse_maxlen), [mse_maxlen[k][-1] for k in sorted(mse_maxlen)], 'ro-', label = "Trainig data (similarity = 1 + similairty = 0)" )
# plt.plot(sorted(mse_maxlen_train), [mse_maxlen_train[k][-1] for k in sorted(mse_maxlen_train)], 'bo-', label = "Trainig data (similarity = 1)" )
# plt.plot(sorted(mse_maxlen_test), [ mse_maxlen_test[k][-1] for k in sorted(mse_maxlen_test)],'go-', label = "Testing data (similarity = 1)" )
plt.ylabel('MSE')
plt.xlabel('Maxlen ( max. number of LSTM units)')
plt.title('MSE Accuracy when changinng max. number of LSTM units')
plt.legend(loc = 4)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('MSE distribution')
plt.plot(sls.mse,'ro-', label="Training data (similarity = 1 + similarity = 2)")
plt.plot(sls.mse_train,'bo-', label="Training data (similarity = 1)")
plt.plot(sls.mse_test,'go-', label="Testing data (similarity = 1)")
plt.legend()

plt.ylabel('MSE')
plt.xlabel('Epoches Times')
plt.show()

# %%
mse_maxlen_test[800][-5]
# Out:
# 0.048728149384260178

# %%
sls.mse_test[-5]
# Out:
# 0.048728149384260178

# %%
sls.mse_test[36]
# Out:
# 0.048728149384260178

# %%
# maxlen = 0
run main.py
# Out:
# Now the maxlen = 0
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training error: 0.0259518921375
# Training_correct error 0.0252002030611
# Testing_correct error: 0.03172102198
# top- 1 = [4, 55, 74, 117, 79, 137, 166, 171, 224, 215, 179, 215, 233, 265, 271, 290, 217, 290, 208, 333, 275, 263, 344, 336, 255, 248, 358, 239, 218, 405, 382, 411, 331, 353, 427, 366, 465, 221, 492] : 492
# top- 5 = [20, 203, 279, 398, 358, 418, 523, 535, 580, 581, 505, 563, 657, 677, 705, 732, 648, 711, 612, 795, 706, 733, 795, 808, 729, 690, 813, 664, 622, 898, 819, 913, 848, 867, 912, 879, 930, 641, 951] : 951
# top- 10 = [31, 316, 418, 532, 482, 563, 657, 687, 695, 726, 629, 723, 790, 793, 818, 848, 777, 811, 740, 874, 831, 882, 892, 891, 857, 813, 911, 790, 762, 951, 905, 972, 941, 934, 968, 968, 966, 777, 985] : 985
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.014014
# std        2.677806
# min        1.000000
# ...

# %%
save_mse_maxlen(900)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('MSE distribution')
plt.plot(,'ro-', label="Training data (similarity = 1 + similarity = 2)")
plt.plot(sls.mse_train,'bo-', label="Training data (similarity = 1)")
plt.plot(sls.mse_test,'go-', label="Testing data (similarity = 1)")
plt.legend()
plt.ylabel('MSE')
plt.xlabel('Epoches Times')
plt.show()

# %%
# maxlen = 900
run main.py
# Out:
# Now the maxlen = 900
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p

# %%
np.max([len(i[0]) for i in train_1])
# Out:
# 1751

# %%
np.max([len(i[1]) for i in train_1])
# Out:
# 3049

# %%
run main.py
# Out:
# Now the maxlen = 300
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.25006455183
# Training_correct error 0.309521198273
# Testing_correct error: 0.317579507828
# top- 1 = [4] : 4
# top- 5 = [25] : 25
# top- 10 = [46] : 46
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     374.497497
# std      263.383509
# min        1.000000
# 25%      158.000000
# 50%      343.500000
# 75%      578.500000
# max      962.500000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [18] : 18
# top- 10 = [31] : 31
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      395.983500
# std       267.509181
# min         1.000000
# 25%       172.750000
# 50%       366.000000
# 75%       630.000000
# max       986.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.213096797466
# ...

# %%
save_mse_maxlen(300)

# %%
run main.py
# Out:
# Now the maxlen = 150
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.274224787951
# Training_correct error 0.383821934462
# Testing_correct error: 0.405536741018
# top- 1 = [2] : 2
# top- 5 = [12] : 12
# top- 10 = [20] : 20
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     505.090090
# std      286.515494
# min        1.000000
# 25%      260.750000
# 50%      526.000000
# 75%      751.000000
# max      979.000000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [11] : 11
# top- 10 = [25] : 25
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      510.607000
# std       292.552154
# min         1.000000
# 25%       257.750000
# 50%       547.000000
# 75%       757.000000
# max       988.500000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.272391736507
# ...

# %%
save_mse_maxlen(150)

# %%
run main.py
# Out:
# Now the maxlen = 50
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.262317985296
# Training_correct error 0.326813369989
# Testing_correct error: 0.319859802723
# top- 1 = [2] : 2
# top- 5 = [18] : 18
# top- 10 = [33] : 33
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     503.848849
# std      298.244531
# min        1.000000
# 25%      234.000000
# 50%      503.000000
# 75%      762.750000
# max      987.500000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [12] : 12
# top- 10 = [16] : 16
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      497.443000
# std       304.234924
# min         1.000000
# 25%       267.500000
# 50%       516.750000
# 75%       755.625000
# max       994.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.231611460447
# ...

# %%
save_mse_maxlen(50)
