# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 3: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sorted(mse_maxlen), [min(mse_maxlen[k]) for k in sorted(mse_maxlen)], 'ro-', label = "Trainig data (similarity = 1 + similairty = 0)" )
plt.plot(sorted(mse_maxlen_train), [min(mse_maxlen_train[k]) for k in sorted(mse_maxlen_train)], 'bo-', label = "Trainig data (similarity = 1)" )
plt.plot(sorted(mse_maxlen_test), [ min(mse_maxlen_test[k]) for k in sorted(mse_maxlen_test)],'go-', label = "Testing data (similarity = 1)" )
# plt.plot(sorted(mse_maxlen), [mse_maxlen[k][-1] for k in sorted(mse_maxlen)], 'ro-', label = "Trainig data (similarity = 1 + similairty = 0)" )
# plt.plot(sorted(mse_maxlen_train), [mse_maxlen_train[k][-1] for k in sorted(mse_maxlen_train)], 'bo-', label = "Trainig data (similarity = 1)" )
# plt.plot(sorted(mse_maxlen_test), [ mse_maxlen_test[k][-1] for k in sorted(mse_maxlen_test)],'go-', label = "Testing data (similarity = 1)" )
plt.ylabel('MSE')
plt.xlabel('Maxlen ( max. number of LSTM units)')
plt.title('MSE Accuracy when changinng max. number of LSTM units')
plt.legend(loc = 1)
plt.show()

# %%
		with open(root_dir + "mse_maxlen.p", 'wb') as handle:
			pickle.dump(mse_maxlen, handle)
		with open(root_dir + "mse_maxlen_train.p", 'wb') as handle:
			pickle.dump(mse_maxlen_train, handle)
		with open(root_dir + "mse_maxlen_test.p", 'wb') as handle:
			pickle.dump(mse_maxlen_test, handle)
		with open(root_dir + "time_cost.p", 'wb') as handle:
			pickle.dump(time_cost, handle)

# %%
time_cost
# Out:
# {50: 4.543102979660034,
#  100: 8.110783815383911,
#  150: 7.896391153335571,
#  200: 9.843168020248413,
#  250: 13.372865915298462,
#  300: 15.378558158874512,
#  350: 16.963040113449097,
#  400: 18.6689190864563,
#  450: 20.756441116333008,
#  500: 23.40636396408081,
#  550: 24.782973051071167,
#  600: 28.09450602531433,
#  650: 30.200191020965576,
#  700: 31.662366151809692,
#  750: 33.98669099807739,
#  800: 35.77139711380005,
#  850: 38.597902059555054,
#  900: 39.797731161117554,
#  950: 39.651423931121826}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sorted(time_cost), [time_cost[k] for k in sorted(time_cost)], 'ro-', label = "Trainig data (similarity = 1 + similairty = 0)" )
plt.ylabel('Time')
plt.xlabel('Maxlen ( max. number of LSTM units)')
plt.title('TIme consuming')
plt.legend(loc = 4)
plt.show()
