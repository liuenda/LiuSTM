# %%
# 更改了maxlen设计的函数，使得可以在main.py中直接定义maxlne的数值

# %%
# maxlen = 200
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the model..., saving to weights/201701051610_e20_1k1k_l200.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.256023526192
# Training_correct error 0.333335667849
# Testing_correct error: 0.342972397804
# top- 1 = [1] : 1
# top- 5 = [17] : 17
# top- 10 = [26] : 26
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     458.362362
# std      279.827936
# min        1.000000
# 25%      224.000000
# 50%      461.000000
# 75%      693.750000
# max      978.000000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [16] : 16
# top- 10 = [29] : 29
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      475.959000
# std       282.316227
# min         1.000000
# 25%       237.125000
# 50%       476.500000
# 75%       722.375000
# max       985.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.251657098532
# Epoch  0 Update  42 Cost  0.24139970541
# Epoch  0 Update  63 Cost  0.272840440273
# Training error: 0.221390083432
# Training_correct error 0.190529316664
# Testing_correct error: 0.193975538015
# top- 1 = [1, 8] : 8
# top- 5 = [17, 37] : 37
# top- 10 = [26, 70] : 70
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     254.861862
# std      216.797657
# min        1.000000
# 25%       75.500000
# 50%      194.000000
# 75%      397.000000
# max      903.500000
# dtype: float64
# top- 1 = [2, 5] : 5
# top- 5 = [16, 23] : 23
# top- 10 = [29, 50] : 50
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      291.273000
# std       235.115686
# min         1.000000
# 25%        96.875000
# 50%       229.500000
# 75%       451.250000
# max       963.000000
# dtype: float64
# epoch took: 9.56556606293
#
# Epoch 1 ...
# Epoch  1 Update  84 Cost  0.173480719328
# Epoch  1 Update  105 Cost  0.227109074593
# Epoch  1 Update  126 Cost  0.209477975965
# Training error: 0.235600933433
# Training_correct error 0.153468713164
# Testing_correct error: 0.155288174748
# top- 1 = [1, 8, 4] : 4
# top- 5 = [17, 37, 35] : 35
# top- 10 = [26, 70, 67] : 67
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     298.236236
# std      232.106766
# min        1.000000
# 25%       95.500000
# 50%      263.000000
# 75%      471.000000
# max      897.500000
# dtype: float64
# top- 1 = [2, 5, 3] : 3
# top- 5 = [16, 23, 37] : 37
# top- 10 = [29, 50, 72] : 72
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      317.561000
# std       241.350061
# min         1.000000
# 25%       107.750000
# 50%       291.000000
# 75%       472.125000
# max       952.000000
# dtype: float64
# epoch took: 9.61420798302
#
# Epoch 2 ...
# Epoch  2 Update  147 Cost  0.152037858963
# Epoch  2 Update  168 Cost  0.211680442095
# Epoch  2 Update  189 Cost  0.233046606183
# Training error: 0.187974974513
# Training_correct error 0.242754876614
# Testing_correct error: 0.231702938676
# top- 1 = [1, 8, 4, 13] : 13
# top- 5 = [17, 37, 35, 61] : 61
# top- 10 = [26, 70, 67, 113] : 113
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     174.578579
# std      177.242147
# min        1.000000
# 25%       35.750000
# 50%      115.000000
# 75%      257.000000
# max      848.500000
# dtype: float64
# top- 1 = [2, 5, 3, 15] : 15
# top- 5 = [16, 23, 37, 63] : 63
# top- 10 = [29, 50, 72, 120] : 120
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      216.51600
# std       200.48973
# min         1.00000
# 25%        47.50000
# 50%       154.75000
# 75%       349.12500
# max       879.00000
# dtype: float64
# epoch took: 9.51830220222
#
# Epoch 3 ...
# Epoch  3 Update  210 Cost  0.128209650517
# Epoch  3 Update  231 Cost  0.189863979816
# Epoch  3 Update  252 Cost  0.143652036786
# Training error: 0.209973186255
# Training_correct error 0.144986107945
# Testing_correct error: 0.158282533288
# top- 1 = [1, 8, 4, 13, 6] : 6
# top- 5 = [17, 37, 35, 61, 33] : 33
# top- 10 = [26, 70, 67, 113, 70] : 70
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     223.489489
# std      191.909551
# min        1.000000
# 25%       65.000000
# 50%      174.000000
# 75%      331.500000
# max      888.000000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5] : 5
# top- 5 = [16, 23, 37, 63, 27] : 27
# top- 10 = [29, 50, 72, 120, 52] : 52
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      261.356000
# std       219.097853
# min         1.000000
# 25%        79.000000
# 50%       199.250000
# 75%       403.000000
# max       930.000000
# dtype: float64
# epoch took: 9.54189419746
#
# Epoch 4 ...
# Epoch  4 Update  273 Cost  0.199347779155
# Epoch  4 Update  294 Cost  0.297611951828
# Epoch  4 Update  315 Cost  0.225044250488
# Training error: 0.164968177676
# Training_correct error 0.234963208437
# Testing_correct error: 0.219791069627
# top- 1 = [1, 8, 4, 13, 6, 8] : 8
# top- 5 = [17, 37, 35, 61, 33, 67] : 67
# top- 10 = [26, 70, 67, 113, 70, 125] : 125
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     119.911912
# std      120.956532
# min        1.000000
# 25%       25.000000
# 50%       79.000000
# 75%      183.750000
# max      724.500000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5, 16] : 16
# top- 5 = [16, 23, 37, 63, 27, 73] : 73
# top- 10 = [29, 50, 72, 120, 52, 126] : 126
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      141.915000
# std       146.831868
# min         1.000000
# 25%        29.375000
# 50%        91.000000
# 75%       206.375000
# max       714.000000
# dtype: float64
# epoch took: 9.53586483002
#
# Epoch 5 ...
# Epoch  5 Update  336 Cost  0.113318875432
# Epoch  5 Update  357 Cost  0.128445804119
# Epoch  5 Update  378 Cost  0.139468535781
# Training error: 0.138220712543
# Training_correct error 0.0922933667898
# Testing_correct error: 0.0988744050264
# top- 1 = [1, 8, 4, 13, 6, 8, 20] : 20
# top- 5 = [17, 37, 35, 61, 33, 67, 90] : 90
# top- 10 = [26, 70, 67, 113, 70, 125, 140] : 140
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      92.508509
# std       87.854111
# min        1.000000
# 25%       22.000000
# 50%       65.000000
# 75%      143.500000
# max      456.500000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5, 16, 13] : 13
# top- 5 = [16, 23, 37, 63, 27, 73, 67] : 67
# top- 10 = [29, 50, 72, 120, 52, 126, 118] : 118
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      118.969000
# std       119.504093
# min         1.000000
# 25%        29.500000
# 50%        75.500000
# 75%       173.500000
# max       720.000000
# dtype: float64
# epoch took: 9.53620696068
#
# Epoch 6 ...
# Epoch  6 Update  399 Cost  0.08879083395
# Epoch  6 Update  420 Cost  0.0998856425285
# Epoch  6 Update  441 Cost  0.205095753074
# Training error: 0.13291439414
# Training_correct error 0.156636953354
# Testing_correct error: 0.18975739181
# top- 1 = [1, 8, 4, 13, 6, 8, 20, 11] : 11
# top- 5 = [17, 37, 35, 61, 33, 67, 90, 81] : 81
# top- 10 = [26, 70, 67, 113, 70, 125, 140, 157] : 157
# Discription of evaluation (ranking) for training data:
# count    999.00000
# mean      92.85986
# std       86.06248
# min        1.00000
# 25%       24.00000
# 50%       71.00000
# 75%      134.00000
# max      444.00000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5, 16, 13, 16] : 16
# top- 5 = [16, 23, 37, 63, 27, 73, 67, 76] : 76
# top- 10 = [29, 50, 72, 120, 52, 126, 118, 124] : 124
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      128.016000
# std       120.254555
# min         1.000000
# 25%        29.750000
# 50%        88.000000
# 75%       196.250000
# max       620.000000
# dtype: float64
# epoch took: 9.54475307465
#
# Epoch 7 ...
# Epoch  7 Update  462 Cost  0.158953100443
# Epoch  7 Update  483 Cost  0.150326967239
# Epoch  7 Update  504 Cost  0.208725348115
# Training error: 0.149434939027
# Training_correct error 0.0807736217976
# Testing_correct error: 0.0905024632812
# top- 1 = [1, 8, 4, 13, 6, 8, 20, 11, 18] : 18
# top- 5 = [17, 37, 35, 61, 33, 67, 90, 81, 79] : 79
# top- 10 = [26, 70, 67, 113, 70, 125, 140, 157, 151] : 151
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     110.995996
# std      112.062444
# min        1.000000
# 25%       21.500000
# 50%       73.000000
# 75%      169.500000
# max      543.000000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5, 16, 13, 16, 13] : 13
# top- 5 = [16, 23, 37, 63, 27, 73, 67, 76, 85] : 85
# top- 10 = [29, 50, 72, 120, 52, 126, 118, 124, 138] : 138
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      159.422000
# std       159.991644
# min         1.000000
# 25%        26.500000
# 50%       100.750000
# 75%       252.500000
# max       725.000000
# dtype: float64
# epoch took: 9.53625798225
#
# Epoch 8 ...
# Epoch  8 Update  525 Cost  0.0983357876539
# Epoch  8 Update  546 Cost  0.123154610395
# Epoch  8 Update  567 Cost  0.103565230966
# Training error: 0.110778510571
# Training_correct error 0.0948333144188
# Testing_correct error: 0.103301428258
# top- 1 = [1, 8, 4, 13, 6, 8, 20, 11, 18, 22] : 22
# top- 5 = [17, 37, 35, 61, 33, 67, 90, 81, 79, 110] : 110
# top- 10 = [26, 70, 67, 113, 70, 125, 140, 157, 151, 181] : 181
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      72.652653
# std       74.072055
# min        1.000000
# 25%       15.000000
# 50%       48.000000
# 75%      105.000000
# max      435.000000
# dtype: float64
# top- 1 = [2, 5, 3, 15, 5, 16, 13, 16, 13, 17] : 17
# top- 5 = [16, 23, 37, 63, 27, 73, 67, 76, 85, 95] : 95
# top- 10 = [29, 50, 72, 120, 52, 126, 118, 124, 138, 162] : 162
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      105.217000
# std       110.803052
# min         1.000000
# 25%        19.000000
# 50%        65.500000
# 75%       155.000000
# max       638.000000
# dtype: float64
# epoch took: 9.56129789352
#
# Epoch 9 ...
# Epoch  9 Update  588 Cost  0.123290605843
# KeyboardInterruptTraceback (most recent call last)
# /home/M2015eliu/cas/2017.1.1~LiuSTM/main.py in <module>()
#     323                 dir_file = "weights/201701051610_e20_1k1k_l200.p"
#     324                 print "Starting to training the model..., saving to", dir_file
# --> 325                 sls=lstm.LSTM(dir_file, maxlen, load=False, training=True)
#     326                 sls.train_lstm(train, 20, train_1, test_1)
#     327                 sls.save_model()
#
# /home/M2015eliu/cas/2017.1.1~LiuSTM/lstm.pyc in train_lstm(self, train, max_epochs, correct, test_correct)
#     524                 emb1 = np.swapaxes(trconv, 1, 2)
#     525
# --> 526                 cst = self.f_grad_shared(emb2, mas2, emb1, mas1, y2)
#     527                 s = self.f_update(lrate) # Not USED ???
#     528
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     949         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     950                  allow_gc=allow_gc):
# --> 951             r = p(n, [x[0] for x in i], o)
#     952             for o in node.outputs:
#     953                 compute_map[o][0] = True
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     938                         args,
#     939                         outs,
# --> 940                         self, node)
#     941         except (ImportError, theano.gof.cmodule.MissingGXX):
#     942             p = self.execute
#
# KeyboardInterrupt:

# %%
# maxlen = 0 (shoul the max. length appeared)
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# ('Now the maxlen =', 0)
# Starting to training the model..., saving to weights/201701051610_e20_1k1k_l200.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.257755994797
# Training_correct error 0.337905704975
# Testing_correct error: 0.335038632154
# top- 1 = [3] : 3
# top- 5 = [21] : 21
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [12] : 12
# top- 10 = [24] : 24
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      551.164000
# std       260.994743
# min         1.000000
# 25%       362.625000
# 50%       559.000000
# 75%       775.500000
# max       985.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.182155281305
# Epoch  0 Update  42 Cost  0.167487800121
# Epoch  0 Update  63 Cost  0.207024231553
# Training error: 0.125692605972
# Training_correct error 0.118412218988
# Testing_correct error: 0.114850081503
# top- 1 = [3, 48] : 48
# top- 5 = [21, 199] : 199
# top- 10 = [30, 304] : 304
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      52.060060
# std       68.136176
# min        1.000000
# 25%        7.500000
# 50%       28.000000
# 75%       63.000000
# max      370.500000
# dtype: float64
# top- 1 = [1, 46] : 46
# top- 5 = [12, 151] : 151
# top- 10 = [24, 232] : 232
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       61.457000
# std        73.761911
# min         1.000000
# 25%        11.500000
# 50%        34.000000
# 75%        85.000000
# max       448.000000
# dtype: float64
# epoch took: 47.7021028996
#
# Epoch 1 ...
# Epoch  1 Update  84 Cost  0.10254971683
# Epoch  1 Update  105 Cost  0.11504471302
# Epoch  1 Update  126 Cost  0.0893101021647
# Training error: 0.117395535111
# Training_correct error 0.0951170623302
# Testing_correct error: 0.0903676599264
# top- 1 = [3, 48, 50] : 50
# top- 5 = [21, 199, 208] : 208
# top- 10 = [30, 304, 320] : 320
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      52.107608
# std       67.633366
# min        1.000000
# 25%        7.000000
# 50%       22.000000
# 75%       72.500000
# max      324.000000
# dtype: float64
# top- 1 = [1, 46, 43] : 43
# top- 5 = [12, 151, 169] : 169
# top- 10 = [24, 232, 267] : 267
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       54.447000
# std        69.017665
# min         1.000000
# 25%         9.500000
# 50%        30.500000
# 75%        61.250000
# max       425.000000
# dtype: float64
# epoch took: 48.3495190144
#
# Epoch 2 ...
# Epoch  2 Update  147 Cost  0.0750384479761
# Epoch  2 Update  168 Cost  0.0610469020903
# Epoch  2 Update  189 Cost  0.124674670398
# Training error: 0.0985486656427
# Training_correct error 0.101944170892
# Testing_correct error: 0.102379269898
# top- 1 = [3, 48, 50, 86] : 86
# top- 5 = [21, 199, 208, 293] : 293
# top- 10 = [30, 304, 320, 431] : 431
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      38.222723
# std       53.008296
# min        1.000000
# 25%        4.000000
# 50%       15.000000
# 75%       50.250000
# max      398.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81] : 81
# top- 5 = [12, 151, 169, 246] : 246
# top- 10 = [24, 232, 267, 378] : 378
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       44.222000
# std        56.271624
# min         1.000000
# 25%         5.500000
# 50%        17.500000
# 75%        62.000000
# max       432.000000
# dtype: float64
# epoch took: 47.8764941692
#
# Epoch 3 ...
# Epoch  3 Update  210 Cost  0.0899893343449
# Epoch  3 Update  231 Cost  0.0913775414228
# Epoch  3 Update  252 Cost  0.0783319026232
# Training error: 0.0997497886419
# Training_correct error 0.0821037888527
# Testing_correct error: 0.083479039371
# top- 1 = [3, 48, 50, 86, 76] : 76
# top- 5 = [21, 199, 208, 293, 310] : 310
# top- 10 = [30, 304, 320, 431, 411] : 411
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      37.868368
# std       57.583045
# min        1.000000
# 25%        3.500000
# 50%       16.000000
# 75%       42.000000
# max      378.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66] : 66
# top- 5 = [12, 151, 169, 246, 242] : 242
# top- 10 = [24, 232, 267, 378, 344] : 344
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       43.143000
# std        60.577844
# min         1.000000
# 25%         6.000000
# 50%        21.250000
# 75%        46.000000
# max       417.000000
# dtype: float64
# epoch took: 48.1992940903
#
# Epoch 4 ...
# Epoch  4 Update  273 Cost  0.102640353143
# Epoch  4 Update  294 Cost  0.0877730324864
# Epoch  4 Update  315 Cost  0.119521379471
# Training error: 0.086856238544
# Training_correct error 0.107121005654
# Testing_correct error: 0.120220825076
# top- 1 = [3, 48, 50, 86, 76, 118] : 118
# top- 5 = [21, 199, 208, 293, 310, 392] : 392
# top- 10 = [30, 304, 320, 431, 411, 533] : 533
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      24.363864
# std       37.543915
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       26.500000
# max      279.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92] : 92
# top- 5 = [12, 151, 169, 246, 242, 285] : 285
# top- 10 = [24, 232, 267, 378, 344, 455] : 455
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       35.453000
# std        50.465682
# min         1.000000
# 25%         4.000000
# 50%        12.500000
# 75%        41.250000
# max       324.000000
# dtype: float64
# epoch took: 49.2182090282
#
# Epoch 5 ...
# Epoch  5 Update  336 Cost  0.0586893036962
# Epoch  5 Update  357 Cost  0.0592846162617
# Epoch  5 Update  378 Cost  0.172971352935
# Training error: 0.0897238701582
# Training_correct error 0.0772184580564
# Testing_correct error: 0.0757179409266
# top- 1 = [3, 48, 50, 86, 76, 118, 93] : 93
# top- 5 = [21, 199, 208, 293, 310, 392, 359] : 359
# top- 10 = [30, 304, 320, 431, 411, 533, 495] : 495
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      28.575576
# std       44.863448
# min        1.000000
# 25%        3.000000
# 50%       10.500000
# 75%       31.000000
# max      277.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79] : 79
# top- 5 = [12, 151, 169, 246, 242, 285, 279] : 279
# top- 10 = [24, 232, 267, 378, 344, 455, 443] : 443
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       35.241500
# std        50.618402
# min         1.000000
# 25%         4.500000
# 50%        13.750000
# 75%        41.000000
# max       273.000000
# dtype: float64
# epoch took: 49.8195390701
#
# Epoch 6 ...
# Epoch  6 Update  399 Cost  0.0754013508558
# Epoch  6 Update  420 Cost  0.0876249596477
# Epoch  6 Update  441 Cost  0.165213420987
# Training error: 0.0925588086247
# Training_correct error 0.075753249228
# Testing_correct error: 0.0882906317711
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92] : 92
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406] : 406
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582] : 582
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      24.823824
# std       42.170965
# min        1.000000
# 25%        3.000000
# 50%        7.500000
# 75%       21.000000
# max      344.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80] : 80
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306] : 306
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470] : 470
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       30.191000
# std        47.151795
# min         1.000000
# 25%         4.000000
# 50%        11.000000
# 75%        25.000000
# max       333.000000
# dtype: float64
# epoch took: 50.368283987
#
# Epoch 7 ...
# KeyboardInterruptTraceback (most recent call last)
# /home/M2015eliu/cas/2017.1.1~LiuSTM/main.py in <module>()
#     324                 dir_file = "weights/201701102308_e40_1k1k_l0.p"
#     325                 print "Starting to training the model..., saving to", dir_file
# --> 326                 sls=lstm.LSTM(dir_file, maxlen, load=False, training=True)
#     327                 sls.train_lstm(train, epoch, train_1, test_1)
#     328                 sls.save_model()
#
# /home/M2015eliu/cas/2017.1.1~LiuSTM/lstm.pyc in train_lstm(self, train, max_epochs, correct, test_correct)
#     524                 emb1 = np.swapaxes(trconv, 1, 2)
#     525
# --> 526                 cst = self.f_grad_shared(emb2, mas2, emb1, mas1, y2)
#     527                 s = self.f_update(lrate) # Not USED ???
#     528
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in rval(p, i, o, n, allow_gc)
#     949         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     950                  allow_gc=allow_gc):
# --> 951             r = p(n, [x[0] for x in i], o)
#     952             for o in node.outputs:
#     953                 compute_map[o][0] = True
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/theano/scan_module/scan_op.pyc in <lambda>(node, args, outs)
#     938                         args,
#     939                         outs,
# --> 940                         self, node)
#     941         except (ImportError, theano.gof.cmodule.MissingGXX):
#     942             p = self.execute
#
# KeyboardInterrupt:

# %%
# Set epoch = 40, maxlen = 0
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# ('Now the maxlen =', 0)
# Starting to training the model..., saving to weights/201701102308_e40_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.257755994797
# Training_correct error 0.337905704975
# Testing_correct error: 0.335038632154
# top- 1 = [3] : 3
# top- 5 = [21] : 21
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [12] : 12
# top- 10 = [24] : 24
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      551.164000
# std       260.994743
# min         1.000000
# 25%       362.625000
# 50%       559.000000
# 75%       775.500000
# max       985.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.182155281305
# Epoch  0 Update  42 Cost  0.167487800121
# Epoch  0 Update  63 Cost  0.207024231553
# Training error: 0.125692605972
# Training_correct error 0.118412218988
# Testing_correct error: 0.114850081503
# top- 1 = [3, 48] : 48
# top- 5 = [21, 199] : 199
# top- 10 = [30, 304] : 304
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      52.060060
# std       68.136176
# min        1.000000
# 25%        7.500000
# 50%       28.000000
# 75%       63.000000
# max      370.500000
# dtype: float64
# top- 1 = [1, 46] : 46
# top- 5 = [12, 151] : 151
# top- 10 = [24, 232] : 232
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       61.457000
# std        73.761911
# min         1.000000
# 25%        11.500000
# 50%        34.000000
# 75%        85.000000
# max       448.000000
# dtype: float64
# epoch took: 49.6009230614
#
# Epoch 1 ...
# Epoch  1 Update  84 Cost  0.10254971683
# Epoch  1 Update  105 Cost  0.11504471302
# Epoch  1 Update  126 Cost  0.0893101021647
# Training error: 0.117395535111
# Training_correct error 0.0951170623302
# Testing_correct error: 0.0903676599264
# top- 1 = [3, 48, 50] : 50
# top- 5 = [21, 199, 208] : 208
# top- 10 = [30, 304, 320] : 320
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      52.107608
# std       67.633366
# min        1.000000
# 25%        7.000000
# 50%       22.000000
# 75%       72.500000
# max      324.000000
# dtype: float64
# top- 1 = [1, 46, 43] : 43
# top- 5 = [12, 151, 169] : 169
# top- 10 = [24, 232, 267] : 267
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       54.447000
# std        69.017665
# min         1.000000
# 25%         9.500000
# 50%        30.500000
# 75%        61.250000
# max       425.000000
# dtype: float64
# epoch took: 50.0520739555
#
# Epoch 2 ...
# Epoch  2 Update  147 Cost  0.0750384479761
# Epoch  2 Update  168 Cost  0.0610469020903
# Epoch  2 Update  189 Cost  0.124674670398
# Training error: 0.0985486656427
# Training_correct error 0.101944170892
# Testing_correct error: 0.102379269898
# top- 1 = [3, 48, 50, 86] : 86
# top- 5 = [21, 199, 208, 293] : 293
# top- 10 = [30, 304, 320, 431] : 431
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      38.222723
# std       53.008296
# min        1.000000
# 25%        4.000000
# 50%       15.000000
# 75%       50.250000
# max      398.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81] : 81
# top- 5 = [12, 151, 169, 246] : 246
# top- 10 = [24, 232, 267, 378] : 378
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       44.222000
# std        56.271624
# min         1.000000
# 25%         5.500000
# 50%        17.500000
# 75%        62.000000
# max       432.000000
# dtype: float64
# epoch took: 50.0570180416
#
# Epoch 3 ...
# Epoch  3 Update  210 Cost  0.0899893343449
# Epoch  3 Update  231 Cost  0.0913775414228
# Epoch  3 Update  252 Cost  0.0783319026232
# Training error: 0.0997497886419
# Training_correct error 0.0821037888527
# Testing_correct error: 0.083479039371
# top- 1 = [3, 48, 50, 86, 76] : 76
# top- 5 = [21, 199, 208, 293, 310] : 310
# top- 10 = [30, 304, 320, 431, 411] : 411
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      37.868368
# std       57.583045
# min        1.000000
# 25%        3.500000
# 50%       16.000000
# 75%       42.000000
# max      378.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66] : 66
# top- 5 = [12, 151, 169, 246, 242] : 242
# top- 10 = [24, 232, 267, 378, 344] : 344
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       43.143000
# std        60.577844
# min         1.000000
# 25%         6.000000
# 50%        21.250000
# 75%        46.000000
# max       417.000000
# dtype: float64
# epoch took: 50.3379600048
#
# Epoch 4 ...
# Epoch  4 Update  273 Cost  0.102640353143
# Epoch  4 Update  294 Cost  0.0877730324864
# Epoch  4 Update  315 Cost  0.119521379471
# Training error: 0.086856238544
# Training_correct error 0.107121005654
# Testing_correct error: 0.120220825076
# top- 1 = [3, 48, 50, 86, 76, 118] : 118
# top- 5 = [21, 199, 208, 293, 310, 392] : 392
# top- 10 = [30, 304, 320, 431, 411, 533] : 533
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      24.363864
# std       37.543915
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       26.500000
# max      279.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92] : 92
# top- 5 = [12, 151, 169, 246, 242, 285] : 285
# top- 10 = [24, 232, 267, 378, 344, 455] : 455
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       35.453000
# std        50.465682
# min         1.000000
# 25%         4.000000
# 50%        12.500000
# 75%        41.250000
# max       324.000000
# dtype: float64
# epoch took: 50.2852768898
#
# Epoch 5 ...
# Epoch  5 Update  336 Cost  0.0586893036962
# Epoch  5 Update  357 Cost  0.0592846162617
# Epoch  5 Update  378 Cost  0.172971352935
# Training error: 0.0897238701582
# Training_correct error 0.0772184580564
# Testing_correct error: 0.0757179409266
# top- 1 = [3, 48, 50, 86, 76, 118, 93] : 93
# top- 5 = [21, 199, 208, 293, 310, 392, 359] : 359
# top- 10 = [30, 304, 320, 431, 411, 533, 495] : 495
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      28.575576
# std       44.863448
# min        1.000000
# 25%        3.000000
# 50%       10.500000
# 75%       31.000000
# max      277.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79] : 79
# top- 5 = [12, 151, 169, 246, 242, 285, 279] : 279
# top- 10 = [24, 232, 267, 378, 344, 455, 443] : 443
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       35.241500
# std        50.618402
# min         1.000000
# 25%         4.500000
# 50%        13.750000
# 75%        41.000000
# max       273.000000
# dtype: float64
# epoch took: 50.6158559322
#
# Epoch 6 ...
# Epoch  6 Update  399 Cost  0.0754013508558
# Epoch  6 Update  420 Cost  0.0876249596477
# Epoch  6 Update  441 Cost  0.165213420987
# Training error: 0.0925588086247
# Training_correct error 0.075753249228
# Testing_correct error: 0.0882906317711
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92] : 92
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406] : 406
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582] : 582
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      24.823824
# std       42.170965
# min        1.000000
# 25%        3.000000
# 50%        7.500000
# 75%       21.000000
# max      344.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80] : 80
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306] : 306
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470] : 470
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       30.191000
# std        47.151795
# min         1.000000
# 25%         4.000000
# 50%        11.000000
# 75%        25.000000
# max       333.000000
# dtype: float64
# epoch took: 50.237580061
#
# Epoch 7 ...
# Epoch  7 Update  462 Cost  0.0874141305685
# Epoch  7 Update  483 Cost  0.0745683759451
# Epoch  7 Update  504 Cost  0.084833085537
# Training error: 0.0767989233136
# Training_correct error 0.0734879598022
# Testing_correct error: 0.0873811766505
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202] : 202
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515] : 515
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690] : 690
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      18.065065
# std       33.711923
# min        1.000000
# 25%        1.500000
# 50%        5.000000
# 75%       14.500000
# max      263.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135] : 135
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423] : 423
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557] : 557
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       27.840000
# std        46.303525
# min         1.000000
# 25%         2.500000
# 50%         8.000000
# 75%        27.250000
# max       291.000000
# dtype: float64
# epoch took: 50.0159208775
#
# Epoch 8 ...
# Epoch  8 Update  525 Cost  0.0818914100528
# Epoch  8 Update  546 Cost  0.102885998785
# Epoch  8 Update  567 Cost  0.124444670975
# Training error: 0.0649016872048
# Training_correct error 0.0729025006294
# Testing_correct error: 0.0839079767466
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205] : 205
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564] : 564
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738] : 738
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      12.638639
# std       22.141127
# min        1.000000
# 25%        1.500000
# 50%        4.000000
# 75%       11.000000
# max      162.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156] : 156
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468] : 468
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596] : 596
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       19.704000
# std        34.629317
# min         1.000000
# 25%         2.000000
# 50%         6.000000
# 75%        19.625000
# max       206.000000
# dtype: float64
# epoch took: 49.9009859562
#
# Epoch 9 ...
# Epoch  9 Update  588 Cost  0.08970028162
# Epoch  9 Update  609 Cost  0.0695525407791
# Epoch  9 Update  630 Cost  0.0319570749998
# Training error: 0.0614430606365
# Training_correct error 0.0697435438633
# Testing_correct error: 0.0887727290392
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225] : 225
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610] : 610
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736] : 736
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      12.092092
# std       22.614483
# min        1.000000
# 25%        1.500000
# 50%        3.500000
# 75%       11.250000
# max      208.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166] : 166
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479] : 479
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614] : 614
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       21.41400
# std        38.95274
# min         1.00000
# 25%         2.00000
# 50%         6.00000
# 75%        22.50000
# max       271.00000
# dtype: float64
# epoch took: 48.964138031
#
# Epoch 10 ...
# Epoch  10 Update  651 Cost  0.063362672925
# Epoch  10 Update  672 Cost  0.0694444775581
# Epoch  10 Update  693 Cost  0.0757331997156
# Training error: 0.064365811646
# Training_correct error 0.0788674727082
# Testing_correct error: 0.0984400510788
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200] : 200
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598] : 598
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745] : 745
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      12.458458
# std       22.218322
# min        1.000000
# 25%        1.500000
# 50%        3.500000
# 75%       11.000000
# max      173.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148] : 148
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475] : 475
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605] : 605
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       21.715000
# std        38.724454
# min         1.000000
# 25%         2.000000
# 50%         6.000000
# 75%        19.000000
# max       289.000000
# dtype: float64
# epoch took: 49.38337183
#
# Epoch 11 ...
# Epoch  11 Update  714 Cost  0.0437170118093
# Epoch  11 Update  735 Cost  0.114784456789
# Epoch  11 Update  756 Cost  0.0514871068299
# Training error: 0.0676115751266
# Training_correct error 0.0683713331819
# Testing_correct error: 0.0836198031902
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161] : 161
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536] : 536
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698] : 698
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      13.920921
# std       23.795582
# min        1.000000
# 25%        2.000000
# 50%        4.500000
# 75%       14.000000
# max      294.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115] : 115
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452] : 452
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622] : 622
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       20.02600
# std        33.57005
# min         1.00000
# 25%         2.00000
# 50%         6.25000
# 75%        17.50000
# max       217.00000
# dtype: float64
# epoch took: 48.763133049
#
# Epoch 12 ...
# Epoch  12 Update  777 Cost  0.0336507894099
# Epoch  12 Update  798 Cost  0.0849446207285
# Epoch  12 Update  819 Cost  0.0798107907176
# Training error: 0.0687031969428
# Training_correct error 0.0725525915623
# Testing_correct error: 0.0905041620135
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169] : 169
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532] : 532
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702] : 702
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      13.523524
# std       23.272234
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%       13.000000
# max      288.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127] : 127
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485] : 485
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672] : 672
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       17.531000
# std        29.637196
# min         1.000000
# 25%         2.000000
# 50%         5.500000
# 75%        15.000000
# max       190.000000
# dtype: float64
# epoch took: 49.0213570595
#
# Epoch 13 ...
# Epoch  13 Update  840 Cost  0.072304174304
# Epoch  13 Update  861 Cost  0.0690368041396
# Epoch  13 Update  882 Cost  0.0413294769824
# Training error: 0.0671595260501
# Training_correct error 0.0689151287079
# Testing_correct error: 0.0870760679245
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186] : 186
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595] : 595
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716] : 716
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      12.617618
# std       21.336281
# min        1.000000
# 25%        1.500000
# 50%        3.500000
# 75%       12.500000
# max      245.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143] : 143
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529] : 529
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665] : 665
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       15.855000
# std        25.879059
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        16.000000
# max       181.000000
# dtype: float64
# epoch took: 50.0139009953
#
# Epoch 14 ...
# Epoch  14 Update  903 Cost  0.0230688545853
# Epoch  14 Update  924 Cost  0.0697318464518
# Epoch  14 Update  945 Cost  0.0603713318706
# Training error: 0.055987522006
# Training_correct error 0.0552660189569
# Testing_correct error: 0.0641145408154
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233] : 233
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653] : 653
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779] : 779
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       8.545546
# std       13.568803
# min        1.000000
# 25%        1.500000
# 50%        3.000000
# 75%        8.500000
# max      157.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162] : 162
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530] : 530
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698] : 698
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       11.858000
# std        17.776947
# min         1.000000
# 25%         2.000000
# 50%         4.750000
# 75%        13.125000
# max       120.000000
# dtype: float64
# epoch took: 49.6344349384
#
# Epoch 15 ...
# Epoch  15 Update  966 Cost  0.0660632997751
# Epoch  15 Update  987 Cost  0.0347093641758
# Epoch  15 Update  1008 Cost  0.039114356041
# Training error: 0.0527125261724
# Training_correct error 0.0673270151019
# Testing_correct error: 0.07998406142
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259] : 259
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714] : 714
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831] : 831
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       7.254254
# std       13.664529
# min        1.000000
# 25%        1.000000
# 50%        2.500000
# 75%        6.000000
# max      155.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193] : 193
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630] : 630
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753] : 753
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       11.165000
# std        18.126012
# min         1.000000
# 25%         1.500000
# 50%         3.000000
# 75%        10.000000
# max       151.000000
# dtype: float64
# epoch took: 48.8395800591
#
# Epoch 16 ...
# Epoch  16 Update  1029 Cost  0.0442724451423
# Epoch  16 Update  1050 Cost  0.0652790665627
# Epoch  16 Update  1071 Cost  0.0747208446264
# Training error: 0.0483071468771
# Training_correct error 0.0516675412655
# Testing_correct error: 0.0678435266018
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272] : 272
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735] : 735
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843] : 843
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       6.183183
# std       11.160784
# min        1.000000
# 25%        1.000000
# 50%        2.500000
# 75%        6.000000
# max      164.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194] : 194
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636] : 636
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802] : 802
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        9.038000
# std        14.761859
# min         1.000000
# 25%         1.500000
# 50%         3.500000
# 75%         8.000000
# max       135.000000
# dtype: float64
# epoch took: 48.9036560059
#
# Epoch 17 ...
# Epoch  17 Update  1092 Cost  0.0414074324071
# Epoch  17 Update  1113 Cost  0.071006372571
# Epoch  17 Update  1134 Cost  0.0419829301536
# Training error: 0.0467457361519
# Training_correct error 0.0499443151057
# Testing_correct error: 0.0650392621756
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263] : 263
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749] : 749
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864] : 864
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       5.903904
# std       10.514103
# min        1.000000
# 25%        1.000000
# 50%        2.500000
# 75%        5.250000
# max      145.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198] : 198
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685] : 685
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807] : 807
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        8.325000
# std        13.669537
# min         1.000000
# 25%         1.500000
# 50%         3.000000
# 75%         7.000000
# max       123.000000
# dtype: float64
# epoch took: 50.1264619827
#
# Epoch 18 ...
# Epoch  18 Update  1155 Cost  0.0281577594578
# Epoch  18 Update  1176 Cost  0.0279857199639
# Epoch  18 Update  1197 Cost  0.031181935221
# Training error: 0.0448585934937
# Training_correct error 0.0507593862712
# Testing_correct error: 0.0675635188818
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297] : 297
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776] : 776
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887] : 887
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       5.160160
# std        9.167385
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       96.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225] : 225
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701] : 701
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817] : 817
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        8.575000
# std        15.275134
# min         1.000000
# 25%         1.500000
# 50%         2.500000
# 75%         7.000000
# max       134.000000
# dtype: float64
# epoch took: 49.9880919456
#
# Epoch 19 ...
# Epoch  19 Update  1218 Cost  0.0584981888533
# Epoch  19 Update  1239 Cost  0.0524895340204
# Epoch  19 Update  1260 Cost  0.0314953140914
# Training error: 0.0442051738501
# Training_correct error 0.0425166003406
# Testing_correct error: 0.0482059717178
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274] : 274
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778] : 778
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881] : 881
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       4.926927
# std        7.862557
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      100.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206] : 206
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689] : 689
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814] : 814
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        6.672000
# std         9.635105
# min         1.000000
# 25%         1.500000
# 50%         3.000000
# 75%         7.000000
# max       109.000000
# dtype: float64
# epoch took: 49.970911026
#
# Epoch 20 ...
# Epoch  20 Update  1281 Cost  0.0426433384418
# Epoch  20 Update  1302 Cost  0.0587750151753
# Epoch  20 Update  1323 Cost  0.0450344607234
# Training error: 0.0559212006629
# Training_correct error 0.0429740361869
# Testing_correct error: 0.0454378426075
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255] : 255
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691] : 691
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808] : 808
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       6.494494
# std        8.808143
# min        1.000000
# 25%        1.000000
# 50%        2.500000
# 75%        7.500000
# max       59.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170] : 170
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616] : 616
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751] : 751
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        8.008000
# std        10.683542
# min         1.000000
# 25%         1.500000
# 50%         4.000000
# 75%        10.000000
# max        79.000000
# dtype: float64
# epoch took: 49.3655118942
#
# Epoch 21 ...
# Epoch  21 Update  1344 Cost  0.0263530723751
# Epoch  21 Update  1365 Cost  0.0522510185838
# Epoch  21 Update  1386 Cost  0.0789667367935
# Training error: 0.055720359087
# Training_correct error 0.0555658824742
# Testing_correct error: 0.0678117498755
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212] : 212
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669] : 669
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815] : 815
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       7.540541
# std       13.140623
# min        1.000000
# 25%        1.500000
# 50%        3.000000
# 75%        7.500000
# max      167.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155] : 155
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550] : 550
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738] : 738
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       11.61400
# std        18.44666
# min         1.00000
# 25%         2.00000
# 50%         4.50000
# 75%        11.00000
# max       124.00000
# dtype: float64
# epoch took: 48.9510321617
#
# Epoch 22 ...
# Epoch  22 Update  1407 Cost  0.0580897480249
# Epoch  22 Update  1428 Cost  0.0394529700279
# Epoch  22 Update  1449 Cost  0.0814228877425
# Training error: 0.0426833406091
# Training_correct error 0.0509922988713
# Testing_correct error: 0.0691846162081
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357] : 357
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826] : 826
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928] : 928
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       4.130130
# std        7.809838
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.500000
# max       79.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239] : 239
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741] : 741
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846] : 846
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean        8.28100
# std        16.69739
# min         1.00000
# 25%         1.50000
# 50%         2.00000
# 75%         5.50000
# max       122.00000
# dtype: float64
# epoch took: 48.2691612244
#
# Epoch 23 ...
# Epoch  23 Update  1470 Cost  0.0264135282487
# Epoch  23 Update  1491 Cost  0.0362154617906
# Epoch  23 Update  1512 Cost  0.0264660809189
# Training error: 0.0416636988521
# Training_correct error 0.0405298173428
# Testing_correct error: 0.0468727312982
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337] : 337
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827] : 827
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909] : 909
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.782783
# std        5.498439
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.500000
# max       75.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234] : 234
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746] : 746
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839] : 839
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        5.429000
# std         7.801399
# min         1.000000
# 25%         1.500000
# 50%         2.000000
# 75%         5.500000
# max        93.000000
# dtype: float64
# epoch took: 49.2957229614
#
# Epoch 24 ...
# Epoch  24 Update  1533 Cost  0.0491187348962
# Epoch  24 Update  1554 Cost  0.0457423888147
# Epoch  24 Update  1575 Cost  0.0264707300812
# Training error: 0.0377053432167
# Training_correct error 0.0344945862889
# Testing_correct error: 0.043886654079
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394] : 394
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875] : 875
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939] : 939
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.208208
# std        4.979637
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.000000
# max       54.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274] : 274
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783] : 783
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872] : 872
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        5.048000
# std         7.617199
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.500000
# max        85.000000
# dtype: float64
# epoch took: 50.686259985
#
# Epoch 25 ...
# Epoch  25 Update  1596 Cost  0.0414323508739
# Epoch  25 Update  1617 Cost  0.0281491354108
# Epoch  25 Update  1638 Cost  0.0174471158534
# Training error: 0.0395827367902
# Training_correct error 0.0427967011929
# Testing_correct error: 0.0637759938836
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399] : 399
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867] : 867
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940] : 940
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.638639
# std        7.016660
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.000000
# max       56.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268] : 268
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750] : 750
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855] : 855
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean        7.44400
# std        14.25012
# min         1.00000
# 25%         1.00000
# 50%         2.00000
# 75%         5.12500
# max       100.00000
# dtype: float64
# epoch took: 50.023966074
#
# Epoch 26 ...
# Epoch  26 Update  1659 Cost  0.0460323989391
# Epoch  26 Update  1680 Cost  0.0329669043422
# Epoch  26 Update  1701 Cost  0.0176671352237
# Training error: 0.0378140434623
# Training_correct error 0.0409294292331
# Testing_correct error: 0.0505609735847
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373] : 373
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859] : 859
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941] : 941
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.520521
# std        5.985439
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.500000
# max       80.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269] : 269
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777] : 777
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853] : 853
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        5.603000
# std         9.090546
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        69.000000
# dtype: float64
# epoch took: 50.0605611801
#
# Epoch 27 ...
# Epoch  27 Update  1722 Cost  0.0237131565809
# Epoch  27 Update  1743 Cost  0.0538401976228
# Epoch  27 Update  1764 Cost  0.0231092013419
# Training error: 0.0398889742792
# Training_correct error 0.0451489761472
# Testing_correct error: 0.0619098581374
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397] : 397
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841] : 841
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934] : 934
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.738739
# std        6.686009
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.000000
# max       54.500000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257] : 257
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747] : 747
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852] : 852
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        7.371000
# std        14.550432
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.500000
# max       107.000000
# dtype: float64
# epoch took: 49.7377181053
#
# Epoch 28 ...
# Epoch  28 Update  1785 Cost  0.0307862199843
# Epoch  28 Update  1806 Cost  0.0532463639975
# Epoch  28 Update  1827 Cost  0.023118449375
# Training error: 0.043498147279
# Training_correct error 0.0411802940071
# Testing_correct error: 0.0437696017325
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332] : 332
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836] : 836
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943] : 943
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.345345
# std        4.253062
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.500000
# max       48.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239] : 239
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766] : 766
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879] : 879
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        4.801000
# std         6.670524
# min         1.000000
# 25%         1.500000
# 50%         2.000000
# 75%         5.000000
# max        46.000000
# dtype: float64
# epoch took: 48.7383549213
#
# Epoch 29 ...
# Epoch  29 Update  1848 Cost  0.0345920696855
# Epoch  29 Update  1869 Cost  0.0392372980714
# Epoch  29 Update  1890 Cost  0.0204216353595
# Training error: 0.0357829034328
# Training_correct error 0.0366004817188
# Testing_correct error: 0.0494484007359
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426] : 426
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886] : 886
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957] : 957
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.897898
# std        4.603528
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       46.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290] : 290
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793] : 793
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875] : 875
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        5.596000
# std         9.861746
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        86.000000
# dtype: float64
# epoch took: 48.9504799843
#
# Epoch 30 ...
# Epoch  30 Update  1911 Cost  0.0358876697719
# Epoch  30 Update  1932 Cost  0.034554567188
# Epoch  30 Update  1953 Cost  0.0349995717406
# Training error: 0.033931940794
# Training_correct error 0.0362541563809
# Testing_correct error: 0.045201279223
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420] : 420
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912] : 912
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969] : 969
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.510511
# std        3.581871
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       65.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290] : 290
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810] : 810
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893] : 893
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        4.524000
# std         6.976395
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        62.000000
# dtype: float64
# epoch took: 49.0416247845
#
# Epoch 31 ...
# Epoch  31 Update  1974 Cost  0.0188236683607
# Epoch  31 Update  1995 Cost  0.0324405953288
# Epoch  31 Update  2016 Cost  0.0351068265736
# Training error: 0.0341457985342
# Training_correct error 0.037388574332
# Testing_correct error: 0.0550444424152
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437] : 437
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902] : 902
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966] : 966
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.173173
# std        6.846553
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       74.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302] : 302
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795] : 795
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884] : 884
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        6.820000
# std        15.057368
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       113.000000
# dtype: float64
# epoch took: 48.8438000679
#
# Epoch 32 ...
# Epoch  32 Update  2037 Cost  0.0197140984237
# Epoch  32 Update  2058 Cost  0.0404128469527
# Epoch  32 Update  2079 Cost  0.0363337732852
# Training error: 0.0400777868927
# Training_correct error 0.0407038629055
# Testing_correct error: 0.0435023233294
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345] : 345
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858] : 858
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944] : 944
# Discription of evaluation (ranking) for training data:
# count    999.00000
# mean       3.23023
# std        4.42433
# min        1.00000
# 25%        1.00000
# 50%        2.00000
# 75%        3.50000
# max       77.00000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265] : 265
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790] : 790
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887] : 887
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        4.762000
# std         7.138229
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.500000
# max        42.000000
# dtype: float64
# epoch took: 48.5661759377
#
# Epoch 33 ...
# Epoch  33 Update  2100 Cost  0.0225670337677
# Epoch  33 Update  2121 Cost  0.0422090739012
# Epoch  33 Update  2142 Cost  0.0197534430772
# Training error: 0.0357491523027
# Training_correct error 0.0343536958098
# Testing_correct error: 0.0373701564968
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395] : 395
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921] : 921
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982] : 982
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.395395
# std        2.664116
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       36.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295] : 295
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840] : 840
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919] : 919
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        3.757000
# std         4.943722
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        30.000000
# dtype: float64
# epoch took: 50.380546093
#
# Epoch 34 ...
# Epoch  34 Update  2163 Cost  0.0274707898498
# Epoch  34 Update  2184 Cost  0.0142586715519
# Epoch  34 Update  2205 Cost  0.0413485430181
# Training error: 0.0308684203774
# Training_correct error 0.0349571034312
# Testing_correct error: 0.0484385229647
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454] : 454
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931] : 931
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969] : 969
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.552553
# std        4.316103
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       41.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327] : 327
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822] : 822
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895] : 895
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        5.188000
# std         9.699523
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        81.000000
# dtype: float64
# epoch took: 48.7266769409
#
# Epoch 35 ...
# Epoch  35 Update  2226 Cost  0.0219029150903
# Epoch  35 Update  2247 Cost  0.0226015094668
# Epoch  35 Update  2268 Cost  0.0214089415967
# Training error: 0.0279977619648
# Training_correct error 0.0266631599516
# Testing_correct error: 0.0349534787238
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454, 500] : 500
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931, 944] : 944
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969, 981] : 981
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.123123
# std        2.839804
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       34.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327, 344] : 344
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822, 840] : 840
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895, 907] : 907
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        4.095000
# std         6.649225
# min         1.000000
# 25%         1.000000
# 50%         1.500000
# 75%         3.500000
# max        42.000000
# dtype: float64
# epoch took: 48.885571003
#
# Epoch 36 ...
# Epoch  36 Update  2289 Cost  0.0116978958249
# Epoch  36 Update  2310 Cost  0.0345799550414
# Epoch  36 Update  2331 Cost  0.0285079330206
# Training error: 0.0314490869641
# Training_correct error 0.0349974296987
# Testing_correct error: 0.0378754511476
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454, 500, 423] : 423
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931, 944, 931] : 931
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969, 981, 976] : 976
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.336336
# std        2.749657
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.500000
# max       43.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327, 344, 294] : 294
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822, 840, 820] : 820
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895, 907, 913] : 913
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        3.736000
# std         4.752567
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        38.000000
# dtype: float64
# epoch took: 48.8142700195
#
# Epoch 37 ...
# Epoch  37 Update  2352 Cost  0.0145929036662
# Epoch  37 Update  2373 Cost  0.0225160494447
# Epoch  37 Update  2394 Cost  0.0285577271134
# Training error: 0.0435521751642
# Training_correct error 0.04953674227
# Testing_correct error: 0.0480021797121
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454, 500, 423, 303] : 303
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931, 944, 931, 832] : 832
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969, 981, 976, 960] : 960
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       3.258258
# std        3.441156
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       46.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327, 344, 294, 227] : 227
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822, 840, 820, 772] : 772
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895, 907, 913, 918] : 918
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        4.225000
# std         4.697919
# min         1.000000
# 25%         1.500000
# 50%         2.500000
# 75%         5.000000
# max        37.000000
# dtype: float64
# epoch took: 49.220813036
#
# Epoch 38 ...
# Epoch  38 Update  2415 Cost  0.029201740399
# Epoch  38 Update  2436 Cost  0.0323530398309
# Epoch  38 Update  2457 Cost  0.0410589314997
# Training error: 0.0332983061671
# Training_correct error 0.036471247673
# Testing_correct error: 0.0384236089885
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454, 500, 423, 303, 424] : 424
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931, 944, 931, 832, 918] : 918
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969, 981, 976, 960, 981] : 981
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.400400
# std        2.663932
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.000000
# max       43.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327, 344, 294, 227, 301] : 301
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822, 840, 820, 772, 825] : 825
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895, 907, 913, 918, 922] : 922
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        3.652000
# std         4.525636
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        33.000000
# dtype: float64
# epoch took: 48.625797987
#
# Epoch 39 ...
# Epoch  39 Update  2478 Cost  0.0360216870904
# Epoch  39 Update  2499 Cost  0.0418747924268
# Epoch  39 Update  2520 Cost  0.0241149105132
# Training error: 0.0285047963262
# Training_correct error 0.0271630845964
# Testing_correct error: 0.0319587923586
# top- 1 = [3, 48, 50, 86, 76, 118, 93, 92, 202, 205, 225, 200, 161, 169, 186, 233, 259, 272, 263, 297, 274, 255, 212, 357, 337, 394, 399, 373, 397, 332, 426, 420, 437, 345, 395, 454, 500, 423, 303, 424, 473] : 473
# top- 5 = [21, 199, 208, 293, 310, 392, 359, 406, 515, 564, 610, 598, 536, 532, 595, 653, 714, 735, 749, 776, 778, 691, 669, 826, 827, 875, 867, 859, 841, 836, 886, 912, 902, 858, 921, 931, 944, 931, 832, 918, 945] : 945
# top- 10 = [30, 304, 320, 431, 411, 533, 495, 582, 690, 738, 736, 745, 698, 702, 716, 779, 831, 843, 864, 887, 881, 808, 815, 928, 909, 939, 940, 941, 934, 943, 957, 969, 966, 944, 982, 969, 981, 976, 960, 981, 992] : 992
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean       2.008008
# std        2.085938
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.000000
# max       27.000000
# dtype: float64
# top- 1 = [1, 46, 43, 81, 66, 92, 79, 80, 135, 156, 166, 148, 115, 127, 143, 162, 193, 194, 198, 225, 206, 170, 155, 239, 234, 274, 268, 269, 257, 239, 290, 290, 302, 265, 295, 327, 344, 294, 227, 301, 329] : 329
# top- 5 = [12, 151, 169, 246, 242, 285, 279, 306, 423, 468, 479, 475, 452, 485, 529, 530, 630, 636, 685, 701, 689, 616, 550, 741, 746, 783, 750, 777, 747, 766, 793, 810, 795, 790, 840, 822, 840, 820, 772, 825, 845] : 845
# top- 10 = [24, 232, 267, 378, 344, 455, 443, 470, 557, 596, 614, 605, 622, 672, 665, 698, 753, 802, 807, 817, 814, 751, 738, 846, 839, 872, 855, 853, 852, 879, 875, 893, 884, 887, 919, 895, 907, 913, 918, 922, 913] : 913
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean        3.608000
# std         4.799309
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.500000
# max        28.500000
# dtype: float64
# epoch took: 48.8241209984
# saving the model...
# Evaluate the model using fast estimation...
# count    999.000000
# mean       2.008008
# std        2.085938
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.000000
# max       27.000000
# dtype: float64
# count    1000.000000
# mean        3.608000
# std         4.799309
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.500000
# max        28.500000
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('MSE distribution')
plt.plot(sls.mse,'ro-', label="Training data (similarity = 1 + similarity = 2)")
plt.plot(sls.mse_train,'bo-', label="Training data (similarity = 1)")
plt.plot(sls.mse_test,'go-', label="Testing data (similarity = 1)")
plt.legend()

plt.ylabel('MSE')
plt.xlabel('Epoches Times')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.tops[1],'ro-', label = "TOP-1 @ Trianing data (similarity = 1)")
plt.plot(sls.tops[5],'bo-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot(sls.tops[10],'go-', label = "TOP-10 @ Trianing data (similarity = 1)")
plt.plot(sls.tops_test[1],'ro--', label = "TOP-1 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[5],'bo--', label = "TOP-5 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[10],'go--', label = "TOP-10 @ Test data (similarity = 1)")
plt.ylabel('Amount of documents belongs to top[1,5,10]')
plt.xlabel('Epoches')
plt.title('Tendancy of accuracy during training')
plt.legend(loc = 2)
plt.show()

# %%
sentences
