# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# ERROR (theano.sandbox.cuda): ERROR: Not using GPU. Initialisation of device 2 failed:
# initCnmem: cnmemInit call failed! Reason=CNMEM_STATUS_OUT_OF_MEMORY. numdev=1
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# NO Training. Load the existed model: weights/201611232246_e10_1k1k.p
# Evaluate the model using fast estimation...
# Finish preparing the data!
# Finished embedding,start projecting...
# Finish preparing the data!
# Finished embedding,start projecting...

# %%
a = pd.Series([1,2,3,4])

# %%
# Out:
# True

# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# ERROR (theano.sandbox.cuda): ERROR: Not using GPU. Initialisation of device 2 failed:
# initCnmem: cnmemInit call failed! Reason=CNMEM_STATUS_OUT_OF_MEMORY. numdev=1
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the modle..., saving to weights/201612131946_e10_1k1k.p
# Training
# the length of the training data is  1998
# (4.3990784, 0.094624788, 0.058451464087564922)
# Finish preparing the data!
# Finished embedding,start projecting...
# top_ [6] : 6
# Epoch 0
# Epoch  0 Update  40 Cost  0.159506469965
# epoch took: 57.1951508522
# (1.961805, 0.7666328, 0.7578090021788968)
# Finish preparing the data!
# ...

# %%
sls.top
# Out:
# [6, 137, 130, 219, 247, 294, 307, 341, 265, 452]

# %%
rank_results = sls.rank[9]

# %%
sum(rank_results)/len(rank_results)
# Out:
# 25.982965931863728

# %%
rank_results = sls.rank[9][0:999]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results,'ro')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
pd.Series(rank_results).describe()
# 精确度很低，虽然每次运行结果会不同，但是这个精度还是使用演示的方法低
# Out:
# count    999.000000
# mean      25.964464
# std       49.284037
# min        1.500000
# 25%        2.500000
# 50%        5.500000
# 75%       22.000000
# max      457.500000
# dtype: float64

# %%
rank_results
# Out:
# [7.5,
#  25.5,
#  1.5,
#  2.5,
#  2.5,
#  9.5,
#  1.5,
#  5.5,
#  81.5,
#  3.5,
#  4.5,
#  1.5,
#  13.5,
#  11.5,
#  12.5,
#  11.5,
#  7.5,
#  1.5,
#  2.5,
#  5.5,
#  1.5,
#  258.5,
#  9.5,
#  7.5,
#  1.5,
#  145.5,
#  1.5,
#  27.5,
#  123.5,
#  1.5,
#  9.5,
#  1.5,
#  5.5,
#  1.5,
#  8.5,
#  1.5,
#  1.5,
#  1.5,
#  5.5,
#  1.5,
#  1.5,
#  89.5,
#  1.5,
#  1.5,
#  258.5,
#  12.5,
#  1.5,
#  1.5,
#  31.5,
#  63.5,
#  1.5,
#  3.5,
#  103.5,
#  2.5,
#  77.5,
#  1.5,
#  1.5,
#  1.5,
#  3.5,
#  7.5,
#  7.5,
#  7.5,
#  1.5,
#  1.5,
#  21.5,
#  7.5,
#  457.5,
#  2.5,
#  6.5,
#  2.5,
#  1.5,
#  8.5,
#  129.5,
#  2.5,
#  3.5,
#  7.5,
#  3.5,
#  3.5,
#  5.5,
#  12.5,
#  10.5,
#  1.5,
#  1.5,
#  1.5,
#  2.5,
#  5.5,
#  12.5,
#  10.5,
#  4.5,
#  5.5,
#  1.5,
#  2.5,
#  3.5,
#  1.5,
#  15.5,
#  2.5,
#  22.5,
#  15.5,
#  157.5,
#  15.5,
#  55.5,
#  129.5,
#  1.5,
#  5.5,
#  221.5,
#  1.5,
#  1.5,
#  1.5,
#  1.5,
#  4.5,
#  1.5,
#  3.5,
#  2.5,
#  31.5,
#  1.5,
#  8.5,
#  1.5,
#  39.5,
#  11.5,
# ...
