# %%
for x in [1,2]:
    a = x*2

# %%
a
# Out:
# 4

# %%
run main.py
# Out:
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.257755994797 = 0.257755994797
# Training_correct error 0.337905704975
# Testing_correct error: 0.335038632154
# top- 1 = [] : 3
# top- 5 = [] : 21
# top- 10 = [] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
# top- 1 = [] : 1
# top- 5 = [] : 12
# top- 10 = [] : 24
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      551.164000
# std       260.994743
# min         1.000000
# 25%       362.625000
# 50%       559.000000
# 75%       775.500000
# max       985.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  40 Cost  0.112757906318
# ...

# %%
# 更改了cost输出的模式，变为所有的minibatch都要输出最后的cost数值

# %%
run main.py
# 【错误！没有重置ipython就运行了】运行结果是【错误】的！
# Out:
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.254455864429 = 0.254455864429 == 0.48718854785
# Training_correct error 0.252215772867
# Testing_correct error: 0.256864190102
# top- 1 = [3] : 3
# top- 5 = [21] : 21
# top- 10 = [36] : 36
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     471.223724
# std      297.328736
# min        1.000000
# 25%      195.000000
# 50%      476.500000
# 75%      750.750000
# max      974.000000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [18] : 18
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      514.562500
# std       284.146446
# min         1.000000
# 25%       275.000000
# 50%       562.000000
# 75%       759.500000
# max       983.000000
# dtype: float64
#
# Epoch 0 ...
# ...

# %%
run main.py
# 这里面的 Training error: 0.257755994797 = 0.257755994797 == 0.25775590539 ?? 0.190321952105
# 分别呆板了: cst【错误】, chkterr2(train)[0]/16【正确】, self.get_mse(train)【正确】, self.f_cost(emb1,mas1,emb2,mas2,y2)[chkterr2函数中]【错误】
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.257755994797 = 0.257755994797 == 0.25775590539 ?? 0.190321952105
# Training_correct error 0.337905704975
# Testing_correct error: 0.335038632154
# top- 1 = [3] : 3
# top- 5 = [21] : 21
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# ...

# %%
# 【注意】不要直接使用cst变量作为cost，因为这里的cst是最后一个batch的cost而已，不是全部的
#  print "Training error:", cst, "=", self.chkterr2(train)[0]/16, "==" #, self.get_mse(train)

# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.257755994797
# Training_correct error 0.337905704975
# Testing_correct error: 0.335038632154
# top- 1 = [3] : 3
# top- 5 = [21] : 21
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
# top- 1 = [1] : 1
# ...

# %%
print sls.mse
print sls.mse_train
print sls.mse_test
# Out:
# [0.25775599479675293, 0.12569260597229004, 0.11739553511142731, 0.098548665642738342, 0.099749788641929626, 0.086856238543987274, 0.089723870158195496, 0.092558808624744415, 0.076798923313617706, 0.064901687204837799, 0.061443060636520386, 0.06436581164598465, 0.067611575126647949, 0.068703196942806244, 0.06715952605009079, 0.055987522006034851, 0.052712526172399521, 0.0483071468770504, 0.04674573615193367, 0.044858593493700027, 0.044205173850059509]
# [0.33790570497512817, 0.11841221898794174, 0.095117062330245972, 0.10194417089223862, 0.08210378885269165, 0.10712100565433502, 0.07721845805644989, 0.075753249228000641, 0.073487959802150726, 0.072902500629425049, 0.069743543863296509, 0.07886747270822525, 0.068371333181858063, 0.072552591562271118, 0.068915128707885742, 0.055266018956899643, 0.067327015101909637, 0.051667541265487671, 0.049944315105676651, 0.050759386271238327, 0.042516600340604782]
# ...

# %%
# Out:
# 21

# %%
#【X不用】
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.mse,'ro-')
plt.plot(sls.mse_train,'bo-')
plt.plot(sls.mse_test,'go-')
# plt.plot(sls.tops_test[1],'ro--')
# plt.plot(sls.tops_test[5],'bo--')
# plt.plot(sls.tops_test[10],'go--')
plt.ylabel('Amount of documents belongs to @top*')
plt.xlabel('Epoches Times')
plt.show()

# %%
#【正确，使用！】
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('MSE distribution')
plt.plot(sls.mse,'ro-', label="Training data (similarity = 1 + similarity = 2)")
plt.plot(sls.mse_train,'bo-', label="Training data (similarity = 1)")
plt.plot(sls.mse_test,'go-', label="Testing data (similarity = 1)")
plt.legend()

plt.ylabel('MSE')
plt.xlabel('Epoches Times')
plt.show()

# %%
df_train_1
# Out:
#                                             en_article  \
# 0    u.s. commerce department seasonal adjust annua...
# 1    chinese budget smartphone maker xiaomi plan se...
# 2    samsung electronics co ltd fell more percent t...
# 3    fiat deal gain full control chrysler group llc...
# 4    fiat share jump thursday it strike deal gain f...
# 5    u.s. treasuries price rise thursday benchmark ...
# 6                       auction detail see 3-year note
# 7    brent crude sink barrel thursday libya prepare...
# 8    gauge u.s. factory activity hold 2-1/2-year hi...
# 9    work massive panama canal extension project ma...
# 10   increase december car sale france spain prompt...
# 11   federal reserve provide liquidity foreign cent...
# 12   new car sale spain rise percent year early car...
# 13   south korean auto maker hyundai motor co kia m...
# 14   u.s. manufacturing end year high note grow dec...
# 15   oil price fell more thursday libya prepare res...
# ...

# %%
train_2[0]
# Out:
# ['5 2 9 6 6 6 6 2 6 6',
# ...

# %%
train_1[0]
# Out:
# ['5 2 9 6 6 6 6 2 6 6', '1 8 2 3 9 7 2 9 7 2 9 7 2 9 7 2 8 2 9 7 2 9 7 2', 5.0]

# %%
train[0]
# Out:
# ['5 2 9 6 6 6 6 2 6 6', '1 8 2 3 9 7 2 9 7 2 9 7 2 9 7 2 8 2 9 7 2 9 7 2', 5.0]

# %%
train[999]
# Out:
# ['5 2 9 6 6 6 6 2 6 6',
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.tops[1],'ro-', label = "TOP-1 @ Trianing data (similarity = 1)")
plt.plot(sls.tops[5],'bo-', label = "TOP-5 @ Trianing data (similarity = 1)" )
plt.plot(sls.tops[10],'go-', label = "TOP-10 @ Trianing data (similarity = 1)")
plt.plot(sls.tops_test[1],'ro--', label = "TOP-1 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[5],'bo--', label = "TOP-5 @ Test data (similarity = 1)")
plt.plot(sls.tops_test[10],'go--', label = "TOP-10 @ Test data (similarity = 1)")
plt.ylabel('Amount of documents belongs to top[1,5,10]')
plt.xlabel('Epoches')
plt.title('Tendancy of accuracy during training')
plt.legend(loc = 2)
plt.show()
