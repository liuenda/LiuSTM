# %%
run baseline_proj.py
# Out:
# [INFO]Reading the word2vec vectors in  en  from  ./data_baseline/good_vecs_en.csv ---
# [INFO]Reading the word2vec vectors in  jp  from  ./data_baseline/good_vecs_jp.csv ---
# [DEBUG] inv(JTJ)*JTJ=I?:
# [DEBUG] [[  1.00000000e+00   1.91963307e-12   2.35026415e-12 ...,   5.48230575e-14
#    -2.53620143e-12  -7.09088496e-13]
#  [ -3.74589285e-12   1.00000000e+00   3.80477022e-13 ...,   9.39741479e-13
#    -3.94819303e-14  -5.11707022e-12]
#  [  4.28733291e-12   2.59181811e-12   1.00000000e+00 ...,  -3.91510958e-13
#    -1.27291775e-12  -4.87672564e-13]
#  ...,
#  [  2.31703545e-12   8.51610359e-13   6.83905426e-14 ...,   1.00000000e+00
#     2.60250195e-13   4.87370210e-13]
#  [  1.68333263e-12  -4.30644827e-13  -3.41771696e-12 ...,   5.35846248e-13
#     1.00000000e+00  -3.86998816e-13]
#  [ -1.53319589e-12   5.53895644e-13   1.69822493e-12 ...,  -4.54747351e-13
#    -1.36424205e-12   1.00000000e+00]]
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    998
# True       1
# Name: en_article, dtype: int64
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    998
# True       2
# Name: en_article, dtype: int64
# Now the maxlen = 0
# Starting to training the model..., saving to weights/proj/20170318_e1_1k1k_l0_b64.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.280861854553
# Training_correct error 0.445522964001
# Testing_correct error: 0.443236082792
# top- 1 = [1] : 1
# top- 5 = [6] : 6
# top- 10 = [21] : 21
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     415.203203
# std      310.029166
# min        1.000000
# 25%      121.000000
# 50%      352.000000
# 75%      689.000000
# max      998.000000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [11] : 11
# top- 10 = [23] : 23
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      402.072500
# std       313.619283
# min         1.000000
# 25%       135.875000
# 50%       315.500000
# 75%       718.250000
# max      1000.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.256454408169
# Epoch  0 Update  42 Cost  0.246713876724
# Epoch  0 Update  63 Cost  0.241447553039
# Training error: 0.227989479899
# Training_correct error 0.239750608802
# Testing_correct error: 0.272573053837
# top- 1 = [1, 8] : 8
# top- 5 = [6, 35] : 35
# top- 10 = [21, 64] : 64
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     289.056056
# std      272.736116
# min        1.000000
# 25%       65.000000
# 50%      193.000000
# 75%      460.000000
# max      998.000000
# dtype: float64
# top- 1 = [2, 3] : 3
# top- 5 = [11, 16] : 16
# top- 10 = [23, 25] : 25
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      293.217000
# std       246.597833
# min         1.000000
# 25%        79.750000
# 50%       227.500000
# 75%       414.750000
# max      1000.000000
# dtype: float64
# epoch took: 70.8041579723
#
# Epoch 1 ...
# Epoch  1 Update  84 Cost  0.195324525237
# Epoch  1 Update  105 Cost  0.206790566444
# Epoch  1 Update  126 Cost  0.18659029901
# Training error: 0.200127497315
# Training_correct error 0.261611759663
# Testing_correct error: 0.237942442298
# top- 1 = [1, 8, 12] : 12
# top- 5 = [6, 35, 51] : 51
# top- 10 = [21, 64, 88] : 88
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     214.683684
# std      226.420265
# min        1.000000
# 25%       42.000000
# 50%      119.500000
# 75%      315.000000
# max      983.000000
# dtype: float64
# top- 1 = [2, 3, 4] : 4
# top- 5 = [11, 16, 25] : 25
# top- 10 = [23, 25, 46] : 46
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      247.566000
# std       230.334397
# min         1.000000
# 25%        63.000000
# 50%       185.000000
# 75%       318.500000
# max       999.000000
# dtype: float64
# epoch took: 70.1129498482
#
# Epoch 2 ...
# Epoch  2 Update  147 Cost  0.205416440964
# Epoch  2 Update  168 Cost  0.174069046974
# Epoch  2 Update  189 Cost  0.168411538005
# Training error: 0.177951589227
# Training_correct error 0.189488351345
# Testing_correct error: 0.232533499599
# top- 1 = [1, 8, 12, 18] : 18
# top- 5 = [6, 35, 51, 78] : 78
# top- 10 = [21, 64, 88, 130] : 130
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     135.043544
# std      152.738369
# min        1.000000
# 25%       24.750000
# 50%       77.000000
# 75%      186.500000
# max      868.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6] : 6
# top- 5 = [11, 16, 25, 32] : 32
# top- 10 = [23, 25, 46, 62] : 62
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      183.849000
# std       152.336928
# min         1.000000
# 25%        61.500000
# 50%       185.000000
# 75%       296.250000
# max      1000.000000
# dtype: float64
# epoch took: 69.6962280273
#
# Epoch 3 ...
# Epoch  3 Update  210 Cost  0.179196447134
# Epoch  3 Update  231 Cost  0.181469902396
# Epoch  3 Update  252 Cost  0.153262346983
# Training error: 0.193386405706
# Training_correct error 0.186641335487
# Testing_correct error: 0.24859046936
# top- 1 = [1, 8, 12, 18, 15] : 15
# top- 5 = [6, 35, 51, 78, 87] : 87
# top- 10 = [21, 64, 88, 130, 143] : 143
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     180.352352
# std      217.628010
# min        1.000000
# 25%       25.000000
# 50%       94.000000
# 75%      246.500000
# max      972.500000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9] : 9
# top- 5 = [11, 16, 25, 32, 27] : 27
# top- 10 = [23, 25, 46, 62, 42] : 42
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      221.929000
# std       188.602232
# min         1.000000
# 25%        61.500000
# 50%       188.500000
# 75%       319.000000
# max      1000.000000
# dtype: float64
# epoch took: 82.2582550049
#
# Epoch 4 ...
# Epoch  4 Update  273 Cost  0.141640469432
# Epoch  4 Update  294 Cost  0.158228293061
# Epoch  4 Update  315 Cost  0.171135663986
# Training error: 0.150049164891
# Training_correct error 0.184397861362
# Testing_correct error: 0.186517760158
# top- 1 = [1, 8, 12, 18, 15, 18] : 18
# top- 5 = [6, 35, 51, 78, 87, 87] : 87
# top- 10 = [21, 64, 88, 130, 143, 145] : 145
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     100.725726
# std      118.906680
# min        1.000000
# 25%       22.500000
# 50%       58.500000
# 75%      129.500000
# max      835.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11] : 11
# top- 5 = [11, 16, 25, 32, 27, 53] : 53
# top- 10 = [23, 25, 46, 62, 42, 80] : 80
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      152.498000
# std       138.284003
# min         1.000000
# 25%        52.500000
# 50%       110.750000
# 75%       201.125000
# max       891.000000
# dtype: float64
# epoch took: 70.6851229668
#
# Epoch 5 ...
# Epoch  5 Update  336 Cost  0.123011618853
# Epoch  5 Update  357 Cost  0.148150742054
# Epoch  5 Update  378 Cost  0.139541193843
# Training error: 0.14014621079
# Training_correct error 0.166378542781
# Testing_correct error: 0.168950423598
# top- 1 = [1, 8, 12, 18, 15, 18, 16] : 16
# top- 5 = [6, 35, 51, 78, 87, 87, 100] : 100
# top- 10 = [21, 64, 88, 130, 143, 145, 178] : 178
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      86.813814
# std      106.865086
# min        1.000000
# 25%       17.000000
# 50%       51.000000
# 75%      111.000000
# max      770.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12] : 12
# top- 5 = [11, 16, 25, 32, 27, 53, 65] : 65
# top- 10 = [23, 25, 46, 62, 42, 80, 94] : 94
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      145.341000
# std       133.101321
# min         1.000000
# 25%        49.000000
# 50%        96.000000
# 75%       195.000000
# max      1000.000000
# dtype: float64
# epoch took: 73.0522320271
#
# Epoch 6 ...
# Epoch  6 Update  399 Cost  0.136477530003
# Epoch  6 Update  420 Cost  0.185572713614
# Epoch  6 Update  441 Cost  0.0751258358359
# Training error: 0.136238142848
# Training_correct error 0.192945614457
# Testing_correct error: 0.214860573411
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20] : 20
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118] : 118
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182] : 182
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      79.392392
# std       99.718030
# min        1.000000
# 25%       15.000000
# 50%       42.000000
# 75%      105.500000
# max      704.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16] : 16
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57] : 57
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109] : 109
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      142.490000
# std       136.793503
# min         1.000000
# 25%        36.375000
# 50%        82.250000
# 75%       205.625000
# max       785.000000
# dtype: float64
# epoch took: 68.8459551334
#
# Epoch 7 ...
# Epoch  7 Update  462 Cost  0.121896058321
# Epoch  7 Update  483 Cost  0.135054498911
# Epoch  7 Update  504 Cost  0.29111006856
# Training error: 0.134758472443
# Training_correct error 0.191691353917
# Testing_correct error: 0.214598536491
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15] : 15
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100] : 100
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189] : 189
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      77.100100
# std       95.798312
# min        1.000000
# 25%       16.000000
# 50%       44.000000
# 75%      105.500000
# max      708.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11] : 11
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61] : 61
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100] : 100
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      137.846000
# std       127.002559
# min         1.000000
# 25%        39.000000
# 50%        81.000000
# 75%       196.500000
# max       606.000000
# dtype: float64
# epoch took: 69.9945838451
#
# Epoch 8 ...
# Epoch  8 Update  525 Cost  0.0970319062471
# Epoch  8 Update  546 Cost  0.158301413059
# Epoch  8 Update  567 Cost  0.194774985313
# Training error: 0.128158926964
# Training_correct error 0.149362638593
# Testing_correct error: 0.168817430735
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24] : 24
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128] : 128
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186] : 186
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      75.111111
# std       93.401286
# min        1.000000
# 25%       16.000000
# 50%       45.000000
# 75%      103.750000
# max      648.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13] : 13
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62] : 62
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110] : 110
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      136.545000
# std       124.581023
# min         1.000000
# 25%        38.875000
# 50%        82.750000
# 75%       196.000000
# max       771.000000
# dtype: float64
# epoch took: 70.027531147
#
# Epoch 9 ...
# Epoch  9 Update  588 Cost  0.150405466557
# Epoch  9 Update  609 Cost  0.0935509800911
# Epoch  9 Update  630 Cost  0.137741580606
# Training error: 0.121483296156
# Training_correct error 0.169310316443
# Testing_correct error: 0.176805272698
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20] : 20
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123] : 123
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194] : 194
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      68.313313
# std       80.373445
# min        1.000000
# 25%       15.000000
# 50%       44.000000
# 75%       93.000000
# max      643.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14] : 14
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68] : 68
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97] : 97
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      126.570000
# std       118.868991
# min         1.000000
# 25%        36.000000
# 50%        69.000000
# 75%       191.500000
# max       723.000000
# dtype: float64
# epoch took: 70.2302951813
#
# Epoch 10 ...
# Epoch  10 Update  651 Cost  0.137834131718
# Epoch  10 Update  672 Cost  0.0977329313755
# Epoch  10 Update  693 Cost  0.115993499756
# Training error: 0.108761824667
# Training_correct error 0.136475712061
# Testing_correct error: 0.162888050079
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31] : 31
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168] : 168
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254] : 254
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      50.840841
# std       59.595116
# min        1.000000
# 25%       10.000000
# 50%       30.500000
# 75%       67.000000
# max      432.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15] : 15
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68] : 68
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129] : 129
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      122.953000
# std       116.559474
# min         1.000000
# 25%        27.750000
# 50%        66.500000
# 75%       195.000000
# max       596.000000
# dtype: float64
# epoch took: 71.8421258926
#
# Epoch 11 ...
# Epoch  11 Update  714 Cost  0.118302196264
# Epoch  11 Update  735 Cost  0.139529198408
# Epoch  11 Update  756 Cost  0.0884041115642
# Training error: 0.115007296205
# Training_correct error 0.14905372262
# Testing_correct error: 0.165336608887
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25] : 25
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114] : 114
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197] : 197
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      61.781782
# std       72.939954
# min        1.000000
# 25%       14.000000
# 50%       37.000000
# 75%       82.000000
# max      553.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14] : 14
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64] : 64
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111] : 111
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      124.224000
# std       116.472244
# min         1.000000
# 25%        32.000000
# 50%        68.500000
# 75%       195.000000
# max       659.500000
# dtype: float64
# epoch took: 72.7458970547
#
# Epoch 12 ...
# Epoch  12 Update  777 Cost  0.0835647508502
# Epoch  12 Update  798 Cost  0.118450835347
# Epoch  12 Update  819 Cost  0.071553774178
# Training error: 0.104687675834
# Training_correct error 0.129083365202
# Testing_correct error: 0.154246777296
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29] : 29
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149] : 149
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248] : 248
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      51.746747
# std       61.095460
# min        1.000000
# 25%       10.500000
# 50%       28.500000
# 75%       69.250000
# max      545.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16] : 16
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71] : 71
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130] : 130
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      122.692000
# std       124.342459
# min         1.000000
# 25%        26.000000
# 50%        66.500000
# 75%       195.000000
# max       761.500000
# dtype: float64
# epoch took: 70.5219779015
#
# Epoch 13 ...
# Epoch  13 Update  840 Cost  0.0743427723646
# Epoch  13 Update  861 Cost  0.0919991582632
# Epoch  13 Update  882 Cost  0.108150601387
# Training error: 0.0986956954002
# Training_correct error 0.114626407623
# Testing_correct error: 0.148491472006
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34] : 34
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182] : 182
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272] : 272
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      46.345345
# std       55.592282
# min        1.000000
# 25%        9.250000
# 50%       24.500000
# 75%       67.000000
# max      423.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12] : 12
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79] : 79
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132] : 132
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      119.030000
# std       112.226708
# min         1.000000
# 25%        25.500000
# 50%        71.250000
# 75%       186.500000
# max       558.000000
# dtype: float64
# epoch took: 81.4317579269
#
# Epoch 14 ...
# Epoch  14 Update  903 Cost  0.150131970644
# Epoch  14 Update  924 Cost  0.124181523919
# Epoch  14 Update  945 Cost  0.113483428955
# Training error: 0.115675099194
# Training_correct error 0.157021820545
# Testing_correct error: 0.167802110314
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28] : 28
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152] : 152
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243] : 243
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      70.654655
# std      103.444916
# min        1.000000
# 25%       11.000000
# 50%       32.000000
# 75%       81.000000
# max      757.500000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15] : 15
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81] : 81
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136] : 136
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      130.220000
# std       129.249701
# min         1.000000
# 25%        26.000000
# 50%        66.500000
# 75%       195.000000
# max       829.000000
# dtype: float64
# epoch took: 74.8047020435
#
# Epoch 15 ...
# Epoch  15 Update  966 Cost  0.107322044671
# Epoch  15 Update  987 Cost  0.102528765798
# Epoch  15 Update  1008 Cost  0.143994227052
# Training error: 0.109110713005
# Training_correct error 0.131210312247
# Testing_correct error: 0.165755733848
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31] : 31
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159] : 159
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254] : 254
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      60.357357
# std       73.812757
# min        1.000000
# 25%       10.000000
# 50%       32.000000
# 75%       80.000000
# max      476.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69] : 69
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120] : 120
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      125.545000
# std       110.942215
# min         1.000000
# 25%        33.875000
# 50%        82.750000
# 75%       193.500000
# max       566.000000
# dtype: float64
# epoch took: 71.2834479809
#
# Epoch 16 ...
# Epoch  16 Update  1029 Cost  0.137137189507
# Epoch  16 Update  1050 Cost  0.122027769685
# Epoch  16 Update  1071 Cost  0.164451360703
# Training error: 0.117600075901
# Training_correct error 0.155385091901
# Testing_correct error: 0.159348279238
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31] : 31
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143] : 143
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224] : 224
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      68.903904
# std       85.669284
# min        1.000000
# 25%       12.250000
# 50%       36.000000
# 75%       98.500000
# max      608.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17] : 17
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84] : 84
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149] : 149
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      124.833000
# std       128.582404
# min         1.000000
# 25%        24.500000
# 50%        66.500000
# 75%       195.000000
# max       766.000000
# dtype: float64
# epoch took: 70.4697139263
#
# Epoch 17 ...
# Epoch  17 Update  1092 Cost  0.0860901474953
# Epoch  17 Update  1113 Cost  0.122048996389
# Epoch  17 Update  1134 Cost  0.133961170912
# Training error: 0.0965646877885
# Training_correct error 0.115799956024
# Testing_correct error: 0.164475083351
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41] : 41
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190] : 190
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302] : 302
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      42.626627
# std       50.571362
# min        1.000000
# 25%        8.000000
# 50%       22.500000
# 75%       61.500000
# max      357.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14] : 14
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76] : 76
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134] : 134
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      117.795000
# std       113.975073
# min         1.000000
# 25%        26.375000
# 50%        66.500000
# 75%       193.500000
# max       552.000000
# dtype: float64
# epoch took: 68.54165411
#
# Epoch 18 ...
# Epoch  18 Update  1155 Cost  0.0672014206648
# Epoch  18 Update  1176 Cost  0.0771205425262
# Epoch  18 Update  1197 Cost  0.0651026591659
# Training error: 0.0981213897467
# Training_correct error 0.111289769411
# Testing_correct error: 0.149227485061
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44] : 44
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165] : 165
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258] : 258
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      50.291291
# std       61.259078
# min        1.000000
# 25%       10.000000
# 50%       29.000000
# 75%       68.750000
# max      427.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20] : 20
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69] : 69
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123] : 123
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      120.004000
# std       110.217203
# min         1.000000
# 25%        30.000000
# 50%        68.750000
# 75%       195.000000
# max       545.000000
# dtype: float64
# epoch took: 70.0161979198
#
# Epoch 19 ...
# Epoch  19 Update  1218 Cost  0.0750693678856
# Epoch  19 Update  1239 Cost  0.118550427258
# Epoch  19 Update  1260 Cost  0.146024778485
# Training error: 0.10645943135
# Training_correct error 0.138506606221
# Testing_correct error: 0.159716144204
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32] : 32
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153] : 153
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232] : 232
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      54.728729
# std       67.232991
# min        1.000000
# 25%       11.250000
# 50%       30.000000
# 75%       74.500000
# max      555.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78] : 78
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135] : 135
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      127.52700
# std       131.19174
# min         1.00000
# 25%        24.50000
# 50%        66.00000
# 75%       194.50000
# max       713.00000
# dtype: float64
# epoch took: 70.4499208927
#
# Epoch 20 ...
# Epoch  20 Update  1281 Cost  0.131636589766
# Epoch  20 Update  1302 Cost  0.0922799408436
# Epoch  20 Update  1323 Cost  0.0850325077772
# Training error: 0.0953033715487
# Training_correct error 0.123933702707
# Testing_correct error: 0.175993651152
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39] : 39
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187] : 187
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287] : 287
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      42.855856
# std       51.984055
# min        1.000000
# 25%        8.000000
# 50%       24.500000
# 75%       61.000000
# max      502.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86] : 86
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135] : 135
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      120.678000
# std       116.311907
# min         1.000000
# 25%        26.000000
# 50%        68.500000
# 75%       191.500000
# max       687.000000
# dtype: float64
# epoch took: 69.7532150745
#
# Epoch 21 ...
# Epoch  21 Update  1344 Cost  0.116074711084
# Epoch  21 Update  1365 Cost  0.0807209163904
# Epoch  21 Update  1386 Cost  0.0979518517852
# Training error: 0.0864329785109
# Training_correct error 0.100591547787
# Testing_correct error: 0.143392726779
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53] : 53
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207] : 207
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329] : 329
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      38.724725
# std       46.740428
# min        1.000000
# 25%        6.500000
# 50%       22.500000
# 75%       55.750000
# max      389.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17] : 17
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79] : 79
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132] : 132
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      117.224000
# std       112.331484
# min         1.000000
# 25%        24.000000
# 50%        63.000000
# 75%       191.500000
# max       559.000000
# dtype: float64
# epoch took: 67.9969389439
#
# Epoch 22 ...
# Epoch  22 Update  1407 Cost  0.100177779794
# Epoch  22 Update  1428 Cost  0.0770055428147
# Epoch  22 Update  1449 Cost  0.0779288485646
# Training error: 0.0901376083493
# Training_correct error 0.111922048032
# Testing_correct error: 0.14604434371
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33] : 33
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165] : 165
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254] : 254
# Discription of evaluation (ranking) for training data:
# count    999.00000
# mean      44.36036
# std       50.89680
# min        1.00000
# 25%       10.00000
# 50%       26.00000
# 75%       63.00000
# max      514.00000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18] : 18
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70] : 70
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122] : 122
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      118.63000
# std       113.91705
# min         1.00000
# 25%        29.00000
# 50%        66.00000
# 75%       191.50000
# max       546.00000
# dtype: float64
# epoch took: 78.6144309044
#
# Epoch 23 ...
# Epoch  23 Update  1470 Cost  0.0891384035349
# Epoch  23 Update  1491 Cost  0.0947560593486
# Epoch  23 Update  1512 Cost  0.12107013166
# Training error: 0.0901369526982
# Training_correct error 0.102023243904
# Testing_correct error: 0.148331403732
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47] : 47
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209] : 209
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302] : 302
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      43.969970
# std       53.844904
# min        1.000000
# 25%        7.000000
# 50%       22.500000
# 75%       63.000000
# max      490.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75] : 75
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135] : 135
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      119.924000
# std       111.955001
# min         1.000000
# 25%        27.375000
# 50%        70.500000
# 75%       191.500000
# max       537.000000
# dtype: float64
# epoch took: 75.0918381214
#
# Epoch 24 ...
# Epoch  24 Update  1533 Cost  0.0930069535971
# Epoch  24 Update  1554 Cost  0.0859850794077
# Epoch  24 Update  1575 Cost  0.0598453469574
# Training error: 0.0818066671491
# Training_correct error 0.0938447937369
# Testing_correct error: 0.1404812783
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43] : 43
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220] : 220
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328] : 328
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      36.694695
# std       43.567616
# min        1.000000
# 25%        6.500000
# 50%       22.000000
# 75%       54.000000
# max      369.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20] : 20
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87] : 87
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136] : 136
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      117.267000
# std       113.595381
# min         1.000000
# 25%        25.000000
# 50%        66.500000
# 75%       191.500000
# max       509.000000
# dtype: float64
# epoch took: 69.4889709949
#
# Epoch 25 ...
# Epoch  25 Update  1596 Cost  0.0532587356865
# Epoch  25 Update  1617 Cost  0.0844791382551
# Epoch  25 Update  1638 Cost  0.100602038205
# Training error: 0.0906613618135
# Training_correct error 0.110553592443
# Testing_correct error: 0.154500469565
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35] : 35
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171] : 171
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278] : 278
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      45.791792
# std       56.257297
# min        1.000000
# 25%        9.000000
# 50%       25.000000
# 75%       63.000000
# max      480.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18] : 18
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72] : 72
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119] : 119
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      117.134000
# std       109.255667
# min         1.000000
# 25%        30.000000
# 50%        66.500000
# 75%       186.500000
# max       514.000000
# dtype: float64
# epoch took: 68.6939041615
#
# Epoch 26 ...
# Epoch  26 Update  1659 Cost  0.0665809363127
# Epoch  26 Update  1680 Cost  0.144254818559
# Epoch  26 Update  1701 Cost  0.0689973980188
# Training error: 0.081662222743
# Training_correct error 0.097406052053
# Testing_correct error: 0.141499102116
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49] : 49
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208] : 208
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330] : 330
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      37.573574
# std       46.785747
# min        1.000000
# 25%        7.000000
# 50%       22.500000
# 75%       53.250000
# max      466.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77] : 77
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122] : 122
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      119.068000
# std       115.861829
# min         1.000000
# 25%        25.000000
# 50%        63.500000
# 75%       191.500000
# max       687.500000
# dtype: float64
# epoch took: 68.1231508255
#
# Epoch 27 ...
# Epoch  27 Update  1722 Cost  0.0589478239417
# Epoch  27 Update  1743 Cost  0.0622145608068
# Epoch  27 Update  1764 Cost  0.0611233897507
# Training error: 0.086345911026
# Training_correct error 0.10411927104
# Testing_correct error: 0.146215364337
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59] : 59
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206] : 206
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305] : 305
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      41.268268
# std       50.609899
# min        1.000000
# 25%        7.000000
# 50%       24.500000
# 75%       59.500000
# max      475.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76] : 76
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127] : 127
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      120.880000
# std       116.970974
# min         1.000000
# 25%        27.875000
# 50%        66.500000
# 75%       188.500000
# max       722.500000
# dtype: float64
# epoch took: 74.8392798901
#
# Epoch 28 ...
# Epoch  28 Update  1785 Cost  0.120800085366
# Epoch  28 Update  1806 Cost  0.0640349462628
# Epoch  28 Update  1827 Cost  0.084812246263
# Training error: 0.0819372311234
# Training_correct error 0.0967820361257
# Testing_correct error: 0.141911685467
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41] : 41
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194] : 194
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312] : 312
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      40.570571
# std       49.466794
# min        1.000000
# 25%        7.500000
# 50%       24.000000
# 75%       60.000000
# max      603.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16] : 16
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71] : 71
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123] : 123
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      117.49000
# std       110.46371
# min         1.00000
# 25%        28.00000
# 50%        67.50000
# 75%       191.50000
# max       544.00000
# dtype: float64
# epoch took: 70.1242229939
#
# Epoch 29 ...
# Epoch  29 Update  1848 Cost  0.0967784151435
# Epoch  29 Update  1869 Cost  0.0519707649946
# Epoch  29 Update  1890 Cost  0.168949633837
# Training error: 0.0913934335113
# Training_correct error 0.11187402159
# Testing_correct error: 0.148842543364
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32] : 32
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165] : 165
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262] : 262
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      50.074074
# std       59.458862
# min        1.000000
# 25%       10.000000
# 50%       26.000000
# 75%       70.500000
# max      490.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10] : 10
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70] : 70
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111] : 111
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      123.293000
# std       113.253757
# min         1.000000
# 25%        32.000000
# 50%        68.250000
# 75%       191.500000
# max       603.000000
# dtype: float64
# epoch took: 68.6660661697
#
# Epoch 30 ...
# Epoch  30 Update  1911 Cost  0.0885039493442
# Epoch  30 Update  1932 Cost  0.065289594233
# Epoch  30 Update  1953 Cost  0.0460389517248
# Training error: 0.0780196785927
# Training_correct error 0.0949650332332
# Testing_correct error: 0.151769772172
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60] : 60
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235] : 235
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362] : 362
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      36.020020
# std       44.999094
# min        1.000000
# 25%        6.000000
# 50%       20.000000
# 75%       51.000000
# max      359.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76] : 76
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115] : 115
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      116.514000
# std       109.348017
# min         1.000000
# 25%        26.875000
# 50%        66.500000
# 75%       191.500000
# max       508.000000
# dtype: float64
# epoch took: 69.5080471039
#
# Epoch 31 ...
# Epoch  31 Update  1974 Cost  0.107172429562
# Epoch  31 Update  1995 Cost  0.0700915753841
# Epoch  31 Update  2016 Cost  0.05521934852
# Training error: 0.0845014154911
# Training_correct error 0.0968842059374
# Testing_correct error: 0.141024976969
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36] : 36
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174] : 174
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292] : 292
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      42.118118
# std       52.222902
# min        1.000000
# 25%        8.250000
# 50%       24.500000
# 75%       60.500000
# max      541.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17] : 17
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67] : 67
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123] : 123
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      120.01600
# std       112.84727
# min         1.00000
# 25%        29.00000
# 50%        66.50000
# 75%       189.25000
# max       548.00000
# dtype: float64
# epoch took: 70.0422239304
#
# Epoch 32 ...
# Epoch  32 Update  2037 Cost  0.114217147231
# Epoch  32 Update  2058 Cost  0.0639609843493
# Epoch  32 Update  2079 Cost  0.0631319358945
# Training error: 0.07503695786
# Training_correct error 0.0846165120602
# Testing_correct error: 0.140762269497
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51] : 51
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230] : 230
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380] : 380
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      33.501502
# std       41.706530
# min        1.000000
# 25%        6.000000
# 50%       18.000000
# 75%       47.000000
# max      419.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17] : 17
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70] : 70
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127] : 127
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      118.09300
# std       112.44785
# min         1.00000
# 25%        27.00000
# 50%        63.00000
# 75%       188.50000
# max       530.50000
# dtype: float64
# epoch took: 69.4121069908
#
# Epoch 33 ...
# Epoch  33 Update  2100 Cost  0.0701021403074
# Epoch  33 Update  2121 Cost  0.116260707378
# Epoch  33 Update  2142 Cost  0.113506391644
# Training error: 0.0791012272239
# Training_correct error 0.0870383307338
# Testing_correct error: 0.137253969908
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36] : 36
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217] : 217
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336] : 336
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      34.560561
# std       41.972950
# min        1.000000
# 25%        6.500000
# 50%       21.000000
# 75%       50.000000
# max      443.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16] : 16
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76] : 76
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128] : 128
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      116.389000
# std       112.279581
# min         1.000000
# 25%        25.750000
# 50%        66.500000
# 75%       188.500000
# max       609.500000
# dtype: float64
# epoch took: 69.7623410225
#
# Epoch 34 ...
# Epoch  34 Update  2163 Cost  0.0898129120469
# Epoch  34 Update  2184 Cost  0.0690591484308
# Epoch  34 Update  2205 Cost  0.0434891097248
# Training error: 0.0787267535925
# Training_correct error 0.0872207656503
# Testing_correct error: 0.137096613646
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51] : 51
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213] : 213
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336] : 336
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      36.426426
# std       45.700146
# min        1.000000
# 25%        6.500000
# 50%       21.000000
# 75%       50.250000
# max      430.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21] : 21
# ...
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      33.384384
# std       39.322129
# min        1.000000
# 25%        6.000000
# 50%       20.000000
# 75%       48.250000
# max      359.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22] : 22
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79] : 79
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122] : 122
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      116.563000
# std       112.254805
# min         1.000000
# 25%        28.000000
# 50%        66.500000
# 75%       188.500000
# max       557.000000
# dtype: float64
# epoch took: 68.6060991287
#
# Epoch 43 ...
# Epoch  43 Update  2730 Cost  0.0375153906643
# Epoch  43 Update  2751 Cost  0.0899803638458
# Epoch  43 Update  2772 Cost  0.0488105453551
# Training error: 0.0688997134566
# Training_correct error 0.0785378441215
# Testing_correct error: 0.137998908758
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61] : 61
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263] : 263
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396] : 396
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      31.463463
# std       42.406852
# min        1.000000
# 25%        5.000000
# 50%       17.000000
# 75%       43.000000
# max      426.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18] : 18
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80] : 80
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140] : 140
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      116.925000
# std       113.006694
# min         1.000000
# 25%        25.875000
# 50%        66.500000
# 75%       188.500000
# max       624.000000
# dtype: float64
# epoch took: 69.0398209095
#
# Epoch 44 ...
# Epoch  44 Update  2793 Cost  0.0580564141273
# Epoch  44 Update  2814 Cost  0.077725186944
# Epoch  44 Update  2835 Cost  0.0467644706368
# Training error: 0.0685729905963
# Training_correct error 0.0746569186449
# Testing_correct error: 0.137655153871
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65] : 65
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272] : 272
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409] : 409
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      29.857858
# std       39.930273
# min        1.000000
# 25%        5.000000
# 50%       15.000000
# 75%       39.000000
# max      429.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16] : 16
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77] : 77
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118] : 118
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      114.909000
# std       108.841142
# min         1.000000
# 25%        23.000000
# 50%        66.500000
# 75%       195.000000
# max       498.000000
# dtype: float64
# epoch took: 69.9280259609
#
# Epoch 45 ...
# Epoch  45 Update  2856 Cost  0.0607965290546
# Epoch  45 Update  2877 Cost  0.109135329723
# Epoch  45 Update  2898 Cost  0.119630135596
# Training error: 0.071922250092
# Training_correct error 0.0807580798864
# Testing_correct error: 0.140240728855
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65, 56] : 56
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272, 248] : 248
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409, 382] : 382
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      32.149149
# std       42.069901
# min        1.000000
# 25%        5.500000
# 50%       17.000000
# 75%       43.750000
# max      460.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16, 19] : 19
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77, 84] : 84
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118, 139] : 139
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      116.414000
# std       110.493001
# min         1.000000
# 25%        26.000000
# 50%        64.000000
# 75%       188.500000
# max       516.000000
# dtype: float64
# epoch took: 69.3780789375
#
# Epoch 46 ...
# Epoch  46 Update  2919 Cost  0.0975152254105
# Epoch  46 Update  2940 Cost  0.0793089717627
# Epoch  46 Update  2961 Cost  0.0515656284988
# Training error: 0.0662823319435
# Training_correct error 0.0748188495636
# Testing_correct error: 0.137359291315
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65, 56, 62] : 62
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272, 248, 276] : 276
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409, 382, 419] : 419
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      27.911912
# std       37.408382
# min        1.000000
# 25%        5.000000
# 50%       14.500000
# 75%       33.000000
# max      364.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16, 19, 23] : 23
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77, 84, 90] : 90
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118, 139, 143] : 143
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      113.004000
# std       110.586968
# min         1.000000
# 25%        24.875000
# 50%        63.250000
# 75%       185.375000
# max       531.000000
# dtype: float64
# epoch took: 71.2236740589
#
# Epoch 47 ...
# Epoch  47 Update  2982 Cost  0.0676066055894
# Epoch  47 Update  3003 Cost  0.0769854336977
# Epoch  47 Update  3024 Cost  0.153812542558
# Training error: 0.067921794951
# Training_correct error 0.0856532454491
# Testing_correct error: 0.148503050208
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65, 56, 62, 60] : 60
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272, 248, 276, 267] : 267
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409, 382, 419, 398] : 398
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      30.070070
# std       38.722926
# min        1.000000
# 25%        5.000000
# 50%       16.000000
# 75%       38.000000
# max      344.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16, 19, 23, 21] : 21
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77, 84, 90, 78] : 78
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118, 139, 143, 129] : 129
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      115.687000
# std       111.304585
# min         1.000000
# 25%        25.500000
# 50%        64.250000
# 75%       191.500000
# max       501.000000
# dtype: float64
# epoch took: 75.2877240181
#
# Epoch 48 ...
# Epoch  48 Update  3045 Cost  0.0599497258663
# Epoch  48 Update  3066 Cost  0.0841865539551
# Epoch  48 Update  3087 Cost  0.0440962128341
# Training error: 0.0667372569442
# Training_correct error 0.0754088461399
# Testing_correct error: 0.137290179729
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65, 56, 62, 60, 56] : 56
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272, 248, 276, 267, 270] : 270
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409, 382, 419, 398, 410] : 410
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      28.846847
# std       38.436341
# min        1.000000
# 25%        5.000000
# 50%       15.500000
# 75%       37.000000
# max      423.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16, 19, 23, 21, 20] : 20
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77, 84, 90, 78, 79] : 79
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118, 139, 143, 129, 135] : 135
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      114.272000
# std       109.320858
# min         1.000000
# 25%        24.000000
# 50%        66.500000
# 75%       191.500000
# max       492.000000
# dtype: float64
# epoch took: 73.8483760357
#
# Epoch 49 ...
# Epoch  49 Update  3108 Cost  0.0777634158731
# Epoch  49 Update  3129 Cost  0.0822257697582
# Epoch  49 Update  3150 Cost  0.0699865818024
# Training error: 0.0684950053692
# Training_correct error 0.0764673501253
# Testing_correct error: 0.136687621474
# top- 1 = [1, 8, 12, 18, 15, 18, 16, 20, 15, 24, 20, 31, 25, 29, 34, 28, 31, 31, 41, 44, 32, 39, 53, 33, 47, 43, 35, 49, 59, 41, 32, 60, 36, 51, 36, 51, 45, 60, 58, 47, 55, 62, 55, 59, 61, 65, 56, 62, 60, 56, 51] : 51
# top- 5 = [6, 35, 51, 78, 87, 87, 100, 118, 100, 128, 123, 168, 114, 149, 182, 152, 159, 143, 190, 165, 153, 187, 207, 165, 209, 220, 171, 208, 206, 194, 165, 235, 174, 230, 217, 213, 186, 258, 244, 246, 265, 274, 217, 231, 263, 272, 248, 276, 267, 270, 265] : 265
# top- 10 = [21, 64, 88, 130, 143, 145, 178, 182, 189, 186, 194, 254, 197, 248, 272, 243, 254, 224, 302, 258, 232, 287, 329, 254, 302, 328, 278, 330, 305, 312, 262, 362, 292, 380, 336, 336, 297, 377, 362, 388, 388, 406, 335, 344, 396, 409, 382, 419, 398, 410, 404] : 404
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean      30.174174
# std       39.208408
# min        1.000000
# 25%        5.000000
# 50%       16.500000
# 75%       40.000000
# max      356.000000
# dtype: float64
# top- 1 = [2, 3, 4, 6, 9, 11, 12, 16, 11, 13, 14, 15, 14, 16, 12, 15, 19, 17, 14, 20, 19, 19, 17, 18, 19, 20, 18, 19, 19, 16, 10, 19, 17, 17, 16, 21, 18, 15, 18, 17, 19, 20, 15, 22, 18, 16, 19, 23, 21, 20, 21] : 21
# top- 5 = [11, 16, 25, 32, 27, 53, 65, 57, 61, 62, 68, 68, 64, 71, 79, 81, 69, 84, 76, 69, 78, 86, 79, 70, 75, 87, 72, 77, 76, 71, 70, 76, 67, 70, 76, 86, 71, 76, 81, 81, 80, 87, 75, 79, 80, 77, 84, 90, 78, 79, 77] : 77
# top- 10 = [23, 25, 46, 62, 42, 80, 94, 109, 100, 110, 97, 129, 111, 130, 132, 136, 120, 149, 134, 123, 135, 135, 132, 122, 135, 136, 119, 122, 127, 123, 111, 115, 123, 127, 128, 131, 113, 139, 134, 135, 145, 143, 117, 122, 140, 118, 139, 143, 129, 135, 134] : 134
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      114.087000
# std       110.291721
# min         1.000000
# 25%        24.000000
# 50%        65.000000
# 75%       188.500000
# max       532.000000
# dtype: float64
# epoch took: 70.895157814
# saving the model...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(sls.tops[1],'r-', label = "TOP-1: Trianing")
plt.plot(sls.tops[5],'b-', label = "TOP-5: Trianing" )
plt.plot(sls.tops[10],'g-', label = "TOP-10: Trianing")
plt.plot(sls.tops_test[1],'r--', label = "TOP-1: Test")
plt.plot(sls.tops_test[5],'b--', label = "TOP-5: Test")
plt.plot(sls.tops_test[10],'g--', label = "TOP10: Test")
plt.ylabel('TOP Accuracy', fontsize=11)
plt.xlabel('Epoches', fontsize=11)
plt.title('TOP Accuracy vs Epoches')
plt.legend(loc = 2, fontsize=8)
plt.savefig('top1-5-10_e40_l0.eps', format='eps', dpi=1000)
plt.show()

# %%
	if True:
		print "Evaluate the model using fast estimation..."
		projection1_train, projection2_train = sls.seq2vec(train_1)
		projection1_test, projection2_test = sls.seq2vec(test_1)

		sim_results_train, rank_results_train = lstm.find_ranking(projection1_train, projection2_train)
		sim_results_test, rank_results_test = lstm.find_ranking(projection1_test, projection2_test)

		print pd.Series(rank_results_train).describe()
		print pd.Series(rank_results_test).describe()
# Out:
# Evaluate the model using fast estimation...
# count    999.000000
# mean      30.174174
# std       39.208408
# min        1.000000
# 25%        5.000000
# 50%       16.500000
# 75%       40.000000
# max      356.000000
# dtype: float64
# count    1000.000000
# mean      114.087000
# std       110.291721
# min         1.000000
# 25%        24.000000
# 50%        65.000000
# 75%       188.500000
# max       532.000000
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
# matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_test[600:1000],'bo')
plt.title('TOP Ranking for test documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.ylim([1000,0])
plt.ylim([532,0.5])
plt.grid(True)
plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_train[0:800],'ro')
plt.title('TOP Ranking for training documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.ylim([532,0])
plt.grid(True)
plt.savefig('top-training.eps', format='eps', dpi=1000)
plt.show()

# %%
type(rank_results_test)
# Out:
# list

# %%
sim_results_test, rank_results_test = lstm.find_ranking(projection1_test[600:1000], projection2_test[600:1000])
print pd.Series(rank_results_test).describe()
# Out:
# count    400.000000
# mean      41.847500
# std       50.092939
# min        1.000000
# 25%        9.500000
# 50%       24.500000
# 75%       55.125000
# max      318.000000
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_train,'ro')
plt.title('TOP Ranking for training documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.ylim([1000,0])
plt.grid(True)
plt.savefig('top-training.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
# matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_test[600:1000],'bo')
plt.title('TOP Ranking for test documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.ylim([1000,0])
# plt.ylim([532,0.5])
plt.grid(True)
plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()
