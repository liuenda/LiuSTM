# %%
# batch size = 64
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 3: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Now the maxlen = 0
# Starting to training the model..., saving to weights/201702212157_e100_1k1k_l0.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# Training error: 0.264640837908
# Training_correct error 0.330076217651
# Testing_correct error: 0.309356570244
# top- 1 = [1] : 1
# top- 5 = [4] : 4
# top- 10 = [17] : 17
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     508.073073
# std      283.017086
# min        1.000000
# 25%      276.500000
# 50%      514.000000
# 75%      752.750000
# max      997.000000
# dtype: float64
# top- 1 = [1] : 1
# top- 5 = [4] : 4
# top- 10 = [6] : 6
# Discription of evaluation (ranking) for testing data:
# count    1000.0000
# mean      553.0825
# std       277.0951
# min         1.0000
# 25%       316.8750
# 50%       585.2500
# 75%       803.3750
# max       998.5000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.302237004042
# Training error: 0.256243079901
# Training_correct error 0.22229757905
# Testing_correct error: 0.208553016186
# top- 1 = [1, 2] : 2
# top- 5 = [4, 10] : 10
# top- 10 = [17, 18] : 18
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     431.817818
# std      283.165279
# min        1.000000
# 25%      183.000000
# 50%      401.000000
# 75%      677.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1] : 1
# top- 5 = [4, 6] : 6
# top- 10 = [6, 10] : 10
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      422.435500
# std       276.554886
# min         1.000000
# 25%       186.000000
# 50%       406.750000
# 75%       616.625000
# max       998.500000
# dtype: float64
# epoch took: 39.4408221245
#
# Epoch 1 ...
# Epoch  1 Update  42 Cost  0.247225552797
# Epoch  1 Update  63 Cost  0.277224808931
# Training error: 0.254095733166
# Training_correct error 0.2293317765
# Testing_correct error: 0.216584250331
# top- 1 = [1, 2, 0] : 0
# top- 5 = [4, 10, 10] : 10
# top- 10 = [17, 18, 18] : 18
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     407.009510
# std      288.905986
# min        1.500000
# 25%      146.500000
# 50%      353.000000
# 75%      650.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2] : 2
# top- 5 = [4, 6, 7] : 7
# top- 10 = [6, 10, 8] : 8
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      389.261500
# std       274.660403
# min         1.000000
# 25%       168.125000
# 50%       329.500000
# 75%       591.250000
# max       998.500000
# dtype: float64
# epoch took: 39.2139818668
#
# Epoch 2 ...
# Epoch  2 Update  84 Cost  0.255546987057
# Training error: 0.254195779562
# Training_correct error 0.246997490525
# Testing_correct error: 0.228625983
# top- 1 = [1, 2, 0, 2] : 2
# top- 5 = [4, 10, 10, 8] : 8
# top- 10 = [17, 18, 18, 22] : 22
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     431.975475
# std      288.841660
# min        1.000000
# 25%      173.750000
# 50%      401.000000
# 75%      660.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2] : 2
# top- 5 = [4, 6, 7, 6] : 6
# top- 10 = [6, 10, 8, 7] : 7
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      424.432000
# std       283.698396
# min         1.000000
# 25%       176.500000
# 50%       393.500000
# 75%       654.500000
# max       998.500000
# dtype: float64
# epoch took: 38.8963220119
#
# Epoch 3 ...
# Epoch  3 Update  105 Cost  0.285109847784
# Epoch  3 Update  126 Cost  0.24310643971
# Training error: 0.253783166409
# Training_correct error 0.223868131638
# Testing_correct error: 0.210479542613
# top- 1 = [1, 2, 0, 2, 2] : 2
# top- 5 = [4, 10, 10, 8, 8] : 8
# top- 10 = [17, 18, 18, 22, 15] : 15
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     425.799299
# std      287.772196
# min        1.000000
# 25%      170.000000
# 50%      379.500000
# 75%      665.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3] : 3
# top- 5 = [4, 6, 7, 6, 7] : 7
# top- 10 = [6, 10, 8, 7, 8] : 8
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      417.786500
# std       282.951086
# min         1.000000
# 25%       180.875000
# 50%       373.000000
# 75%       637.500000
# max       998.500000
# dtype: float64
# epoch took: 39.4885737896
#
# Epoch 4 ...
# Epoch  4 Update  147 Cost  0.238274633884
# Training error: 0.252492845058
# Training_correct error 0.233289524913
# Testing_correct error: 0.222114861012
# top- 1 = [1, 2, 0, 2, 2, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10] : 10
# top- 10 = [17, 18, 18, 22, 15, 16] : 16
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     426.852352
# std      286.235869
# min        1.000000
# 25%      169.500000
# 50%      384.000000
# 75%      670.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12] : 12
# top- 10 = [6, 10, 8, 7, 8, 16] : 16
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      419.859000
# std       284.806808
# min         1.000000
# 25%       177.000000
# 50%       360.000000
# 75%       631.875000
# max       998.500000
# dtype: float64
# epoch took: 39.7222611904
#
# Epoch 5 ...
# Epoch  5 Update  168 Cost  0.238718658686
# Epoch  5 Update  189 Cost  0.249705761671
# Training error: 0.248321726918
# Training_correct error 0.206596150994
# Testing_correct error: 0.194651931524
# top- 1 = [1, 2, 0, 2, 2, 3, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9] : 9
# top- 10 = [17, 18, 18, 22, 15, 16, 17] : 17
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     401.597598
# std      280.368117
# min        1.000000
# 25%      149.500000
# 50%      360.000000
# 75%      629.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9] : 9
# top- 10 = [6, 10, 8, 7, 8, 16, 21] : 21
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      413.489000
# std       283.327498
# min         1.000000
# 25%       179.000000
# 50%       364.000000
# 75%       647.625000
# max       998.500000
# dtype: float64
# epoch took: 38.1298158169
#
# Epoch 6 ...
# Epoch  6 Update  210 Cost  0.241765275598
# Training error: 0.246507808566
# Training_correct error 0.245332837105
# Testing_correct error: 0.232281282544
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2] : 2
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7] : 7
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15] : 15
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     407.292793
# std      286.204885
# min        1.000000
# 25%      152.500000
# 50%      346.500000
# 75%      647.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12] : 12
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20] : 20
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      417.070500
# std       287.566199
# min         1.000000
# 25%       177.000000
# 50%       363.750000
# 75%       684.500000
# max       998.500000
# dtype: float64
# epoch took: 38.6030089855
#
# Epoch 7 ...
# Epoch  7 Update  231 Cost  0.2288774997
# Epoch  7 Update  252 Cost  0.272972404957
# Training error: 0.254146039486
# Training_correct error 0.185588866472
# Testing_correct error: 0.177643090487
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11] : 11
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21] : 21
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     409.070070
# std      277.293862
# min        1.000000
# 25%      167.250000
# 50%      376.000000
# 75%      617.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11] : 11
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14] : 14
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      415.720500
# std       280.199566
# min         1.000000
# 25%       169.000000
# 50%       354.500000
# 75%       628.625000
# max       998.500000
# dtype: float64
# epoch took: 38.7432911396
#
# Epoch 8 ...
# Epoch  8 Update  273 Cost  0.272068858147
# Training error: 0.242367044091
# Training_correct error 0.252176553011
# Testing_correct error: 0.242689236999
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14] : 14
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24] : 24
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     392.275776
# std      281.004609
# min        1.000000
# 25%      140.500000
# 50%      343.000000
# 75%      615.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13] : 13
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17] : 17
# Discription of evaluation (ranking) for testing data:
# count    1000.0000
# mean      412.0970
# std       287.4996
# min         1.0000
# 25%       157.5000
# 50%       395.5000
# 75%       655.1250
# max       998.5000
# dtype: float64
# epoch took: 38.1128890514
#
# Epoch 9 ...
# Epoch  9 Update  294 Cost  0.220294088125
# Epoch  9 Update  315 Cost  0.235775545239
# Training error: 0.240950375795
# Training_correct error 0.24952237308
# Testing_correct error: 0.238036721945
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11] : 11
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22] : 22
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     386.808809
# std      283.571777
# min        1.000000
# 25%      133.000000
# 50%      335.500000
# 75%      594.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7] : 7
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10] : 10
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean      394.35900
# std       285.20908
# min         1.00000
# 25%       155.00000
# 50%       341.50000
# 75%       614.50000
# max       998.50000
# dtype: float64
# epoch took: 37.9193720818
#
# Epoch 10 ...
# Epoch  10 Update  336 Cost  0.248345389962
# Training error: 0.251694500446
# Training_correct error 0.19002148509
# Testing_correct error: 0.182588472962
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15] : 15
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21] : 21
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     408.489990
# std      283.183716
# min        1.000000
# 25%      153.000000
# 50%      386.500000
# 75%      618.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2] : 2
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5] : 5
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8] : 8
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      413.853000
# std       280.927344
# min         1.000000
# 25%       175.000000
# 50%       344.500000
# 75%       646.375000
# max       998.500000
# dtype: float64
# epoch took: 38.6339640617
#
# Epoch 11 ...
# Epoch  11 Update  357 Cost  0.235826194286
# Epoch  11 Update  378 Cost  0.218521744013
# Training error: 0.260331600904
# Training_correct error 0.155260235071
# Testing_correct error: 0.144606411457
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16] : 16
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22] : 22
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     407.338338
# std      284.708821
# min        1.000000
# 25%      166.500000
# 50%      358.500000
# 75%      634.250000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0] : 0
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1] : 1
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4] : 4
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      407.492000
# std       282.006635
# min         2.500000
# 25%       170.000000
# 50%       344.000000
# 75%       628.000000
# max       998.500000
# dtype: float64
# epoch took: 38.2260639668
#
# Epoch 12 ...
# Epoch  12 Update  399 Cost  0.245027393103
# Training error: 0.246809765697
# Training_correct error 0.285826891661
# Testing_correct error: 0.271548509598
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10] : 10
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19] : 19
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     409.069069
# std      284.167676
# min        1.000000
# 25%      165.500000
# 50%      374.500000
# 75%      628.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0] : 0
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8] : 8
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9] : 9
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      416.751000
# std       284.241489
# min         1.500000
# 25%       176.000000
# 50%       353.750000
# 75%       661.125000
# max       998.500000
# dtype: float64
# epoch took: 38.666328907
#
# Epoch 13 ...
# Epoch  13 Update  420 Cost  0.24937812984
# Epoch  13 Update  441 Cost  0.238321259618
# Training error: 0.255492419004
# Training_correct error 0.178141325712
# Testing_correct error: 0.171791702509
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2] : 2
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13] : 13
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25] : 25
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     397.816817
# std      279.434562
# min        1.000000
# 25%      150.500000
# 50%      358.500000
# 75%      615.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2] : 2
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9] : 9
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20] : 20
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      384.644000
# std       276.634236
# min         1.000000
# 25%       175.750000
# 50%       328.000000
# 75%       584.625000
# max       998.500000
# dtype: float64
# epoch took: 38.7673809528
#
# Epoch 14 ...
# Epoch  14 Update  462 Cost  0.22957611084
# Training error: 0.237810626626
# Training_correct error 0.251275986433
# Testing_correct error: 0.239227220416
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2] : 2
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9] : 9
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27] : 27
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     373.694695
# std      276.708016
# min        1.000000
# 25%      130.000000
# 50%      339.000000
# 75%      576.250000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7] : 7
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20] : 20
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      378.551000
# std       278.724841
# min         1.000000
# 25%       146.000000
# 50%       319.000000
# 75%       593.125000
# max       998.500000
# dtype: float64
# epoch took: 39.0305850506
#
# Epoch 15 ...
# Epoch  15 Update  483 Cost  0.246667355299
# Epoch  15 Update  504 Cost  0.240683704615
# Training error: 0.240887671709
# Training_correct error 0.318011671305
# Testing_correct error: 0.295084267855
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5] : 5
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13] : 13
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27] : 27
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     361.884885
# std      277.507999
# min        1.000000
# 25%      113.250000
# 50%      301.000000
# 75%      574.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8] : 8
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21] : 21
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      365.765000
# std       277.405672
# min         1.000000
# 25%       136.500000
# 50%       303.500000
# 75%       551.250000
# max       998.500000
# dtype: float64
# epoch took: 38.4990570545
#
# Epoch 16 ...
# Epoch  16 Update  525 Cost  0.242910578847
# Training error: 0.25239405036
# Training_correct error 0.176912859082
# Testing_correct error: 0.165998831391
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15] : 15
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31] : 31
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     395.485485
# std      279.303106
# min        1.000000
# 25%      156.750000
# 50%      362.000000
# 75%      602.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2] : 2
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5] : 5
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12] : 12
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      398.434000
# std       275.825754
# min         1.000000
# 25%       170.500000
# 50%       336.000000
# 75%       608.500000
# max       998.500000
# dtype: float64
# epoch took: 39.4092140198
#
# Epoch 17 ...
# Epoch  17 Update  546 Cost  0.25964781642
# Epoch  17 Update  567 Cost  0.257043063641
# Training error: 0.234556406736
# Training_correct error 0.292283028364
# Testing_correct error: 0.274673461914
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17] : 17
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26] : 26
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     363.448949
# std      278.001864
# min        1.000000
# 25%      115.000000
# 50%      305.500000
# 75%      572.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13] : 13
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30] : 30
# Discription of evaluation (ranking) for testing data:
# count    1000.0000
# mean      356.0145
# std       270.8418
# min         1.0000
# 25%       137.3750
# 50%       292.0000
# 75%       537.1250
# max       998.5000
# dtype: float64
# epoch took: 38.5551159382
#
# Epoch 18 ...
# Epoch  18 Update  588 Cost  0.243452906609
# Training error: 0.233797997236
# Training_correct error 0.249196007848
# Testing_correct error: 0.236423015594
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11] : 11
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29] : 29
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     368.563564
# std      283.886464
# min        1.000000
# 25%      116.250000
# 50%      294.500000
# 75%      594.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4] : 4
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8] : 8
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22] : 22
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      361.696500
# std       274.227191
# min         1.000000
# 25%       136.000000
# 50%       303.750000
# 75%       526.875000
# max       998.500000
# dtype: float64
# epoch took: 38.1171600819
#
# Epoch 19 ...
# Epoch  19 Update  609 Cost  0.236123532057
# Epoch  19 Update  630 Cost  0.24251614511
# Training error: 0.243955075741
# Training_correct error 0.193669453263
# Testing_correct error: 0.173176974058
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12] : 12
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24] : 24
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     375.804304
# std      278.866774
# min        1.000000
# 25%      140.000000
# 50%      313.000000
# 75%      592.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2] : 2
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10] : 10
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18] : 18
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      374.694000
# std       273.852614
# min         1.000000
# 25%       153.875000
# 50%       315.250000
# 75%       555.875000
# max       998.500000
# dtype: float64
# epoch took: 38.6669070721
#
# Epoch 20 ...
# Epoch  20 Update  651 Cost  0.231325358152
# Epoch  20 Update  672 Cost  0.241164728999
# Training error: 0.232148647308
# Training_correct error 0.273571074009
# Testing_correct error: 0.254434734583
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6] : 6
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12] : 12
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31] : 31
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     367.071572
# std      277.536533
# min        1.000000
# 25%      113.000000
# 50%      307.000000
# 75%      582.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6] : 6
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13] : 13
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24] : 24
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      360.950500
# std       272.732684
# min         1.000000
# 25%       133.500000
# 50%       301.500000
# 75%       544.250000
# max       998.500000
# dtype: float64
# epoch took: 38.6010379791
#
# Epoch 21 ...
# Epoch  21 Update  693 Cost  0.207892388105
# Training error: 0.243090182543
# Training_correct error 0.184895172715
# Testing_correct error: 0.162369146943
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15] : 15
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29] : 29
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     375.013514
# std      282.716775
# min        1.000000
# 25%      123.500000
# 50%      302.000000
# 75%      619.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8] : 8
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18] : 18
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      374.094000
# std       279.395809
# min         1.000000
# 25%       139.000000
# 50%       314.500000
# 75%       572.000000
# max       998.500000
# dtype: float64
# epoch took: 38.2649481297
#
# Epoch 22 ...
# Epoch  22 Update  714 Cost  0.231641024351
# Epoch  22 Update  735 Cost  0.251356452703
# Training error: 0.234843954444
# Training_correct error 0.212701007724
# Testing_correct error: 0.190442815423
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2] : 2
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13] : 13
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26] : 26
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     355.502002
# std      276.914824
# min        1.000000
# 25%      115.750000
# 50%      288.000000
# 75%      566.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10] : 10
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22] : 22
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      347.353500
# std       267.219769
# min         1.000000
# 25%       125.875000
# 50%       283.250000
# 75%       532.250000
# max       998.500000
# dtype: float64
# epoch took: 38.5279560089
#
# Epoch 23 ...
# Epoch  23 Update  756 Cost  0.230098724365
# Training error: 0.23259422183
# Training_correct error 0.285817980766
# Testing_correct error: 0.264875054359
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5] : 5
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13] : 13
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24] : 24
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     360.262262
# std      276.022199
# min        1.000000
# 25%      114.000000
# 50%      301.000000
# 75%      595.250000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13] : 13
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19] : 19
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      345.382500
# std       255.419615
# min         1.000000
# 25%       133.000000
# 50%       298.250000
# 75%       510.375000
# max       998.500000
# dtype: float64
# epoch took: 40.510612011
#
# Epoch 24 ...
# Epoch  24 Update  777 Cost  0.224883377552
# Epoch  24 Update  798 Cost  0.228802680969
# Training error: 0.230857595801
# Training_correct error 0.202732980251
# Testing_correct error: 0.182680055499
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2] : 2
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15] : 15
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26] : 26
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     353.838338
# std      271.781600
# min        1.000000
# 25%      115.250000
# 50%      296.000000
# 75%      578.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12] : 12
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23] : 23
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      325.848000
# std       246.598309
# min         1.000000
# 25%       127.000000
# 50%       276.500000
# 75%       452.000000
# max       998.500000
# dtype: float64
# epoch took: 39.2822749615
#
# Epoch 25 ...
# Epoch  25 Update  819 Cost  0.215485274792
# Training error: 0.228821992874
# Training_correct error 0.212769895792
# Testing_correct error: 0.195576295257
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3] : 3
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14] : 14
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25] : 25
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     351.953954
# std      280.641770
# min        1.000000
# 25%      109.500000
# 50%      272.000000
# 75%      583.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1] : 1
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15] : 15
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25] : 25
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      334.739500
# std       255.547578
# min         1.000000
# 25%       131.500000
# 50%       281.500000
# 75%       490.750000
# max       998.500000
# dtype: float64
# epoch took: 38.258243084
#
# Epoch 26 ...
# Epoch  26 Update  840 Cost  0.224036842585
# Epoch  26 Update  861 Cost  0.214413702488
# Training error: 0.232651680708
# Training_correct error 0.23076979816
# Testing_correct error: 0.207666799426
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6] : 6
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18] : 18
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36] : 36
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     346.175676
# std      274.918461
# min        1.000000
# 25%      104.000000
# 50%      270.000000
# 75%      564.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10] : 10
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23] : 23
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      339.090000
# std       262.657255
# min         1.000000
# 25%       127.500000
# 50%       274.750000
# 75%       495.125000
# max       998.500000
# dtype: float64
# epoch took: 38.4693889618
#
# Epoch 27 ...
# Epoch  27 Update  882 Cost  0.224064588547
# Training error: 0.23870703578
# Training_correct error 0.20530615747
# Testing_correct error: 0.197456166148
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18, 15] : 15
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36, 31] : 31
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     363.263263
# std      279.228824
# min        1.000000
# 25%      115.500000
# 50%      304.500000
# 75%      585.250000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10, 11] : 11
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23, 18] : 18
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      360.941500
# std       262.667421
# min         1.000000
# 25%       142.375000
# 50%       315.250000
# 75%       537.750000
# max       998.500000
# dtype: float64
# epoch took: 37.4558899403
#
# Epoch 28 ...
# Epoch  28 Update  903 Cost  0.24205738306
# Epoch  28 Update  924 Cost  0.248687699437
# Training error: 0.226423799992
# Training_correct error 0.226251840591
# Testing_correct error: 0.20443533361
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6, 4, 5] : 5
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18, 15, 13] : 13
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36, 31, 33] : 33
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     343.174675
# std      271.943624
# min        1.000000
# 25%      109.000000
# 50%      269.000000
# 75%      568.750000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3, 3, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10, 11, 15] : 15
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23, 18, 25] : 25
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      332.297000
# std       255.286829
# min         1.000000
# 25%       123.000000
# 50%       279.500000
# 75%       475.125000
# max       998.500000
# dtype: float64
# epoch took: 36.5016069412
#
# Epoch 29 ...
# Epoch  29 Update  945 Cost  0.228655561805
# Training error: 0.225882947445
# Training_correct error 0.243535280228
# Testing_correct error: 0.218394890428
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6, 4, 5, 7] : 7
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18, 15, 13, 18] : 18
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36, 31, 33, 29] : 29
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     339.764765
# std      267.565473
# min        1.000000
# 25%      109.500000
# 50%      266.000000
# 75%      550.250000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3, 3, 3, 2] : 2
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10, 11, 15, 18] : 18
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23, 18, 25, 25] : 25
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      320.892500
# std       245.166335
# min         1.000000
# 25%       120.500000
# 50%       271.000000
# 75%       446.000000
# max       998.500000
# dtype: float64
# epoch took: 36.5411109924
#
# Epoch 30 ...
# Epoch  30 Update  966 Cost  0.214603930712
# Epoch  30 Update  987 Cost  0.224697262049
# Training error: 0.238030195236
# Training_correct error 0.209891960025
# Testing_correct error: 0.184541106224
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6, 4, 5, 7, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18, 15, 13, 18, 16] : 16
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36, 31, 33, 29, 32] : 32
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     343.796797
# std      274.499051
# min        1.000000
# 25%      102.250000
# 50%      269.500000
# 75%      554.500000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3, 3, 3, 2, 0] : 0
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10, 11, 15, 18, 10] : 10
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23, 18, 25, 25, 22] : 22
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      331.937000
# std       257.799151
# min         2.000000
# 25%       121.875000
# 50%       274.500000
# 75%       471.500000
# max       998.500000
# dtype: float64
# epoch took: 36.2598860264
#
# Epoch 31 ...
# Epoch  31 Update  1008 Cost  0.203763097525
# Training error: 0.232158705592
# Training_correct error 0.19963850081
# Testing_correct error: 0.186485916376
# top- 1 = [1, 2, 0, 2, 2, 3, 3, 2, 3, 3, 3, 3, 4, 4, 2, 2, 5, 3, 4, 3, 3, 6, 4, 2, 5, 2, 3, 6, 4, 5, 7, 4, 4] : 4
# top- 5 = [4, 10, 10, 8, 8, 10, 9, 7, 11, 14, 11, 15, 16, 10, 13, 9, 13, 15, 17, 11, 12, 12, 15, 13, 13, 15, 14, 18, 15, 13, 18, 16, 17] : 17
# top- 10 = [17, 18, 18, 22, 15, 16, 17, 15, 21, 24, 22, 21, 22, 19, 25, 27, 27, 31, 26, 29, 24, 31, 29, 26, 24, 26, 25, 36, 31, 33, 29, 32, 30] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     341.856857
# std      267.825088
# min        1.000000
# 25%      104.000000
# 50%      280.000000
# 75%      537.000000
# max      997.000000
# dtype: float64
# top- 1 = [1, 1, 2, 2, 3, 1, 3, 1, 1, 3, 1, 2, 0, 0, 2, 1, 3, 2, 3, 4, 2, 6, 1, 1, 3, 3, 1, 3, 3, 3, 2, 0, 3] : 3
# top- 5 = [4, 6, 7, 6, 7, 12, 9, 12, 11, 13, 7, 5, 1, 8, 9, 7, 8, 5, 13, 8, 10, 13, 8, 10, 13, 12, 15, 10, 11, 15, 18, 10, 11] : 11
# top- 10 = [6, 10, 8, 7, 8, 16, 21, 20, 14, 17, 10, 8, 4, 9, 20, 20, 21, 12, 30, 22, 18, 24, 18, 22, 19, 23, 25, 23, 18, 25, 25, 22, 27] : 27
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      326.722500
# std       245.046255
# min         1.000000
# 25%       131.000000
# 50%       286.500000
# 75%       473.625000
# max       998.500000
# dtype: float64
# epoch took: 36.2616081238
#
# Epoch 32 ...
# Epoch  32 Update  1029 Cost  0.213442832232

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.0)
plt.plot(sls.tops[1],'r-', label = "TOP-1: Trianing")
plt.plot(sls.tops[5],'b-', label = "TOP-5: Trianing" )
plt.plot(sls.tops[10],'g-', label = "TOP-10: Trianing")
plt.plot(sls.tops_test[1],'r--', label = "TOP-1: Test")
plt.plot(sls.tops_test[5],'b--', label = "TOP-5: Test")
plt.plot(sls.tops_test[10],'g--', label = "TOP10: Test")
plt.ylabel('TOP Accuracy', fontsize=11)
plt.xlabel('Epoches', fontsize=11)
plt.title('TOP Accuracy vs Epoches')
plt.legend(loc = 2, fontsize=8)
plt.savefig('top1-5-10_e40_l0.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_train,'ro')
plt.title('TOP Ranking for training documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
# plt.ylim([30,0.5])
plt.grid(True)
# plt.savefig('top-training.eps', format='eps', dpi=1000)
plt.show()

# %%
		print "Evaluate the model using fast estimation..."
		projection1_train, projection2_train = sls.seq2vec(train_1)
		projection1_test, projection2_test = sls.seq2vec(test_1)

		sim_results_train, rank_results_train = lstm.find_ranking(projection1_train, projection2_train)
		sim_results_test, rank_results_test = lstm.find_ranking(projection1_test, projection2_test)

		print pd.Series(rank_results_train).describe()
		print pd.Series(rank_results_test).describe()
# Out:
# Evaluate the model using fast estimation...
# count    999.000000
# mean     273.883884
# std      231.620076
# min        1.000000
# 25%       79.250000
# 50%      207.000000
# 75%      401.500000
# max      997.000000
# dtype: float64
# count    1000.000000
# mean      270.997000
# std       211.949694
# min         1.000000
# 25%        99.875000
# 50%       233.000000
# 75%       383.000000
# max       998.500000
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6, 2)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_test,'bo')
plt.title('TOP Ranking for test documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
# plt.ylim([30,0.5])
plt.grid(True)
# plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()

# %%
sls.tops
# Out:
# {1: [1,
#   2,
#   0,
#   2,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   4,
#   4,
#   2,
#   2,
#   5,
#   3,
#   4,
#   3,
#   3,
#   6,
#   4,
#   2,
#   5,
#   2,
#   3,
#   6,
#   4,
#   5,
#   7,
#   4,
#   4,
#   3,
#   3,
#   1,
#   4,
#   4,
#   7,
#   4,
#   5,
#   3,
#   4,
#   7,
#   1,
#   3,
#   5,
#   5,
#   3,
#   5,
#   7,
#   4,
#   5,
#   4,
#   4,
#   4,
#   6,
#   3,
#   4,
#   4,
#   6,
#   4,
#   7,
#   4,
#   5,
#   3,
#   6,
#   3,
#   6,
#   4,
#   2,
#   2,
#   5,
#   2,
#   3,
#   4,
#   5,
#   3,
#   0,
#   6,
#   4,
#   4,
#   3,
#   2,
#   4,
#   4,
#   7,
#   5,
#   3,
#   6,
#   4,
#   6,
#   1,
#   6,
#   9,
#   6,
#   7,
#   2,
#   3,
#   4,
#   3],
#  5: [4,
#   10,
#   10,
#   8,
#   8,
#   10,
#   9,
#   7,
#   11,
#   14,
#   11,
#   15,
#   16,
#   10,
#   13,
#   9,
#   13,
#   15,
#   17,
#   11,
#   12,
#   12,
#   15,
#   13,
#   13,
#   15,
#   14,
#   18,
#   15,
#   13,
#   18,
#   16,
#   17,
#   15,
#   18,
#   18,
#   8,
#   18,
#   26,
#   12,
#   16,
#   14,
#   22,
#   24,
#   22,
#   22,
#   25,
#   24,
#   22,
#   28,
#   18,
#   17,
#   24,
#   24,
#   23,
#   24,
#   19,
#   16,
#   24,
#   27,
#   22,
#   24,
#   29,
#   18,
#   21,
#   25,
#   28,
#   23,
#   23,
#   24,
#   21,
#   22,
#   25,
#   21,
#   17,
#   27,
#   25,
#   15,
#   12,
#   20,
#   14,
#   24,
#   20,
#   18,
#   26,
#   28,
#   31,
#   21,
#   19,
#   26,
#   29,
#   25,
#   21,
#   25,
#   22,
#   27,
#   27,
#   22,
#   20,
#   22,
#   25],
#  10: [17,
#   18,
#   18,
#   22,
#   15,
#   16,
#   17,
#   15,
#   21,
#   24,
#   22,
#   21,
#   22,
#   19,
#   25,
#   27,
#   27,
#   31,
#   26,
#   29,
#   24,
#   31,
#   29,
#   26,
#   24,
#   26,
#   25,
#   36,
#   31,
#   33,
#   29,
#   32,
#   30,
#   32,
#   28,
#   33,
#   24,
#   31,
#   36,
#   32,
#   32,
#   39,
#   36,
#   44,
#   35,
#   43,
#   39,
#   43,
#   47,
#   45,
#   43,
#   37,
#   44,
#   50,
#   54,
#   42,
#   31,
#   29,
#   42,
#   56,
#   39,
#   50,
#   49,
#   28,
#   51,
#   39,
#   50,
#   44,
#   45,
#   50,
#   45,
#   35,
#   53,
#   45,
#   44,
#   44,
#   47,
#   30,
#   31,
#   45,
#   34,
#   50,
#   45,
#   35,
#   52,
#   52,
#   46,
#   43,
#   34,
#   49,
#   48,
#   48,
#   43,
#   49,
#   48,
#   45,
#   50,
#   39,
#   40,
#   39,
#   44]}

# %%
sls.tops_test
# Out:
# {1: [1,
#   1,
#   2,
#   2,
#   3,
#   1,
#   3,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0,
#   0,
#   2,
#   1,
#   3,
#   2,
#   3,
#   4,
#   2,
#   6,
#   1,
#   1,
#   3,
#   3,
#   1,
#   3,
#   3,
#   3,
#   2,
#   0,
#   3,
#   1,
#   2,
#   3,
#   1,
#   5,
#   4,
#   3,
#   5,
#   3,
#   4,
#   7,
#   5,
#   3,
#   1,
#   4,
#   4,
#   2,
#   1,
#   4,
#   4,
#   4,
#   2,
#   4,
#   0,
#   2,
#   6,
#   1,
#   9,
#   2,
#   5,
#   3,
#   3,
#   2,
#   2,
#   1,
#   1,
#   2,
#   1,
#   0,
#   2,
#   2,
#   2,
#   2,
#   4,
#   1,
#   1,
#   5,
#   1,
#   4,
#   6,
#   1,
#   6,
#   2,
#   4,
#   2,
#   3,
#   4,
#   4,
#   4,
#   6,
#   2,
#   7,
#   2,
#   5,
#   1,
#   3,
#   3,
#   4],
#  5: [4,
#   6,
#   7,
#   6,
#   7,
#   12,
#   9,
#   12,
#   11,
#   13,
#   7,
#   5,
#   1,
#   8,
#   9,
#   7,
#   8,
#   5,
#   13,
#   8,
#   10,
#   13,
#   8,
#   10,
#   13,
#   12,
#   15,
#   10,
#   11,
#   15,
#   18,
#   10,
#   11,
#   7,
#   13,
#   19,
#   13,
#   19,
#   12,
#   15,
#   17,
#   16,
#   17,
#   20,
#   20,
#   17,
#   17,
#   15,
#   21,
#   16,
#   20,
#   17,
#   22,
#   18,
#   13,
#   14,
#   7,
#   11,
#   17,
#   12,
#   19,
#   20,
#   15,
#   11,
#   18,
#   14,
#   17,
#   14,
#   16,
#   19,
#   16,
#   12,
#   19,
#   19,
#   15,
#   17,
#   14,
#   8,
#   8,
#   21,
#   8,
#   16,
#   23,
#   17,
#   23,
#   17,
#   17,
#   18,
#   17,
#   17,
#   28,
#   21,
#   16,
#   20,
#   22,
#   16,
#   18,
#   15,
#   13,
#   12,
#   12],
#  10: [6,
#   10,
#   8,
#   7,
#   8,
#   16,
#   21,
#   20,
#   14,
#   17,
#   10,
#   8,
#   4,
#   9,
#   20,
#   20,
#   21,
#   12,
#   30,
#   22,
#   18,
#   24,
#   18,
#   22,
#   19,
#   23,
#   25,
#   23,
#   18,
#   25,
#   25,
#   22,
#   27,
#   19,
#   24,
#   26,
#   26,
#   26,
#   20,
#   26,
#   31,
#   32,
#   30,
#   30,
#   34,
#   31,
#   33,
#   29,
#   33,
#   30,
#   34,
#   31,
#   42,
#   37,
#   28,
#   27,
#   19,
#   20,
#   25,
#   29,
#   40,
#   33,
#   35,
#   17,
#   38,
#   24,
#   39,
#   32,
#   29,
#   35,
#   31,
#   23,
#   37,
#   33,
#   38,
#   28,
#   33,
#   19,
#   14,
#   36,
#   16,
#   41,
#   37,
#   36,
#   38,
#   37,
#   30,
#   39,
#   35,
#   36,
#   41,
#   41,
#   33,
#   36,
#   39,
#   35,
#   35,
#   25,
#   20,
#   26,
#   31]}
