# %%
run baseline_proj.py
# Out:
# [INFO]Reading the word2vec vectors in  en  from  ./data_baseline/good_vecs_en.csv ---
# [INFO]Reading the word2vec vectors in  jp  from  ./data_baseline/good_vecs_jp.csv ---
# [DEBUG] inv(JTJ)*JTJ=I?:
# [DEBUG] [[  1.00000000e+00   1.91963307e-12   2.35026415e-12 ...,   5.48230575e-14
#    -2.53620143e-12  -7.09088496e-13]
#  [ -3.74589285e-12   1.00000000e+00   3.80477022e-13 ...,   9.39741479e-13
#    -3.94819303e-14  -5.11707022e-12]
#  [  4.28733291e-12   2.59181811e-12   1.00000000e+00 ...,  -3.91510958e-13
#    -1.27291775e-12  -4.87672564e-13]
#  ...,
#  [  2.31703545e-12   8.51610359e-13   6.83905426e-14 ...,   1.00000000e+00
#     2.60250195e-13   4.87370210e-13]
#  [  1.68333263e-12  -4.30644827e-13  -3.41771696e-12 ...,   5.35846248e-13
#     1.00000000e+00  -3.86998816e-13]
#  [ -1.53319589e-12   5.53895644e-13   1.69822493e-12 ...,  -4.54747351e-13
#    -1.36424205e-12   1.00000000e+00]]

# %%
kmeans_en.fit(vecs_en.drop('en',axis=1))
# Out:
#                           en         0         1         2         3  \
# 0                    Deficit  0.084308  0.132496 -0.209025 -0.034399
# 1                   Cautions  0.055394 -0.033914 -0.077901 -0.042476
# 2                      Entry  0.001466 -0.017145  0.037660  0.000031
# 3                    Support  0.064751 -0.018078 -0.074576  0.010683
# 4    Resumption of dividends  0.016426  0.009314 -0.088602 -0.043313
# 5                   Addition  0.059325 -0.082537  0.114558  0.067912
# 6                  Delisting -0.038565 -0.023951  0.122080  0.040249
# 7             Price increase  0.007985  0.016837 -0.050116 -0.142364
# 8                  Reduction -0.000495  0.073713  0.151051 -0.035996
# 9                       Jump  0.095559 -0.001361  0.019275 -0.022261
# 10           Upward revision -0.045601  0.024389 -0.041612 -0.008335
# 11                 Fair wind -0.002593  0.055042  0.007195 -0.077398
# 12              Contribution -0.032373  0.036847  0.143564  0.015545
# ...

# %%
np.dot(E, W)
# Out:
# array([[-0.0769665 ,  0.05680371,  0.03503396, ...,  0.00700042,
#          0.04894968, -0.00305676],
#        [ 0.03710773, -0.03775909, -0.03730526, ...,  0.07772317,
#         -0.06466517,  0.06190146],
#        [ 0.05897767, -0.03840106, -0.14856152, ...,  0.03191265,
#         -0.03881222, -0.0537605 ],
#        ...,
#        [ 0.00367532,  0.0588059 , -0.01774912, ..., -0.01606006,
#         -0.06309642,  0.00044677],
#        [-0.06056983,  0.04923827, -0.09125971, ..., -0.04412608,
#         -0.05469798,  0.06909986],
#        [ 0.00369978, -0.03406202,  0.01000587, ...,  0.06887186,
#          0.01089858, -0.068722  ]])

# %%
np.array(J)
# Out:
# array([[-0.0769706 ,  0.05680276,  0.03503606, ...,  0.00699851,
#          0.04895106, -0.00305858],
#        [ 0.03710445, -0.0377584 , -0.03730559, ...,  0.07772418,
#         -0.06466551,  0.06190131],
#        [ 0.05897798, -0.03840174, -0.14856376, ...,  0.03191319,
#         -0.03881501, -0.05375743],
#        ...,
#        [ 0.01359174,  0.12105995,  0.00306812, ..., -0.05695213,
#         -0.1090797 ,  0.07060809],
#        [-0.03041093,  0.06489757, -0.14848064, ..., -0.06736273,
#         -0.05338883,  0.06104626],
#        [ 0.00369859, -0.03406082,  0.01000692, ...,  0.06887277,
#          0.01089932, -0.06872336]])
