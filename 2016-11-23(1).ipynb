# %%
run main.py
# Out:
# merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       1
# Name: xb, dtype: int64

# %%
df_train_1[]
# Out:
#                                             en_article  \
# 0    u.s. commerce department seasonal adjust annua...
# 1    chinese budget smartphone maker xiaomi plan se...
# 2    samsung electronics co ltd fell more percent t...
# 3    fiat deal gain full control chrysler group llc...
# 4    fiat share jump thursday it strike deal gain f...
# 5    u.s. treasuries price rise thursday benchmark ...
# 6                       auction detail see 3-year note
# 7    brent crude sink barrel thursday libya prepare...
# 8    gauge u.s. factory activity hold 2-1/2-year hi...
# 9    work massive panama canal extension project ma...
# 10   increase december car sale france spain prompt...
# 11   federal reserve provide liquidity foreign cent...
# 12   new car sale spain rise percent year early car...
# 13   south korean auto maker hyundai motor co kia m...
# 14   u.s. manufacturing end year high note grow dec...
# 15   oil price fell more thursday libya prepare res...
# ...

# %%
len(train_2)
# Out:
# 999

# %%
run main.py
# Out:
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       1
# Name: xb, dtype: int64
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       2
# Name: xb, dtype: int64
# Evaluate in terms of training data...
# the round 0 rank: 12.0
# the round 1 rank: 10.0
# the round 2 rank: 6.0
# the round 3 rank: 35.5
# the round 4 rank: 33.5
# the round 5 rank: 20.0
# the round 6 rank: 1.0
# the round 7 rank: 26.0
# the round 8 rank: 54.0
# the round 9 rank: 7.0
# the round 10 rank: 7.5
# ...

# %%
score_tr = sum(rank_results_tr)/len(rank_results_tr)
print "score of training data:", score_tr
score_te = sum(rank_results_te)/len(rank_results_te)
print "socre of testing data:", score_te
# Out:
# score of training data: 30.954954955
# socre of testing data: 36.7525

# %%
df_train_1
# Out:
#                                             en_article  \
# 0    u.s. commerce department seasonal adjust annua...
# 1    chinese budget smartphone maker xiaomi plan se...
# 2    samsung electronics co ltd fell more percent t...
# 3    fiat deal gain full control chrysler group llc...
# 4    fiat share jump thursday it strike deal gain f...
# 5    u.s. treasuries price rise thursday benchmark ...
# 6                       auction detail see 3-year note
# 7    brent crude sink barrel thursday libya prepare...
# 8    gauge u.s. factory activity hold 2-1/2-year hi...
# 9    work massive panama canal extension project ma...
# 10   increase december car sale france spain prompt...
# 11   federal reserve provide liquidity foreign cent...
# 12   new car sale spain rise percent year early car...
# 13   south korean auto maker hyundai motor co kia m...
# 14   u.s. manufacturing end year high note grow dec...
# 15   oil price fell more thursday libya prepare res...
# ...

# %%
df_test_1
# Out:
#                                             en_article  \
# 0    european central bank leave interest rate unch...
# 1    european central bank keep interest rate stead...
# 2    european central bank leave interest rate unch...
# 3    european central bank leave interest rate unch...
# 4    european central bank leave interest rate unch...
# 5    european central bank hold borrow rate thursda...
# 6    european central bank leave interest rate unch...
# 7    china annual consumer inflation slow more aggr...
# 8    european central bank unexpected cut interest ...
# 9    european central bank hold borrow rate thursda...
# 10   monsanto co world large seed company say wedne...
# 11   european central bank hold borrow rate thursda...
# 12   south korea central bank keep interest rate st...
# 13   european central bank keep interest rate recor...
# 14   european central bank hold borrow rate thursda...
# 15   european central bank leave interest rate unch...
# ...

# %%
run main.py
# Out:
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       1
# Name: xb, dtype: int64
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       2
# Name: xb, dtype: int64
# Evaluate in terms of training data...
# the round 0 rank: 12.0
# the round 1 rank: 10.0
# the round 2 rank: 6.0
# the round 3 rank: 35.5
# the round 4 rank: 33.5
# the round 5 rank: 20.0
# the round 6 rank: 1.0
# the round 7 rank: 26.0
# the round 8 rank: 54.0
# the round 9 rank: 7.0
# the round 10 rank: 7.5
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_tr,'ro')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
# plt.plot(rank_results_tr,'ro')
plt.plot(rank_results_te,'bo')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_tr,'ro')
plt.plot(rank_results_te,'bo')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
print pd.Series(rank_results_tr).describe()
print pd.Series(rank_results_te).describe()
# Out:
# count    999.000000
# mean      30.954955
# std       56.035211
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       26.000000
# max      390.000000
# dtype: float64
# count    1000.000000
# mean       36.752500
# std        58.397592
# min         1.000000
# 25%         4.000000
# 50%        12.000000
# 75%        34.250000
# max       331.000000
# dtype: float64

# %%
run main.py
# Out:
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       1
# Name: xb, dtype: int64
# Reading english Data: 1000
# Reading english Data: 1000
# Merging the English and Japanes news dataframe
# Read mapping file and convert it to tuple from string
# Mapping English clusters to Japanese clusters
# Drop the null line
# Convert cluster names(list) to cluster namse(string)
# False    998
# True       2
# Name: xb, dtype: int64
# Starting to training the modle..., saving to 201611232246.p
# Training
# the length of the training data is  1998
# (3.9384785, 0.21876754, 0.22225336219185393)
# Epoch 0
# Epoch  0 Update  40 Cost  0.115946665406
# epoch took: 38.5631911755
# (1.9499207, 0.77788025, 0.77229360174910866)
# Epoch 1
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_tr,'ro')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
# plt.plot(rank_results_tr,'ro')
plt.plot(rank_results_te,'bo')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_tr,'ro')
plt.plot(rank_results_te,'bo')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
df_train_1[["en_article","xa", "jp_article", "transformation_jp","xb"]]
# Out:
#                                             en_article  \
# 0    u.s. commerce department seasonal adjust annua...
# 1    chinese budget smartphone maker xiaomi plan se...
# 2    samsung electronics co ltd fell more percent t...
# 3    fiat deal gain full control chrysler group llc...
# 4    fiat share jump thursday it strike deal gain f...
# 5    u.s. treasuries price rise thursday benchmark ...
# 6                       auction detail see 3-year note
# 7    brent crude sink barrel thursday libya prepare...
# 8    gauge u.s. factory activity hold 2-1/2-year hi...
# 9    work massive panama canal extension project ma...
# 10   increase december car sale france spain prompt...
# 11   federal reserve provide liquidity foreign cent...
# 12   new car sale spain rise percent year early car...
# 13   south korean auto maker hyundai motor co kia m...
# 14   u.s. manufacturing end year high note grow dec...
# 15   oil price fell more thursday libya prepare res...
# ...

# %%
matplotlib.rcParams['figure.figsize'] = (15, 8)
a= pd.Series(rank_results_te)
b= pd.Series(rank_results_tr)
freq_a = a.value_counts().sort_index()
freq_b = b.value_counts().sort_index()
plt.ylabel('Frequency of the ranking')
plt.xlabel('Ranks [LOG]')
plt.xscale('log')
# plt.yscale('log')

plt.plot( freq_a.index, freq_a.values,'b-', label="Testing Data")
plt.plot( freq_a.index, freq_b.values, 'r-', label="Training Data")
plt.title("Comparison of evaluation results between testing data training data")
plt.legend(bbox_to_anchor=(0.8, 0.9), loc=2, borderaxespad=0.)

# %%
freq_a.sort_index()
# Out:
# 1.0      151
# 1.5       50
# 2.0       90
# 2.5       26
# 3.0       56
# 3.5       22
# 4.0       36
# 4.5       28
# 5.0       24
# 5.5       12
# 6.0       21
# 6.5       12
# 7.0       25
# 7.5        8
# 8.0       18
# 8.5        4
# 9.0       10
# 9.5       10
# 10.0      14
# 10.5      12
# 11.0      25
# 11.5       4
# 12.0       9
# 12.5      10
# 13.0      14
# 13.5      10
# 14.0       6
# 15.0      10
# 15.5       2
# 16.0      18
#         ...
# 125.5      2
# 128.0      1
# 130.0      1
# 134.0      1
# 136.0      1
# 138.0      1
# 139.0      1
# 145.0      1
# 155.0      1
# 159.0      4
# 160.0      1
# 162.0      3
# 164.0      3
# 165.0      3
# 166.0      1
# 166.5      6
# 171.0      3
# 173.0      1
# 174.0      1
# 175.0      1
# 176.5      2
# 179.0      3
# 189.0      1
# 195.0      1
# 208.0      1
# 212.0      1
# 215.5      2
# 217.0      1
# 219.0      1
# 307.0      1
# dtype: int64
