# %%
run keras_article.py
# Out:
# maxlen 300 epoch 10 dim_lstm 200
# dim_Dense 800
# dropout_rate 0.0 , LSTM type: bi-lstm sum
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading english Data: 63386
# Reading english Data: 63386
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    63340
# True         3
# Name: en_article, dtype: int64
# Using the new test data to evaluate.......
# keras_article.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['word2vec_en'] = df_pairs_evaluate['en_article'].apply(doc2vec_en)
# keras_article.py:443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10, 6)
plt.plot(tops[1],'r-*', label = "TOP-1: TEST-1L")
plt.plot(tops[5],'b-*', label = "TOP-5: TEST-1L" )
plt.plot(tops[10],'g-*', label = "TOP-10: TEST-1L")
plt.plot(tops_test[1],'r--', label = "TOP-1: TEST-2L")
plt.plot(tops_test[5],'b--', label = "TOP-5: TEST-2L")
plt.plot(tops_test[10],'g--', label = "TOP10: TEST-2L")
plt.ylabel('TOP-N', fontsize=16)
plt.xlabel('Epoches', fontsize=16)
plt.title('TOP-N vs Epoches for LONG test data', fontsize=16)
plt.legend(loc='upper center', ncol=3, fontsize=12, bbox_to_anchor=(0.5, -0.1))
plt.savefig('lstm-long-test.eps', format='eps', dpi=1000)
plt.grid()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10, 6)
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(tops[1],'r-*', label = "TOP-1: TEST-1L")
ax.plot(tops[5],'b-*', label = "TOP-5: TEST-1L" )
ax.plot(tops[10],'g-*', label = "TOP-10: TEST-1L")
ax.plot(tops_test[1],'r--p', label = "TOP-1: TEST-2L")
ax.plot(tops_test[5],'b--p', label = "TOP-5: TEST-2L")
ax.plot(tops_test[10],'g--p', label = "TOP10: TEST-2L")
plt.ylabel('TOP-N', fontsize=16)
plt.xlabel('Epoches', fontsize=16)
plt.title('TOP-N vs Epoches for LONG test data', fontsize=16)
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
ax.legend(loc='upper center', ncol=3, fontsize=12, fancybox=True, bbox_to_anchor=(0.5, -0.12))
plt.grid()
fig.savefig('lstm-long-test-s.pdf', format='pdf', dpi=1000)
# fig.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10, 9)
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(tops[1],'r-*', label = "TOP-1: TEST-1L")
ax.plot(tops[5],'b-*', label = "TOP-5: TEST-1L" )
ax.plot(tops[10],'g-*', label = "TOP-10: TEST-1L")
ax.plot(tops_test[1],'r--p', label = "TOP-1: TEST-2L")
ax.plot(tops_test[5],'b--p', label = "TOP-5: TEST-2L")
ax.plot(tops_test[10],'g--p', label = "TOP10: TEST-2L")
plt.ylabel('TOP-N', fontsize=16)
plt.xlabel('Epoches', fontsize=16)
plt.title('TOP-N vs Epoches for LONG test data', fontsize=16)
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
ax.legend(loc='upper center', ncol=3, fontsize=12, fancybox=True, bbox_to_anchor=(0.5, -0.12))
plt.grid()
plt.savefig('lstm-long-test.pdf', format='pdf', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

fig = plt.figure(figsize=(10, 7))
ax = plt.subplot(211)

ax.plot(rank_results_test,'b.')
plt.title('Ranks for TEST-1L\n', fontsize=16)
plt.ylabel('Rank (Linear)', fontsize=16)
plt.ylim([100,0])
ax.plot([0, 1000], [11, 11], 'r:', lw=3, label = "TOP-10 line")
# ax.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
# ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=2, label = "TOP-1 line")
# plt.ylim([30,0.5])
ax.grid(True)


fig = plt.figure(figsize=(10, 17))
ax = plt.subplot(212)
ax.plot(rank_results_test,'b.')

plt.xlabel('\nDocument Number', fontsize=16)
plt.ylabel('Rank (Log)', fontsize=16)
plt.ylim([1000,0.9])
# plt.ylim([0.9,1000])
plt.yscale('log')
ax.grid()
# plt.ylim([30,0.5])
ax.plot([0, 1000], [11, 11], 'r:', lw=5, label = "TOP-10 line")
ax.plot([0, 1000], [6, 6], 'g:', lw=5, label ="TOP-5 line")
ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=5, label = "TOP-1 line")
ax.legend(loc='upper center', ncol=3, fontsize=15, bbox_to_anchor=(0.5, -0.14))

fig.savefig('long-lstm-test1.pdf', format='pdf', dpi=1000)
fig.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

fig = plt.figure(figsize=(10, 7))
ax = plt.subplot(211)

ax.plot(rank_results_test2,'b.')
plt.title('Ranks for TEST-2L\n', fontsize=16)
plt.ylabel('Rank (Linear)', fontsize=16)
plt.ylim([100,0])
ax.plot([0, 1000], [11, 11], 'r:', lw=3, label = "TOP-10 line")
# ax.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
# ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=2, label = "TOP-1 line")
# plt.ylim([30,0.5])
ax.grid(True)


fig = plt.figure(figsize=(10, 17))
ax = plt.subplot(212)
ax.plot(rank_results_test2,'b.')

plt.xlabel('\nDocument Number', fontsize=16)
plt.ylabel('Rank (Log)', fontsize=16)
plt.ylim([1000,0.9])
# plt.ylim([0.9,1000])
plt.yscale('log')
ax.grid()
# plt.ylim([30,0.5])
ax.plot([0, 1000], [11, 11], 'r:', lw=5, label = "TOP-10 line")
ax.plot([0, 1000], [6, 6], 'g:', lw=5, label ="TOP-5 line")
ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=5, label = "TOP-1 line")
ax.legend(loc='upper center', ncol=3, fontsize=15, bbox_to_anchor=(0.5, -0.14))
plt.savefig('long-lstm-test2test.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

fig = plt.figure(figsize=(10, 7))
ax = plt.subplot(211)

ax.plot(rank_results_test2,'b.')
plt.title('Ranks for TEST-2L\n', fontsize=16)
plt.ylabel('Rank (Linear)', fontsize=16)
plt.ylim([100,0])
plt.xlim([725,850])
ax.plot([0, 1000], [11, 11], 'r:', lw=3, label = "TOP-10 line")
# ax.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
# ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=2, label = "TOP-1 line")
# plt.ylim([30,0.5])
ax.grid(True)


fig = plt.figure(figsize=(10, 17))
ax = plt.subplot(212)
ax.plot(rank_results_test2,'b.')

plt.xlabel('\nDocument Number', fontsize=16)
plt.ylabel('Rank (Log)', fontsize=16)
plt.ylim([1000,0.9])
# plt.ylim([0.9,1000])
plt.yscale('log')
plt.xlim([700,900])
ax.grid()
# plt.ylim([30,0.5])
ax.plot([0, 1000], [11, 11], 'r:', lw=5, label = "TOP-10 line")
ax.plot([0, 1000], [6, 6], 'g:', lw=5, label ="TOP-5 line")
ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=5, label = "TOP-1 line")
ax.legend(loc='upper center', ncol=3, fontsize=15, bbox_to_anchor=(0.5, -0.14))

plt.savefig('long-lstm-test2.pdf', format='pdf', dpi=1000)
plt.show()

# %%
 _1, _2, df_pairs = prepare_train(dir_en, dir_jp)
df_pairs_evaluate = df_pairs.iloc[50000:55000:5]
df_pairs_evaluate.iloc[720:745]
# Out:
# Reading english Data: 63386
# Reading english Data: 63386
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    63341
# True         2
# Name: en_article, dtype: int64
#        Unnamed: 0                                         en_article  \
# 53630       53630  first deputy governor russia central bank say ...
# 53635       53635  federal reserve could step it chair twice-per-...
# 53640       53640  * discovery capital eton park fund say benefit...
# 53645       53645  voter united state take poll tuesday cast ball...
# 53650       53650  fiat chrysler automobile chief executive offic...
# 53655       53655  expeditors international washington inc report...
# 53660       53660  republican roll big victory tuesday seize cont...
# 53665       53665  voter united state take poll tuesday cast ball...
# 53670       53670  president barack obama face political rebuke c...
# 53675       53675  republican strike powerful first blow u.s. con...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
# matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.figsize'] = (10,9)
plt.plot(rank_results_test,'bo')
plt.title('TOP Ranking for test documents (1-1000)', fontsize=16)
plt.xlabel('Document Number', fontsize=16)
plt.ylabel('The ranking of the real pair', fontsize=16)
# plt.ylim([1000,0.9])
plt.ylim([0.9,1000])
plt.yscale('log')
plt.grid()
# plt.ylim([30,0.5])
plt.plot([0, 1000], [11, 11], 'r:', lw=5, label = "TOP-1 line")
plt.plot([0, 1000], [6, 6], 'g:', lw=5, label ="TOP-5 line")
plt.plot([0, 1000], [1.2, 1.2], 'y:', lw=5, label = "TOP-10 line")
plt.legend(loc='upper center', ncol=3, fontsize=16, bbox_to_anchor=(0.5, -0.07))

plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
# matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.figsize'] = (10,4)
plt.plot(rank_results_test,'bo')
plt.title('TOP Ranking for test documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
# plt.ylim([500,0])
# plt.yscale('log')
# plt.ylim([30,0.5])
plt.grid(True)
plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
from matplotlib import gridspec
import matplotlib.pyplot as plt
import matplotlib

fig = plt.figure(figsize=(8.5, 10)) 
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 2.5]) 
ax1 = fig.add_subplot(gs[0])


plt.plot(rank_results_test2,'bx')
ax1.set_title('Ranks for TEST-2L, LSTM, Long\n', fontsize=16)
ax1.set_ylabel('Rank (Linear)', fontsize=16)
# ax1.set_ylim([100,0])
ax1.set_ylim([0,150])
ax1.plot([0, 1000], [11, 11], 'r-', lw=2, label = "TOP-10 line")
# ax.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
# ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=2, label = "TOP-1 line")
ax1.tick_params(axis='y', labelsize=16)
# plt.ylim([30,0.5])
ax1.grid(True)
# plt.show()
ax1.xaxis.set_ticklabels([])


# fig = plt.figure(figsize=(10, 17))
ax2 = fig.add_subplot(gs[1])
ax2.plot(rank_results_test2,'bx')

ax2.set_xlabel('Document Number', fontsize=16)
ax2.set_ylabel('Rank (Log)', fontsize=16)
ax2.set_ylim([1000,0.9])
# plt.ylim([0.9,1000])
ax2.set_yscale('log')
ax2.grid()
# plt.ylim([30,0.5])
ax2.plot([0, 1000], [11, 11], 'r-', lw=2, label = "TOP-10 line")
ax2.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
ax2.plot([0, 1000], [1.2, 1.2], 'y-', lw=2, label = "TOP-1 line")
ax2.tick_params(axis='x', labelsize=16)
ax2.tick_params(axis='y', labelsize=16)
lgd = plt.legend(loc='upper center', ncol=3, fontsize=14, bbox_to_anchor=(0.5, -0.1))
plt.tight_layout()
plt.savefig('long-lstm-test2.pdf', format='pdf', dpi=1000, bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
# %matplotlib inline
from matplotlib import gridspec
import matplotlib.pyplot as plt
import matplotlib

fig = plt.figure(figsize=(8.5, 10)) 
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 2.5]) 
ax1 = fig.add_subplot(gs[0])


plt.plot(rank_results_test,'bx')
ax1.set_title('Ranks for TEST-1L, LSTM, Long\n', fontsize=16)
ax1.set_ylabel('Rank (Linear)', fontsize=16)
# ax1.set_ylim([100,0])
ax1.set_ylim([0,150])
ax1.plot([0, 1000], [11, 11], 'r-', lw=2, label = "TOP-10 line")
# ax.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
# ax.plot([0, 1000], [1.2, 1.2], 'y:', lw=2, label = "TOP-1 line")
ax1.tick_params(axis='y', labelsize=16)
# plt.ylim([30,0.5])
ax1.grid(True)
# plt.show()
ax1.xaxis.set_ticklabels([])


# fig = plt.figure(figsize=(10, 17))
ax2 = fig.add_subplot(gs[1])
ax2.plot(rank_results_test,'bx')

ax2.set_xlabel('Document Number', fontsize=16)
ax2.set_ylabel('Rank (Log)', fontsize=16)
ax2.set_ylim([1000,0.9])
# plt.ylim([0.9,1000])
ax2.set_yscale('log')
ax2.grid()
# plt.ylim([30,0.5])
ax2.plot([0, 1000], [11, 11], 'r-', lw=2, label = "TOP-10 line")
ax2.plot([0, 1000], [6, 6], 'g-', lw=2, label ="TOP-5 line")
ax2.plot([0, 1000], [1.2, 1.2], 'y-', lw=2, label = "TOP-1 line")
lgd = plt.legend(loc='upper center', ncol=3, fontsize=14, bbox_to_anchor=(0.5, -0.1))
ax2.tick_params(axis='x', labelsize=16)
ax2.tick_params(axis='y', labelsize=16)
plt.tight_layout()
plt.savefig('long-lstm-test1.pdf', format='pdf', dpi=1000, bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
print "classification report of TEST-1L data:"
print pd.Series(rank_results_test).describe()
print "classification report of TEST-2L data:"
print pd.Series(rank_results_test2).describe()
# Out:
# classification report of TEST-1L data:
# count    1000.000000
# mean       34.427000
# std        67.667437
# min         1.000000
# 25%         4.500000
# 50%        12.250000
# 75%        33.000000
# max       708.500000
# dtype: float64
# classification report of TEST-2L data:
# count    1000.000000
# mean       31.074000
# std        56.234352
# min         1.000000
# 25%         5.000000
# 50%        13.000000
# 75%        33.000000
# max       637.500000
# dtype: float64

# %%
from sklearn.metrics import classification_report
y_pred_train1 = model_lstm2.predict([X1_train, X2_train])
print "classification report of Train-1L-e data:"
print(classification_report(y_train, y_pred_train1>0.5))
# Out:
# classification report of Train-1L-e data:
#              precision    recall  f1-score   support
#
#         0.0       1.00      0.90      0.95      4000
#         1.0       0.91      1.00      0.95      4000
#
# avg / total       0.95      0.95      0.95      8000

# %%
from sklearn.metrics import classification_report
y_pred_test1 = model_lstm2.predict([X1_test, X2_test])
print "classification report of TEST-1L-e data:"
print(classification_report(y_test, y_pred_test1>0.5))
# Out:
# classification report of TEST-1L-e data:
#              precision    recall  f1-score   support
#
#         0.0       0.90      0.82      0.86      1000
#         1.0       0.83      0.91      0.87      1000
#
# avg / total       0.86      0.86      0.86      2000

# %%
from sklearn.metrics import classification_report
y_pred_test2 = model_lstm2.predict([X1_test_new, X2_test_new])
print "classification report of TEST-2L-e data:"
print(classification_report(y_test, y_pred_test2>0.5))
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [False]], dtype=bool)

# %%
    # Generate training data (similarity = 0)
    features_en_0_new = np.array(features_en_new)
    np.random.shuffle((features_en_0_new))

    # check the duplicated amount
    c = np.all(features_en_new == features_en_0_new, axis=(1,2))
    print("C value =", c.sum(), "position:", np.where(c== True)[0].tolist())

    # Prepare the final training and test data
    X1_test_new = np.concatenate((features_en_new, features_en_0_new), axis = 0)
    X2_test_new = np.concatenate((features_jp_new, features_jp_new), axis = 0)

    if mode == "reg":
        y_test_new = np.concatenate((np.ones(len(features_en_new)), np.zeros(len(features_en_0_new))+bias_y), axis = 0)
        # y_test = np.concatenate((np.ones(len(X1_test_1)), np.zeros(len(X1_test_0))), axis = 0)
    else:
        y_test_new = np.concatenate((np.ones(len(features_en_new)), np.zeros(len(features_en_0_new))), axis = 0)
# Out:
# ('C value =', 1, 'position:', [955])

# %%
from sklearn.metrics import classification_report
y_pred_test2 = model_lstm2.predict([X1_test_new, X2_test_new])
print "classification report of TEST-2L-e data:"
print(classification_report(y_test_new, y_pred_test2>0.5))
# Out:
# classification report of TEST-2L-e data:
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.87      0.91      1000
#         1.0       0.88      0.96      0.92      1000
#
# avg / total       0.92      0.92      0.92      2000

# %%
len(features_en_0_new)
# Out:
# 1000

# %%
model_lstm2.save("./cl-model/lstm-long-model")

# %%
print "the statistics for TEST-1L"
for i in [1,5,10]:
    print "TOP", i, sum(np.array(rank_results_test)<=i)
print "the statistics for TEST-2L"
for i in [1,5,10]:
    print "TOP", i, sum(np.array(rank_results_test2)<=i)
# Out:
# the statistics for TEST-1L
# TOP 1 61
# TOP 5 284
# TOP 10 456
# the statistics for TEST-2L
# TOP 1 58
# TOP 5 278
# TOP 10 432
