# %%
run baseline_proj.py
# Out:
# [INFO]Reading the word2vec vectors in  en  from  ./data_baseline/good_vecs_en.csv ---
# [INFO]Reading the word2vec vectors in  jp  from  ./data_baseline/good_vecs_jp.csv ---
# [DEBUG] inv(JTJ)*JTJ=I?:
# [DEBUG] [[  1.00000000e+00   1.91963307e-12   2.35026415e-12 ...,   5.48230575e-14
#    -2.53620143e-12  -7.09088496e-13]
#  [ -3.74589285e-12   1.00000000e+00   3.80477022e-13 ...,   9.39741479e-13
#    -3.94819303e-14  -5.11707022e-12]
#  [  4.28733291e-12   2.59181811e-12   1.00000000e+00 ...,  -3.91510958e-13
#    -1.27291775e-12  -4.87672564e-13]
#  ...,
#  [  2.31703545e-12   8.51610359e-13   6.83905426e-14 ...,   1.00000000e+00
#     2.60250195e-13   4.87370210e-13]
#  [  1.68333263e-12  -4.30644827e-13  -3.41771696e-12 ...,   5.35846248e-13
#     1.00000000e+00  -3.86998816e-13]
#  [ -1.53319589e-12   5.53895644e-13   1.69822493e-12 ...,  -4.54747351e-13
#    -1.36424205e-12   1.00000000e+00]]
# Reading english Data: 63386
# Reading english Data: 63386
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    63340
# True         3
# Name: en_article, dtype: int64
# Now the maxlen = 0
# Starting to training the model..., saving to weights/proj/20170320_e50_4000_b64.p
# Training
# the length of the training data is  8000
# Batchsize = 128
# max_epochs = 50
# Before trianing, the error is:
# Training error: 0.285438090563
# Training_correct error 0.452831834555
# Testing_correct error: 0.462717562914
# top- 1 = [3] : 3
# top- 5 = [8] : 8
# top- 10 = [17] : 17
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean     1724.484375
# std      1249.377203
# min         1.000000
# 25%       507.250000
# 50%      1517.250000
# 75%      2871.000000
# max      3998.000000
# dtype: float64
# top- 1 = [2] : 2
# top- 5 = [11] : 11
# top- 10 = [30] : 30
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      466.209500
# std       292.690919
# min         1.000000
# 25%       207.375000
# 50%       452.000000
# 75%       728.500000
# max       998.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  21 Cost  0.21845176816
# Epoch  0 Update  42 Cost  0.209820866585
# Epoch  0 Update  63 Cost  0.208747431636
# Epoch  0 Update  84 Cost  0.210478678346
# Epoch  0 Update  105 Cost  0.207644730806
# Training error: 0.175022616982
# Training_correct error 0.213600188494
# Testing_correct error: 0.247879847884
# top- 1 = [3, 7] : 7
# top- 5 = [8, 58] : 58
# top- 10 = [17, 114] : 114
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      710.052500
# std       710.700647
# min         1.000000
# 25%       164.625000
# 50%       441.000000
# 75%      1050.000000
# max      3998.000000
# dtype: float64
# top- 1 = [2, 5] : 5
# top- 5 = [11, 43] : 43
# top- 10 = [30, 68] : 68
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      231.939000
# std       208.639658
# min         1.000000
# 25%        67.875000
# 50%       173.000000
# 75%       343.500000
# max       999.000000
# dtype: float64
# epoch took: 257.894371986
#
# Epoch 1 ...
# Epoch  1 Update  126 Cost  0.147241905332
# Epoch  1 Update  147 Cost  0.199921548367
# Epoch  1 Update  168 Cost  0.188631266356
# Epoch  1 Update  189 Cost  0.187534064054
# Epoch  1 Update  210 Cost  0.148796975613
# Epoch  1 Update  231 Cost  0.169364154339
# Training error: 0.143999949098
# Training_correct error 0.183864802122
# Testing_correct error: 0.216220170259
# top- 1 = [3, 7, 19] : 19
# top- 5 = [8, 58, 116] : 116
# top- 10 = [17, 114, 182] : 182
# Discription of evaluation (ranking) for training data:
# count    4000.00000
# mean      427.49750
# std       471.59735
# min         1.00000
# 25%        85.00000
# 50%       254.00000
# 75%       586.00000
# max      3997.00000
# dtype: float64
# top- 1 = [2, 5, 12] : 12
# top- 5 = [11, 43, 54] : 54
# top- 10 = [30, 68, 80] : 80
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      141.876000
# std       141.876872
# min         1.000000
# 25%        33.375000
# 50%        96.000000
# 75%       219.125000
# max      1000.000000
# dtype: float64
# epoch took: 260.231648922
#
# Epoch 2 ...
# Epoch  2 Update  252 Cost  0.141048938036
# Epoch  2 Update  273 Cost  0.156762316823
# Epoch  2 Update  294 Cost  0.153831362724
# Epoch  2 Update  315 Cost  0.1187402457
# Epoch  2 Update  336 Cost  0.161492198706
# Epoch  2 Update  357 Cost  0.122316382825
# Training error: 0.131312265992
# Training_correct error 0.153284147382
# Testing_correct error: 0.186569184065
# top- 1 = [3, 7, 19, 16] : 16
# top- 5 = [8, 58, 116, 112] : 112
# top- 10 = [17, 114, 182, 195] : 195
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      369.894750
# std       405.014625
# min         1.000000
# 25%        85.000000
# 50%       248.250000
# 75%       486.125000
# max      3491.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13] : 13
# top- 5 = [11, 43, 54, 53] : 53
# top- 10 = [30, 68, 80, 100] : 100
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      118.346000
# std       126.730402
# min         1.000000
# 25%        26.375000
# 50%        77.500000
# 75%       174.000000
# max       937.000000
# dtype: float64
# epoch took: 251.174807072
#
# Epoch 3 ...
# Epoch  3 Update  378 Cost  0.129247426987
# Epoch  3 Update  399 Cost  0.127808913589
# Epoch  3 Update  420 Cost  0.126292228699
# Epoch  3 Update  441 Cost  0.163434118032
# Epoch  3 Update  462 Cost  0.12967133522
# Epoch  3 Update  483 Cost  0.130066946149
# Training error: 0.12150080502
# Training_correct error 0.131598383188
# Testing_correct error: 0.16435469687
# top- 1 = [3, 7, 19, 16, 28] : 28
# top- 5 = [8, 58, 116, 112, 112] : 112
# top- 10 = [17, 114, 182, 195, 202] : 202
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      300.428750
# std       342.241491
# min         1.000000
# 25%        76.750000
# 50%       198.250000
# 75%       423.000000
# max      3994.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19] : 19
# top- 5 = [11, 43, 54, 53, 70] : 70
# top- 10 = [30, 68, 80, 100, 128] : 128
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean      100.867000
# std       113.708636
# min         1.000000
# 25%        26.000000
# 50%        65.250000
# 75%       134.500000
# max       900.500000
# dtype: float64
# epoch took: 253.16247201
#
# Epoch 4 ...
# Epoch  4 Update  504 Cost  0.150614872575
# Epoch  4 Update  525 Cost  0.121806770563
# Epoch  4 Update  546 Cost  0.134479671717
# Epoch  4 Update  567 Cost  0.142308697104
# Epoch  4 Update  588 Cost  0.11790741235
# Epoch  4 Update  609 Cost  0.124740466475
# Training error: 0.113107345998
# Training_correct error 0.120825275779
# Testing_correct error: 0.149987027049
# top- 1 = [3, 7, 19, 16, 28, 26] : 26
# top- 5 = [8, 58, 116, 112, 112, 134] : 134
# top- 10 = [17, 114, 182, 195, 202, 229] : 229
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      272.893875
# std       317.757356
# min         1.000000
# 25%        69.000000
# 50%       170.500000
# 75%       379.125000
# max      3584.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69] : 69
# top- 10 = [30, 68, 80, 100, 128, 132] : 132
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       92.375000
# std       101.784928
# min         1.000000
# 25%        21.000000
# 50%        58.000000
# 75%       123.500000
# max       747.500000
# dtype: float64
# epoch took: 255.35078001
#
# Epoch 5 ...
# Epoch  5 Update  630 Cost  0.10904353112
# Epoch  5 Update  651 Cost  0.100192293525
# Epoch  5 Update  672 Cost  0.139901548624
# Epoch  5 Update  693 Cost  0.119266360998
# Epoch  5 Update  714 Cost  0.146963968873
# Epoch  5 Update  735 Cost  0.167842537165
# Training error: 0.108779005706
# Training_correct error 0.122531987727
# Testing_correct error: 0.157167062163
# top- 1 = [3, 7, 19, 16, 28, 26, 30] : 30
# top- 5 = [8, 58, 116, 112, 112, 134, 150] : 150
# top- 10 = [17, 114, 182, 195, 202, 229, 263] : 263
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      252.254000
# std       297.356149
# min         1.000000
# 25%        58.000000
# 50%       157.000000
# 75%       352.000000
# max      3358.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12] : 12
# top- 5 = [11, 43, 54, 53, 70, 69, 76] : 76
# top- 10 = [30, 68, 80, 100, 128, 132, 147] : 147
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       83.532000
# std        93.761245
# min         1.000000
# 25%        18.000000
# 50%        53.750000
# 75%       113.125000
# max       662.000000
# dtype: float64
# epoch took: 250.474764824
#
# Epoch 6 ...
# Epoch  6 Update  756 Cost  0.10921304673
# Epoch  6 Update  777 Cost  0.0904427915812
# Epoch  6 Update  798 Cost  0.109962843359
# Epoch  6 Update  819 Cost  0.109279870987
# Epoch  6 Update  840 Cost  0.116396710277
# Epoch  6 Update  861 Cost  0.128116309643
# Training error: 0.104559928179
# Training_correct error 0.121624499559
# Testing_correct error: 0.160366490483
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22] : 22
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138] : 138
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250] : 250
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      246.063000
# std       285.651606
# min         1.000000
# 25%        57.000000
# 50%       152.750000
# 75%       346.500000
# max      3329.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13] : 13
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70] : 70
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159] : 159
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       85.203000
# std        97.812735
# min         1.000000
# 25%        19.000000
# 50%        54.500000
# 75%       113.000000
# max       708.500000
# dtype: float64
# epoch took: 246.89234519
#
# Epoch 7 ...
# Epoch  7 Update  882 Cost  0.0922960042953
# Epoch  7 Update  903 Cost  0.118055909872
# Epoch  7 Update  924 Cost  0.129344552755
# Epoch  7 Update  945 Cost  0.104515098035
# Epoch  7 Update  966 Cost  0.123167350888
# Epoch  7 Update  987 Cost  0.1022285074
# Training error: 0.107940092683
# Training_correct error 0.128373324871
# Testing_correct error: 0.162319868803
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16] : 16
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131] : 131
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247] : 247
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      250.896250
# std       292.190771
# min         1.000000
# 25%        59.000000
# 50%       153.250000
# 75%       346.000000
# max      3384.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16] : 16
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86] : 86
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166] : 166
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       82.807000
# std        93.843014
# min         1.000000
# 25%        17.000000
# 50%        53.000000
# 75%       111.750000
# max       635.000000
# dtype: float64
# epoch took: 247.594173193
#
# Epoch 8 ...
# Epoch  8 Update  1008 Cost  0.0944165959954
# Epoch  8 Update  1029 Cost  0.0987976044416
# Epoch  8 Update  1050 Cost  0.0807317346334
# Epoch  8 Update  1071 Cost  0.101280078292
# Epoch  8 Update  1092 Cost  0.111856564879
# Epoch  8 Update  1113 Cost  0.0862399563193
# Training error: 0.0990503132343
# Training_correct error 0.112099424005
# Testing_correct error: 0.149171754718
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27] : 27
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159] : 159
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269] : 269
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      225.757750
# std       263.227206
# min         1.000000
# 25%        52.500000
# 50%       141.500000
# 75%       308.125000
# max      3345.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19] : 19
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99] : 99
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180] : 180
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       78.911000
# std        89.271908
# min         1.000000
# 25%        18.000000
# 50%        53.000000
# 75%       105.125000
# max       793.500000
# dtype: float64
# epoch took: 254.036314964
#
# Epoch 9 ...
# Epoch  9 Update  1134 Cost  0.0922966971993
# Epoch  9 Update  1155 Cost  0.123904660344
# Epoch  9 Update  1176 Cost  0.075028270483
# Epoch  9 Update  1197 Cost  0.110590554774
# Epoch  9 Update  1218 Cost  0.104771487415
# Epoch  9 Update  1239 Cost  0.0983023792505
# Training error: 0.103589572012
# Training_correct error 0.120302520692
# Testing_correct error: 0.164371758699
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22] : 22
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121] : 121
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238] : 238
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      259.385750
# std       292.225306
# min         1.000000
# 25%        61.875000
# 50%       172.750000
# 75%       371.625000
# max      3251.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14] : 14
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79] : 79
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149] : 149
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       94.974000
# std       111.183709
# min         1.000000
# 25%        22.375000
# 50%        57.500000
# 75%       126.500000
# max       952.500000
# dtype: float64
# epoch took: 253.17057991
#
# Epoch 10 ...
# Epoch  10 Update  1260 Cost  0.105357259512
# Epoch  10 Update  1281 Cost  0.0972587838769
# Epoch  10 Update  1302 Cost  0.0917907953262
# Epoch  10 Update  1323 Cost  0.0847927629948
# Epoch  10 Update  1344 Cost  0.0956434160471
# Epoch  10 Update  1365 Cost  0.0760318487883
# Training error: 0.105029575527
# Training_correct error 0.104605130851
# Testing_correct error: 0.13967962563
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25] : 25
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113] : 113
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216] : 216
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      248.283000
# std       283.170462
# min         1.000000
# 25%        60.500000
# 50%       160.000000
# 75%       334.000000
# max      3453.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95] : 95
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155] : 155
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       86.003000
# std        96.413207
# min         1.000000
# 25%        19.500000
# 50%        55.000000
# 75%       113.250000
# max       759.500000
# dtype: float64
# epoch took: 249.867516994
#
# Epoch 11 ...
# Epoch  11 Update  1386 Cost  0.0866064578295
# Epoch  11 Update  1407 Cost  0.104932740331
# Epoch  11 Update  1428 Cost  0.0923819094896
# Epoch  11 Update  1449 Cost  0.0930134356022
# Epoch  11 Update  1470 Cost  0.110512547195
# Epoch  11 Update  1491 Cost  0.125368818641
# Training error: 0.0981290563941
# Training_correct error 0.106716193259
# Testing_correct error: 0.144401550293
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28] : 28
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166] : 166
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318] : 318
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      236.504750
# std       280.658826
# min         1.000000
# 25%        51.000000
# 50%       145.000000
# 75%       327.500000
# max      3376.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21] : 21
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92] : 92
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164] : 164
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       78.852000
# std        88.184441
# min         1.000000
# 25%        18.000000
# 50%        51.500000
# 75%       109.000000
# max       644.500000
# dtype: float64
# epoch took: 252.530745029
#
# Epoch 12 ...
# Epoch  12 Update  1512 Cost  0.0610847473145
# Epoch  12 Update  1533 Cost  0.128263384104
# Epoch  12 Update  1554 Cost  0.066406160593
# Epoch  12 Update  1575 Cost  0.121131904423
# Epoch  12 Update  1596 Cost  0.105730928481
# Epoch  12 Update  1617 Cost  0.101244837046
# Training error: 0.0986579507589
# Training_correct error 0.105970107019
# Testing_correct error: 0.143369436264
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33] : 33
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162] : 162
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278] : 278
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      238.617625
# std       280.083675
# min         1.000000
# 25%        52.000000
# 50%       144.000000
# 75%       321.000000
# max      3204.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20] : 20
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92] : 92
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150] : 150
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       77.717000
# std        84.494291
# min         1.000000
# 25%        19.000000
# 50%        50.000000
# 75%       111.125000
# max       657.500000
# dtype: float64
# epoch took: 252.260571957
#
# Epoch 13 ...
# Epoch  13 Update  1638 Cost  0.130983382463
# Epoch  13 Update  1659 Cost  0.092377781868
# Epoch  13 Update  1680 Cost  0.11204020679
# Epoch  13 Update  1701 Cost  0.114721618593
# Epoch  13 Update  1722 Cost  0.069347448647
# Epoch  13 Update  1743 Cost  0.111718960106
# Training error: 0.0938372761011
# Training_correct error 0.103589035571
# Testing_correct error: 0.143940940499
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30] : 30
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166] : 166
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309] : 309
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      227.857750
# std       262.151609
# min         1.000000
# 25%        50.000000
# 50%       139.000000
# 75%       324.000000
# max      3140.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84] : 84
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154] : 154
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       80.980000
# std        93.414206
# min         1.000000
# 25%        20.000000
# 50%        50.750000
# 75%       107.125000
# max       828.500000
# dtype: float64
# epoch took: 250.181006193
#
# Epoch 14 ...
# Epoch  14 Update  1764 Cost  0.107083879411
# Epoch  14 Update  1785 Cost  0.0941385701299
# Epoch  14 Update  1806 Cost  0.0928194373846
# Epoch  14 Update  1827 Cost  0.106013968587
# Epoch  14 Update  1848 Cost  0.105042673647
# Epoch  14 Update  1869 Cost  0.149359688163
# Training error: 0.0913902297616
# Training_correct error 0.0892898887396
# Testing_correct error: 0.123546600342
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28] : 28
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176] : 176
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309] : 309
# Discription of evaluation (ranking) for training data:
# count    4000.00000
# mean      205.55850
# std       243.34017
# min         1.00000
# 25%        44.50000
# 50%       119.00000
# 75%       275.00000
# max      3213.00000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16] : 16
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85] : 85
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175] : 175
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       70.695000
# std        80.211488
# min         1.000000
# 25%        15.500000
# 50%        44.000000
# 75%        96.250000
# max       602.000000
# dtype: float64
# epoch took: 253.468251944
#
# Epoch 15 ...
# Epoch  15 Update  1890 Cost  0.0628872364759
# Epoch  15 Update  1911 Cost  0.104055926204
# Epoch  15 Update  1932 Cost  0.0872994661331
# Epoch  15 Update  1953 Cost  0.108464501798
# Epoch  15 Update  1974 Cost  0.110522985458
# Epoch  15 Update  1995 Cost  0.106629043818
# Training error: 0.0933742970228
# Training_correct error 0.104551225901
# Testing_correct error: 0.148938983679
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24] : 24
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144] : 144
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270] : 270
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      227.377750
# std       260.993179
# min         1.000000
# 25%        50.000000
# 50%       136.000000
# 75%       318.000000
# max      3319.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19] : 19
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76] : 76
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135] : 135
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       79.877000
# std        92.863294
# min         1.000000
# 25%        19.500000
# 50%        46.500000
# 75%       110.000000
# max       765.500000
# dtype: float64
# epoch took: 251.830914021
#
# Epoch 16 ...
# Epoch  16 Update  2016 Cost  0.101291306317
# Epoch  16 Update  2037 Cost  0.0781591683626
# Epoch  16 Update  2058 Cost  0.10733230412
# Epoch  16 Update  2079 Cost  0.0826858729124
# Epoch  16 Update  2100 Cost  0.0946256369352
# Epoch  16 Update  2121 Cost  0.0991135537624
# Training error: 0.0921997353435
# Training_correct error 0.0993159338832
# Testing_correct error: 0.14095941186
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26] : 26
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149] : 149
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283] : 283
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      221.424625
# std       256.019261
# min         1.000000
# 25%        50.000000
# 50%       136.750000
# 75%       301.500000
# max      3212.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19] : 19
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78] : 78
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140] : 140
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       81.560000
# std       103.229064
# min         1.000000
# 25%        19.000000
# 50%        48.000000
# 75%       105.625000
# max       877.500000
# dtype: float64
# epoch took: 249.70837307
#
# Epoch 17 ...
# Epoch  17 Update  2142 Cost  0.107315033674
# Epoch  17 Update  2163 Cost  0.105980075896
# Epoch  17 Update  2184 Cost  0.100180096924
# Epoch  17 Update  2205 Cost  0.0728528425097
# Epoch  17 Update  2226 Cost  0.0881363004446
# Epoch  17 Update  2247 Cost  0.0724478065968
# Training error: 0.0884627699852
# Training_correct error 0.0967183038592
# Testing_correct error: 0.137962609529
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28] : 28
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171] : 171
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326] : 326
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      204.764000
# std       237.136861
# min         1.000000
# 25%        44.000000
# 50%       117.000000
# 75%       281.000000
# max      3134.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20] : 20
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84] : 84
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158] : 158
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.349000
# std        85.872885
# min         1.000000
# 25%        18.000000
# 50%        44.750000
# 75%        97.000000
# max       703.500000
# dtype: float64
# epoch took: 249.797944069
#
# Epoch 18 ...
# Epoch  18 Update  2268 Cost  0.104687720537
# Epoch  18 Update  2289 Cost  0.104912266135
# Epoch  18 Update  2310 Cost  0.076697871089
# Epoch  18 Update  2331 Cost  0.108656123281
# Epoch  18 Update  2352 Cost  0.0956315472722
# Epoch  18 Update  2373 Cost  0.0953576639295
# Training error: 0.086412884295
# Training_correct error 0.0988144725561
# Testing_correct error: 0.150062561035
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31] : 31
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195] : 195
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326] : 326
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      206.426000
# std       239.961153
# min         1.000000
# 25%        42.000000
# 50%       122.750000
# 75%       284.000000
# max      2795.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14] : 14
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72] : 72
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154] : 154
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       77.379000
# std        95.216703
# min         1.000000
# 25%        19.000000
# 50%        45.000000
# 75%       100.625000
# max       895.000000
# dtype: float64
# epoch took: 247.196898937
#
# Epoch 19 ...
# Epoch  19 Update  2394 Cost  0.0803737640381
# Epoch  19 Update  2415 Cost  0.0928016379476
# Epoch  19 Update  2436 Cost  0.105912283063
# Epoch  19 Update  2457 Cost  0.067954108119
# Epoch  19 Update  2478 Cost  0.0823752135038
# Epoch  19 Update  2499 Cost  0.125935554504
# Training error: 0.085894420743
# Training_correct error 0.0911588743329
# Testing_correct error: 0.135822504759
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36] : 36
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187] : 187
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340] : 340
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      196.112375
# std       230.569331
# min         1.000000
# 25%        41.000000
# 50%       115.500000
# 75%       262.250000
# max      2866.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22] : 22
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93] : 93
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167] : 167
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       71.138000
# std        86.729758
# min         1.000000
# 25%        17.000000
# 50%        44.250000
# 75%        94.125000
# max       978.000000
# dtype: float64
# epoch took: 250.255216122
#
# Epoch 20 ...
# Epoch  20 Update  2520 Cost  0.0916276201606
# Epoch  20 Update  2541 Cost  0.0785704553127
# Epoch  20 Update  2562 Cost  0.0943355932832
# Epoch  20 Update  2583 Cost  0.108098715544
# Epoch  20 Update  2604 Cost  0.106922708452
# Epoch  20 Update  2625 Cost  0.105368167162
# Training error: 0.0848928391933
# Training_correct error 0.0956523865461
# Testing_correct error: 0.141724303365
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34] : 34
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201] : 201
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359] : 359
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      193.200000
# std       230.957441
# min         1.000000
# 25%        37.500000
# 50%       110.000000
# 75%       256.000000
# max      2830.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20] : 20
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90] : 90
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174] : 174
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       70.577000
# std        85.449551
# min         1.000000
# 25%        16.000000
# 50%        43.000000
# 75%        92.625000
# max       961.000000
# dtype: float64
# epoch took: 249.703888893
#
# Epoch 21 ...
# Epoch  21 Update  2646 Cost  0.0835552215576
# Epoch  21 Update  2667 Cost  0.0543085150421
# Epoch  21 Update  2688 Cost  0.11044293642
# Epoch  21 Update  2709 Cost  0.0989188998938
# Epoch  21 Update  2730 Cost  0.0697517320514
# Training error: 0.0834003314376
# Training_correct error 0.0956675484776
# Testing_correct error: 0.140785649419
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31] : 31
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191] : 191
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360] : 360
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      193.401250
# std       226.601948
# min         1.000000
# 25%        39.500000
# 50%       111.500000
# 75%       261.125000
# max      2714.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109] : 109
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197] : 197
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       68.408000
# std        81.639614
# min         1.000000
# 25%        14.375000
# 50%        42.500000
# 75%        93.000000
# max       956.000000
# dtype: float64
# epoch took: 253.352775097
#
# Epoch 22 ...
# Epoch  22 Update  2751 Cost  0.087279714644
# Epoch  22 Update  2772 Cost  0.117316834629
# Epoch  22 Update  2793 Cost  0.0758201479912
# Epoch  22 Update  2814 Cost  0.0790335983038
# Epoch  22 Update  2835 Cost  0.0737578868866
# Epoch  22 Update  2856 Cost  0.0856459438801
# Training error: 0.0866751000285
# Training_correct error 0.088246755302
# Testing_correct error: 0.12973511219
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34] : 34
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199] : 199
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331] : 331
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      197.582750
# std       226.299572
# min         1.000000
# 25%        46.875000
# 50%       121.500000
# 75%       254.500000
# max      2300.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16] : 16
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98] : 98
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173] : 173
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       72.45400
# std        88.17017
# min         1.00000
# 25%        16.50000
# 50%        45.00000
# 75%        95.62500
# max       988.00000
# dtype: float64
# epoch took: 250.985614777
#
# Epoch 23 ...
# Epoch  23 Update  2877 Cost  0.108239874244
# Epoch  23 Update  2898 Cost  0.112656459212
# Epoch  23 Update  2919 Cost  0.126538813114
# Epoch  23 Update  2940 Cost  0.0768421143293
# Epoch  23 Update  2961 Cost  0.0902097374201
# Epoch  23 Update  2982 Cost  0.10615362972
# Training error: 0.0869683548808
# Training_correct error 0.0980277433991
# Testing_correct error: 0.148692175746
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29] : 29
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182] : 182
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347] : 347
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      196.469000
# std       227.556628
# min         1.000000
# 25%        41.000000
# 50%       117.000000
# 75%       264.000000
# max      2604.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24] : 24
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89] : 89
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149] : 149
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       74.368000
# std        90.230217
# min         1.000000
# 25%        18.000000
# 50%        46.000000
# 75%        93.250000
# max       862.500000
# dtype: float64
# epoch took: 243.093273163
#
# Epoch 24 ...
# Epoch  24 Update  3003 Cost  0.0855725780129
# Epoch  24 Update  3024 Cost  0.0653682947159
# Epoch  24 Update  3045 Cost  0.0728671550751
# Epoch  24 Update  3066 Cost  0.0741753429174
# Epoch  24 Update  3087 Cost  0.0923785418272
# Epoch  24 Update  3108 Cost  0.0753875374794
# Training error: 0.0809899643064
# Training_correct error 0.0811730623245
# Testing_correct error: 0.127247869968
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31] : 31
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187] : 187
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371] : 371
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      190.012000
# std       225.951444
# min         1.000000
# 25%        37.000000
# 50%       112.750000
# 75%       254.000000
# max      2607.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23] : 23
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100] : 100
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165] : 165
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       70.131000
# std        83.595568
# min         1.000000
# 25%        17.000000
# 50%        44.000000
# 75%        93.125000
# max       975.000000
# dtype: float64
# epoch took: 244.939687014
#
# Epoch 25 ...
# Epoch  25 Update  3129 Cost  0.0816129595041
# Epoch  25 Update  3150 Cost  0.0828391313553
# Epoch  25 Update  3171 Cost  0.0807261615992
# Epoch  25 Update  3192 Cost  0.0873966664076
# Epoch  25 Update  3213 Cost  0.0966942161322
# Epoch  25 Update  3234 Cost  0.0951204150915
# Training error: 0.082835264504
# Training_correct error 0.0973986461759
# Testing_correct error: 0.148829594254
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34] : 34
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188] : 188
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342] : 342
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      188.167000
# std       218.482986
# min         1.000000
# 25%        40.000000
# 50%       108.000000
# 75%       254.000000
# max      2399.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101] : 101
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174] : 174
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       69.120000
# std        82.289113
# min         1.000000
# 25%        16.000000
# 50%        41.250000
# 75%        94.125000
# max       907.000000
# dtype: float64
# epoch took: 243.570849895
#
# Epoch 26 ...
# Epoch  26 Update  3255 Cost  0.0812874957919
# Epoch  26 Update  3276 Cost  0.160840973258
# Epoch  26 Update  3297 Cost  0.0730645209551
# Epoch  26 Update  3318 Cost  0.0642713680863
# Epoch  26 Update  3339 Cost  0.080064162612
# Epoch  26 Update  3360 Cost  0.0589378923178
# Training error: 0.0796700119972
# Training_correct error 0.0879486352205
# Testing_correct error: 0.138036444783
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40] : 40
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187] : 187
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392] : 392
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      181.042750
# std       215.842671
# min         1.000000
# 25%        34.500000
# 50%        99.000000
# 75%       254.000000
# max      2446.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21] : 21
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102] : 102
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170] : 170
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       67.482000
# std        79.886617
# min         1.000000
# 25%        15.000000
# 50%        41.000000
# 75%        94.125000
# max       967.000000
# dtype: float64
# epoch took: 243.767152071
#
# Epoch 27 ...
# Epoch  27 Update  3381 Cost  0.0912469029427
# Epoch  27 Update  3402 Cost  0.0840065702796
# Epoch  27 Update  3423 Cost  0.115656144917
# Epoch  27 Update  3444 Cost  0.0874334424734
# Epoch  27 Update  3465 Cost  0.0613488964736
# Epoch  27 Update  3486 Cost  0.101410344243
# Training error: 0.080005183816
# Training_correct error 0.0891797319055
# Testing_correct error: 0.138917386532
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22] : 22
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179] : 179
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352] : 352
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      191.404500
# std       221.640034
# min         1.000000
# 25%        39.000000
# 50%       108.750000
# 75%       261.000000
# max      2332.500000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22] : 22
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91] : 91
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167] : 167
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       70.84600
# std        83.17693
# min         1.00000
# 25%        16.00000
# 50%        44.00000
# 75%        95.00000
# max       917.00000
# dtype: float64
# epoch took: 244.235814095
#
# Epoch 28 ...
# Epoch  28 Update  3507 Cost  0.0597625821829
# Epoch  28 Update  3528 Cost  0.0904465466738
# Epoch  28 Update  3549 Cost  0.0693819820881
# Epoch  28 Update  3570 Cost  0.0898500084877
# Epoch  28 Update  3591 Cost  0.103322729468
# Epoch  28 Update  3612 Cost  0.0699833035469
# Training error: 0.0828290432692
# Training_correct error 0.0852350667119
# Testing_correct error: 0.131312519312
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34] : 34
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192] : 192
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331] : 331
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      194.518875
# std       230.381360
# min         1.000000
# 25%        40.000000
# 50%       108.500000
# 75%       256.500000
# max      2297.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96] : 96
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166] : 166
# Discription of evaluation (ranking) for testing data:
# count    1000.00000
# mean       68.47500
# std        78.38278
# min         1.00000
# 25%        15.50000
# 50%        44.00000
# 75%        90.00000
# max       695.50000
# dtype: float64
# epoch took: 244.695760965
#
# Epoch 29 ...
# Epoch  29 Update  3633 Cost  0.0605844408274
# Epoch  29 Update  3654 Cost  0.0753406733274
# Epoch  29 Update  3675 Cost  0.0850922614336
# Epoch  29 Update  3696 Cost  0.0791645795107
# Epoch  29 Update  3717 Cost  0.0840876623988
# Epoch  29 Update  3738 Cost  0.0867354795337
# Training error: 0.0800518169999
# Training_correct error 0.0826210305095
# Testing_correct error: 0.132065400481
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30] : 30
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184] : 184
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358] : 358
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      190.650500
# std       216.017247
# min         1.000000
# 25%        40.000000
# 50%       113.000000
# 75%       260.500000
# max      2087.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98] : 98
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171] : 171
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       75.070000
# std        94.827297
# min         1.000000
# 25%        17.000000
# 50%        43.000000
# 75%        97.125000
# max       960.000000
# dtype: float64
# epoch took: 243.907490015
#
# Epoch 30 ...
# Epoch  30 Update  3759 Cost  0.0806648209691
# Epoch  30 Update  3780 Cost  0.0478856265545
# Epoch  30 Update  3801 Cost  0.0939734876156
# Epoch  30 Update  3822 Cost  0.101650871336
# Epoch  30 Update  3843 Cost  0.0564403831959
# Epoch  30 Update  3864 Cost  0.0490770488977
# Training error: 0.0795174539089
# Training_correct error 0.0869616121054
# Testing_correct error: 0.138365954161
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35] : 35
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183] : 183
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358] : 358
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      191.176750
# std       218.765785
# min         1.000000
# 25%        40.000000
# 50%       109.000000
# 75%       255.500000
# max      2376.500000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21] : 21
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104] : 104
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171] : 171
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.129000
# std        90.173497
# min         1.000000
# 25%        16.000000
# 50%        42.000000
# 75%        96.000000
# max       837.500000
# dtype: float64
# epoch took: 244.40279007
#
# Epoch 31 ...
# Epoch  31 Update  3885 Cost  0.105453923345
# Epoch  31 Update  3906 Cost  0.0578236728907
# Epoch  31 Update  3927 Cost  0.0921371355653
# Epoch  31 Update  3948 Cost  0.0712143629789
# Epoch  31 Update  3969 Cost  0.0624521225691
# Epoch  31 Update  3990 Cost  0.0729480832815
# Training error: 0.0812308192253
# Training_correct error 0.0842276141047
# Testing_correct error: 0.134764805436
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35] : 35
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194] : 194
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329] : 329
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      196.496750
# std       226.530906
# min         1.000000
# 25%        42.000000
# 50%       118.500000
# 75%       265.000000
# max      2321.500000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18] : 18
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80] : 80
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169] : 169
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       75.209000
# std        86.348152
# min         1.000000
# 25%        17.875000
# 50%        47.500000
# 75%       102.000000
# max       827.500000
# dtype: float64
# ...
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161] : 161
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.380000
# std        83.187853
# min         1.000000
# 25%        16.000000
# 50%        45.000000
# 75%        98.125000
# max       615.000000
# dtype: float64
# epoch took: 249.506257057
#
# Epoch 40 ...
# Epoch  40 Update  5019 Cost  0.0858498215675
# Epoch  40 Update  5040 Cost  0.0630429238081
# Epoch  40 Update  5061 Cost  0.0775053650141
# Epoch  40 Update  5082 Cost  0.0682787597179
# Epoch  40 Update  5103 Cost  0.0808642953634
# Epoch  40 Update  5124 Cost  0.0575118809938
# Training error: 0.0739757046103
# Training_correct error 0.0739882364869
# Testing_correct error: 0.135860905051
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28] : 28
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170] : 170
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347] : 347
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      178.318000
# std       220.228387
# min         1.000000
# 25%        38.375000
# 50%        98.250000
# 75%       254.000000
# max      2746.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18] : 18
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98] : 98
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157] : 157
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.611000
# std        87.004295
# min         1.000000
# 25%        18.000000
# 50%        44.500000
# 75%        97.000000
# max       835.000000
# dtype: float64
# epoch took: 244.401189804
#
# Epoch 41 ...
# Epoch  41 Update  5145 Cost  0.0453429967165
# Epoch  41 Update  5166 Cost  0.0992764905095
# Epoch  41 Update  5187 Cost  0.0605706050992
# Epoch  41 Update  5208 Cost  0.0779540091753
# Epoch  41 Update  5229 Cost  0.131978228688
# Epoch  41 Update  5250 Cost  0.0606312826276
# Training error: 0.0749573931098
# Training_correct error 0.074165083468
# Testing_correct error: 0.131138980389
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27] : 27
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192] : 192
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372] : 372
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      174.532250
# std       207.782058
# min         1.000000
# 25%        34.875000
# 50%        96.000000
# 75%       254.000000
# max      2639.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17] : 17
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84] : 84
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154] : 154
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       72.122000
# std        85.942692
# min         1.000000
# 25%        17.500000
# 50%        44.000000
# 75%        94.000000
# max       847.500000
# dtype: float64
# epoch took: 243.515936136
#
# Epoch 42 ...
# Epoch  42 Update  5271 Cost  0.0618120059371
# Epoch  42 Update  5292 Cost  0.0828299671412
# Epoch  42 Update  5313 Cost  0.0769891366363
# Epoch  42 Update  5334 Cost  0.0797508507967
# Epoch  42 Update  5355 Cost  0.0649464130402
# Training error: 0.0748016312718
# Training_correct error 0.0771874338388
# Testing_correct error: 0.135772287846
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27, 32] : 32
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192, 191] : 191
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372, 354] : 354
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      174.699000
# std       202.796147
# min         1.000000
# 25%        37.375000
# 50%        98.000000
# 75%       254.000000
# max      2003.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17, 22] : 22
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84, 94] : 94
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154, 164] : 164
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.100000
# std        89.458073
# min         1.000000
# 25%        16.500000
# 50%        43.000000
# 75%        99.000000
# max       851.500000
# dtype: float64
# epoch took: 248.638633013
#
# Epoch 43 ...
# Epoch  43 Update  5376 Cost  0.110623881221
# Epoch  43 Update  5397 Cost  0.0914756730199
# Epoch  43 Update  5418 Cost  0.0930030271411
# Epoch  43 Update  5439 Cost  0.0677630528808
# Epoch  43 Update  5460 Cost  0.0536750741303
# Epoch  43 Update  5481 Cost  0.0847671627998
# Training error: 0.085358992219
# Training_correct error 0.0918649733067
# Testing_correct error: 0.13056859374
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27, 32, 31] : 31
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192, 191, 176] : 176
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372, 354, 335] : 335
# Discription of evaluation (ranking) for training data:
# count    4000.00000
# mean      198.60675
# std       244.66914
# min         1.00000
# 25%        42.00000
# 50%       110.00000
# 75%       260.00000
# max      2763.00000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17, 22, 13] : 13
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84, 94, 72] : 72
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154, 164, 151] : 151
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       77.038000
# std        95.942736
# min         1.000000
# 25%        18.375000
# 50%        47.000000
# 75%       101.000000
# max       909.500000
# dtype: float64
# epoch took: 262.903198957
#
# Epoch 44 ...
# Epoch  44 Update  5502 Cost  0.0696545019746
# Epoch  44 Update  5523 Cost  0.0685597956181
# Epoch  44 Update  5544 Cost  0.0604855120182
# Epoch  44 Update  5565 Cost  0.0719439089298
# Epoch  44 Update  5586 Cost  0.093502946198
# Epoch  44 Update  5607 Cost  0.101074680686
# Training error: 0.0742453336716
# Training_correct error 0.07968685776
# Testing_correct error: 0.142479375005
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27, 32, 31, 32] : 32
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192, 191, 176, 194] : 194
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372, 354, 335, 383] : 383
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      180.400000
# std       214.548616
# min         1.000000
# 25%        36.000000
# 50%       102.000000
# 75%       254.000000
# max      2879.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17, 22, 13, 18] : 18
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84, 94, 72, 89] : 89
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154, 164, 151, 162] : 162
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       74.239000
# std        84.032371
# min         1.000000
# 25%        17.000000
# 50%        47.000000
# 75%       102.250000
# max       647.000000
# dtype: float64
# epoch took: 252.638581038
#
# Epoch 45 ...
# Epoch  45 Update  5628 Cost  0.0865880474448
# Epoch  45 Update  5649 Cost  0.0960983783007
# Epoch  45 Update  5670 Cost  0.0849598795176
# Epoch  45 Update  5691 Cost  0.0514366477728
# Epoch  45 Update  5712 Cost  0.0972960442305
# Epoch  45 Update  5733 Cost  0.0991544649005
# Training error: 0.0735885053873
# Training_correct error 0.0703603774309
# Testing_correct error: 0.130008101463
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27, 32, 31, 32, 42] : 42
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192, 191, 176, 194, 177] : 177
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372, 354, 335, 383, 372] : 372
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      176.635625
# std       218.682236
# min         1.000000
# 25%        37.500000
# 50%        97.250000
# 75%       254.000000
# max      2740.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17, 22, 13, 18, 14] : 14
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84, 94, 72, 89, 84] : 84
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154, 164, 151, 162, 164] : 164
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       73.666000
# std        84.364079
# min         1.000000
# 25%        19.375000
# 50%        44.500000
# 75%       102.500000
# max       753.500000
# dtype: float64
# epoch took: 247.203681946
#
# Epoch 46 ...
# Epoch  46 Update  5754 Cost  0.0751048177481
# Epoch  46 Update  5775 Cost  0.0554105676711
# Epoch  46 Update  5796 Cost  0.0668008551002
# Epoch  46 Update  5817 Cost  0.0808808356524
# Epoch  46 Update  5838 Cost  0.0877977460623
# Epoch  46 Update  5859 Cost  0.0904617086053
# Training error: 0.0714982077479
# Training_correct error 0.0714875757694
# Testing_correct error: 0.135054290295
# top- 1 = [3, 7, 19, 16, 28, 26, 30, 22, 16, 27, 22, 25, 28, 33, 30, 28, 24, 26, 28, 31, 36, 34, 31, 34, 29, 31, 34, 40, 22, 34, 30, 35, 35, 34, 25, 26, 30, 32, 30, 23, 31, 28, 27, 32, 31, 32, 42, 37] : 37
# top- 5 = [8, 58, 116, 112, 112, 134, 150, 138, 131, 159, 121, 113, 166, 162, 166, 176, 144, 149, 171, 195, 187, 201, 191, 199, 182, 187, 188, 187, 179, 192, 184, 183, 194, 199, 183, 192, 180, 191, 185, 198, 187, 170, 192, 191, 176, 194, 177, 218] : 218
# top- 10 = [17, 114, 182, 195, 202, 229, 263, 250, 247, 269, 238, 216, 318, 278, 309, 309, 270, 283, 326, 326, 340, 359, 360, 331, 347, 371, 342, 392, 352, 331, 358, 358, 329, 373, 336, 370, 356, 382, 353, 357, 376, 347, 372, 354, 335, 383, 372, 402] : 402
# Discription of evaluation (ranking) for training data:
# count    4000.000000
# mean      169.563250
# std       211.026905
# min         1.000000
# 25%        33.000000
# 50%        90.000000
# 75%       246.000000
# max      2921.000000
# dtype: float64
# top- 1 = [2, 5, 12, 13, 19, 17, 12, 13, 16, 19, 14, 17, 21, 20, 17, 16, 19, 19, 20, 14, 22, 20, 17, 16, 24, 23, 17, 21, 22, 17, 17, 21, 18, 16, 20, 17, 18, 17, 15, 22, 17, 18, 17, 22, 13, 18, 14, 16] : 16
# top- 5 = [11, 43, 54, 53, 70, 69, 76, 70, 86, 99, 79, 95, 92, 92, 84, 85, 76, 78, 84, 72, 93, 90, 109, 98, 89, 100, 101, 102, 91, 96, 98, 104, 80, 102, 85, 79, 83, 85, 94, 84, 96, 98, 84, 94, 72, 89, 84, 103] : 103
# top- 10 = [30, 68, 80, 100, 128, 132, 147, 159, 166, 180, 149, 155, 164, 150, 154, 175, 135, 140, 158, 154, 167, 174, 197, 173, 149, 165, 174, 170, 167, 166, 171, 171, 169, 176, 164, 159, 150, 159, 173, 163, 161, 157, 154, 164, 151, 162, 164, 185] : 185
# Discription of evaluation (ranking) for testing data:
# count    1000.000000
# mean       70.266000
# std        85.499002
# min         1.000000
# 25%        15.500000
# 50%        41.250000
# 75%        95.750000
# max       809.500000
# dtype: float64
# epoch took: 251.812783957
#
# Epoch 47 ...
# Epoch  47 Update  5880 Cost  0.088145211339
# Epoch  47 Update  5901 Cost  0.10887273401
# Epoch  47 Update  5922 Cost  0.062162488699

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(sls.tops[1],'r-', label = "TOP-1: Trianing")
plt.plot(sls.tops[5],'b-', label = "TOP-5: Trianing" )
plt.plot(sls.tops[10],'g-', label = "TOP-10: Trianing")
plt.plot(sls.tops_test[1],'r--', label = "TOP-1: Test")
plt.plot(sls.tops_test[5],'b--', label = "TOP-5: Test")
plt.plot(sls.tops_test[10],'g--', label = "TOP10: Test")
plt.ylabel('TOP Accuracy', fontsize=11)
plt.xlabel('Epoches', fontsize=11)
plt.title('TOP Accuracy vs Epoches')
plt.legend(loc = 2, fontsize=8)
plt.savefig('top1-5-10_e40_l0.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_train,'ro')
plt.title('TOP Ranking for training documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.ylim([1000,0])
plt.grid(True)
plt.savefig('top-training.eps', format='eps', dpi=1000)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['figure.figsize'] = (6.0, 2.0)
# matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.figsize'] = (15, 7)
plt.plot(rank_results_test,'bo')
plt.title('TOP Ranking for test documents (1-1000)')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
# plt.ylim([1000,0])
plt.ylim([532,0.5])
plt.grid(True)
plt.savefig('top-test.eps', format='eps', dpi=1000)
plt.show()

# %%
		print pd.Series(rank_results_train).describe()
		print pd.Series(rank_results_test).describe()
# Out:
# count    4000.00000
# mean      172.78200
# std       214.98174
# min         1.00000
# 25%        36.00000
# 50%        93.00000
# 75%       254.00000
# max      3167.00000
# dtype: float64
# count    1000.000000
# mean       75.242000
# std        94.022911
# min         1.000000
# 25%        18.000000
# 50%        42.500000
# 75%        98.625000
# max       875.500000
# dtype: float64
