# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the modle..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# (4.1240959, 0.095272966, 0.046075466722721184)
# Finish preparing the data!
# Finished embedding,start projecting...
# top: [] : 10
# Epoch 0 ...
# Epoch  0 Update  40 Cost  0.112757906318
# (2.0110817, 0.76414847, 0.75776556286056573)
# Finish preparing the data!
# Finished embedding,start projecting...
# top: [103] : 103
# epoch took: 60.8310480118
# Epoch 1 ...
# Epoch  1 Update  80 Cost  0.154227882624
# Epoch  1 Update  120 Cost  0.102236732841
# ...

# %%
# 这个sls.rank记录的精度是不对的，误差增大了一倍，现在已经被修复
for i in range(20):
    print "the results of epoch", i, ":"
    print pd.Series(sls.rank[i][:998]).describe()
# Out:
# the results of epoch 0 :
# count    998.000000
# mean     103.648297
# std      136.337764
# min        1.500000
# 25%       14.500000
# 50%       55.500000
# 75%      125.500000
# max      740.500000
# dtype: float64
# the results of epoch 1 :
# count    998.000000
# mean     103.785571
# std      135.316263
# min        1.500000
# 25%       13.500000
# 50%       43.500000
# 75%      145.000000
# max      647.500000
# dtype: float64
# the results of epoch 2 :
# count    998.000000
# mean      76.000000
# std      106.055716
# min        1.500000
# 25%        7.500000
# 50%       29.500000
# 75%      100.250000
# max      795.500000
# dtype: float64
# the results of epoch 3 :
# count    998.000000
# mean      75.280561
# std      115.215497
# min        1.500000
# 25%        6.500000
# 50%       31.500000
# 75%       83.500000
# max      755.500000
# dtype: float64
# the results of epoch 4 :
# count    998.000000
# mean      48.267535
# std       75.114931
# min        1.500000
# ...

# %%
sls.rank[i][:998]
# Out:
# [9.5,
#  15.5,
#  1.5,
#  2.5,
#  2.5,
#  1.5,
#  1.5,
#  1.5,
#  41.5,
#  1.5,
#  14.5,
#  3.5,
#  7.5,
#  1.5,
#  2.5,
#  1.5,
#  3.5,
#  9.5,
#  2.5,
#  5.5,
#  9.5,
#  68.5,
#  5.5,
#  1.5,
#  3.5,
#  15.5,
#  1.5,
#  3.5,
#  19.5,
#  33.5,
#  5.5,
#  1.5,
#  5.5,
#  1.5,
#  6.5,
#  5.5,
#  1.5,
#  1.5,
#  3.5,
#  3.5,
#  1.5,
#  9.5,
#  3.5,
#  1.5,
#  68.5,
#  2.5,
#  3.5,
#  1.5,
#  5.5,
#  9.5,
#  3.5,
#  1.5,
#  1.5,
#  2.5,
#  17.5,
#  5.5,
#  1.5,
#  1.5,
#  17.5,
#  5.5,
#  3.5,
#  3.5,
#  1.5,
#  5.5,
#  5.5,
#  1.5,
#  199.5,
#  2.5,
#  6.5,
#  2.5,
#  1.5,
#  6.5,
#  33.5,
#  2.5,
#  1.5,
#  1.5,
#  3.5,
#  1.5,
#  1.5,
#  2.5,
#  8.5,
#  33.5,
#  7.5,
#  3.5,
#  2.5,
#  1.5,
#  2.5,
#  8.5,
#  14.5,
#  1.5,
#  1.5,
#  2.5,
#  7.5,
#  13.5,
#  9.5,
#  4.5,
#  6.5,
#  5.5,
#  23.5,
#  1.5,
#  25.5,
#  51.5,
#  1.5,
#  3.5,
#  33.5,
#  7.5,
#  1.5,
#  3.5,
#  9.5,
#  2.5,
#  1.5,
#  13.5,
#  2.5,
#  17.5,
#  1.5,
#  6.5,
#  1.5,
#  1.5,
#  3.5,
#  75.5,
#  1.5,
#  8.5,
# ...

# %%
rank_results_train
# Out:
# [5.0,
#  8.0,
#  1.0,
#  1.5,
#  1.5,
#  1.0,
#  1.0,
#  1.0,
#  21.0,
#  1.0,
#  7.5,
#  2.0,
#  4.0,
#  1.0,
#  1.5,
#  1.0,
#  2.0,
#  5.0,
#  1.5,
#  3.0,
#  5.0,
#  34.5,
#  3.0,
#  1.0,
#  2.0,
#  8.0,
#  1.0,
#  2.0,
#  10.0,
#  17.0,
#  3.0,
#  1.0,
#  3.0,
#  1.0,
#  3.5,
#  3.0,
#  1.0,
#  1.0,
#  2.0,
#  2.0,
#  1.0,
#  5.0,
#  2.0,
#  1.0,
#  34.5,
#  1.5,
#  2.0,
#  1.0,
#  3.0,
#  5.0,
#  2.0,
#  1.0,
#  1.0,
#  1.5,
#  9.0,
#  3.0,
#  1.0,
#  1.0,
#  9.0,
#  3.0,
#  2.0,
#  2.0,
#  1.0,
#  3.0,
#  3.0,
#  1.0,
#  100.0,
#  1.5,
#  3.5,
#  1.5,
#  1.0,
#  3.5,
#  17.0,
#  1.5,
#  1.0,
#  1.0,
#  2.0,
#  1.0,
#  1.0,
#  1.5,
#  4.5,
#  17.0,
#  4.0,
#  2.0,
#  1.5,
#  1.0,
#  1.5,
#  4.5,
#  7.5,
#  1.0,
#  1.0,
#  1.5,
#  4.0,
#  7.0,
#  5.0,
#  2.5,
#  3.5,
#  3.0,
#  12.0,
#  1.0,
#  13.0,
#  26.0,
#  1.0,
#  2.0,
#  17.0,
#  4.0,
#  1.0,
#  2.0,
#  5.0,
#  1.5,
#  1.0,
#  7.0,
#  1.5,
#  9.0,
#  1.0,
#  3.5,
#  1.0,
#  1.0,
#  2.0,
#  38.0,
#  1.0,
#  4.5,
#  1.5,
# ...

# %%
sim_results_train[3]
# Out:
# array([  1.33067640e-02,   1.36164144e-01,   1.80685624e-01,
#          9.10717905e-01,   8.17174137e-01,   3.12454045e-01,
#          6.08398067e-03,   7.83817768e-02,   1.12365298e-01,
#          9.41847190e-02,   3.72573376e-01,   1.36063546e-02,
#          2.49640364e-02,   1.54106319e-01,   2.70841178e-02,
#          9.61761847e-02,   1.51333762e-02,   1.53069109e-01,
#          3.59074116e-01,   1.39547001e-05,   2.36534372e-01,
#          5.07331491e-01,   6.76578507e-02,   1.71287954e-01,
#          1.05969235e-01,   4.55066562e-02,   2.98235361e-02,
#          1.85133025e-01,   8.62451047e-02,   2.83597976e-01,
#          1.18034862e-01,   8.68205801e-02,   1.12397159e-02,
#          8.19843650e-01,   4.11878794e-01,   1.53966561e-01,
#          3.90874296e-02,   6.25597984e-02,   1.91835806e-01,
#          5.10083027e-02,   1.65459178e-02,   1.30264908e-01,
#          9.68440901e-03,   1.89534239e-02,   5.07331491e-01,
# ...

# %%
rank = pd.Series(sim_results_train[3]).rank(ascending = False)
print sim_results_train[3].max()
print sim_results_train[3]
print rank
# Out:
# 0.910718
# [  1.33067640e-02   1.36164144e-01   1.80685624e-01   9.10717905e-01
#    8.17174137e-01   3.12454045e-01   6.08398067e-03   7.83817768e-02
#    1.12365298e-01   9.41847190e-02   3.72573376e-01   1.36063546e-02
#    2.49640364e-02   1.54106319e-01   2.70841178e-02   9.61761847e-02
#    1.51333762e-02   1.53069109e-01   3.59074116e-01   1.39547001e-05
#    2.36534372e-01   5.07331491e-01   6.76578507e-02   1.71287954e-01
#    1.05969235e-01   4.55066562e-02   2.98235361e-02   1.85133025e-01
#    8.62451047e-02   2.83597976e-01   1.18034862e-01   8.68205801e-02
#    1.12397159e-02   8.19843650e-01   4.11878794e-01   1.53966561e-01
#    3.90874296e-02   6.25597984e-02   1.91835806e-01   5.10083027e-02
#    1.65459178e-02   1.30264908e-01   9.68440901e-03   1.89534239e-02
#    5.07331491e-01   2.70841178e-02   2.53850430e-01   3.66447657e-01
#    2.47853007e-02   3.78116071e-01   2.35142522e-02   7.92381689e-02
# ...

# %%
sls.rank[i]
# Out:
# [9.5,
#  15.5,
#  1.5,
#  2.5,
#  2.5,
#  1.5,
#  1.5,
#  1.5,
#  41.5,
#  1.5,
#  14.5,
#  3.5,
#  7.5,
#  1.5,
#  2.5,
#  1.5,
#  3.5,
#  9.5,
#  2.5,
#  5.5,
#  9.5,
#  68.5,
#  5.5,
#  1.5,
#  3.5,
#  15.5,
#  1.5,
#  3.5,
#  19.5,
#  33.5,
#  5.5,
#  1.5,
#  5.5,
#  1.5,
#  6.5,
#  5.5,
#  1.5,
#  1.5,
#  3.5,
#  3.5,
#  1.5,
#  9.5,
#  3.5,
#  1.5,
#  68.5,
#  2.5,
#  3.5,
#  1.5,
#  5.5,
#  9.5,
#  3.5,
#  1.5,
#  1.5,
#  2.5,
#  17.5,
#  5.5,
#  1.5,
#  1.5,
#  17.5,
#  5.5,
#  3.5,
#  3.5,
#  1.5,
#  5.5,
#  5.5,
#  1.5,
#  199.5,
#  2.5,
#  6.5,
#  2.5,
#  1.5,
#  6.5,
#  33.5,
#  2.5,
#  1.5,
#  1.5,
#  3.5,
#  1.5,
#  1.5,
#  2.5,
#  8.5,
#  33.5,
#  7.5,
#  3.5,
#  2.5,
#  1.5,
#  2.5,
#  8.5,
#  14.5,
#  1.5,
#  1.5,
#  2.5,
#  7.5,
#  13.5,
#  9.5,
#  4.5,
#  6.5,
#  5.5,
#  23.5,
#  1.5,
#  25.5,
#  51.5,
#  1.5,
#  3.5,
#  33.5,
#  7.5,
#  1.5,
#  3.5,
#  9.5,
#  2.5,
#  1.5,
#  13.5,
#  2.5,
#  17.5,
#  1.5,
#  6.5,
#  1.5,
#  1.5,
#  3.5,
#  75.5,
#  1.5,
#  8.5,
# ...

# %%
# 真正的误差在这里：
pd.Series(rank_results_train).describe()
# Out:
# count    999.000000
# mean       4.926927
# std        7.862557
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      100.000000
# dtype: float64

# %%
pd.Series(rank_results_test).describe()
# Out:
# count    1000.000000
# mean        6.672000
# std         9.635105
# min         1.000000
# 25%         1.500000
# 50%         3.000000
# 75%         7.000000
# max       109.000000
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_train,'ro')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_test,'bo')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()
