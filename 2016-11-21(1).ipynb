# %%
# coding: utf-8
# from lstm import *
import pandas as pd

dir_en = "./data/news/sample_cleaned2_tag_en.txt"
dir_jp = "./data/news/sample_cleaned2_tag_jp.txt"

# dir_en = "./data/news/cleaned2_tag_en.txt"
# dir_jp = "./data/news/cleaned2_tag_jp.txt"

# Read news data
df_en=pd.read_table(dir_en,names=["en_article"])
df_jp=pd.read_table(dir_jp,names=["jp_article"])

# %%
df_jp
# Out:
#                                             jp_article
# 0    米 商務省 発表 する 建設 支出 以下 とおり 季節調整 年率 総 建設 支出 民間 部門...
# 1    中国 低価格 スマホ メーカー 小米科技 () 雷軍 董事長 以上 販売 する 計画 明らか...
# 2    ソウル 株式市場 サムスン電子 株価 超 下落 する 安値 付ける 一部 アナリスト ウォン...
# 3    欧州 株式市場 イタリア 自動車 大手 FIAT 株価 一時 急伸 する 8月 以来 高値 ...
# 4    欧州 株式市場 イタリア 自動車 大手 FIAT 株価 一時 急伸 する 8月 以来 高値 ...
# 5    カッコ 前 営業日 米 東部 時間 時分 前 営業日 終盤 米 東部 時間 時分 前 営業日...
# 6       米財務省 銘柄 統合 入札 実施 する 発表 する 発行 いずれ 償還 1月 11月 11月
# 7    原油 先物 相場 リビア 大 規模 油田 生産 停止 要因 なる いる 抗議活動 休止 する...
# 8    米 労働省 発表 する 12月 週 新規 失業保険 申請 件数 季節調整 前週 り 連続 減...
# 9    パナマ運河 拡張 工事 めぐる 建設 会社 成る 企業 連合 パナマ運河 PC コスト 超過...
# 10   12月 フランス イタリア スペイン 自動車販売 台数 前年 同月 増加 する 欧州 自動車...
# 11   米 連邦準備理事会 FRB 傘下 ニューヨーク連銀 発表 する 最新 週間 データ よる 通...
# 12   スペイン 自動車 業界団体 よる 新車 販売 政府 補助 支援 する 前年 なる 減少 する...
# 13   韓国 自動車メーカー 現代自動車 系列 起亜自動車 世界 販売台数 両社 合計 前年 目標 ...
# 14   Markit 発表 する 12月 米 製造業 購買担当者景気指数 PM 改定 1月 以来 高...
# 15   原油 先物 相場 リビア 大 規模 油田 生産 停止 要因 なる いる 抗議活動 休止 する...
# ...

# %%
df_en
# Out:
#                                             en_article
# 0    u.s. commerce department seasonal adjust annua...
# 1    chinese budget smartphone maker xiaomi plan se...
# 2    samsung electronics co ltd fell more percent t...
# 3    fiat deal gain full control chrysler group llc...
# 4    fiat share jump thursday it strike deal gain f...
# 5    u.s. treasuries price rise thursday benchmark ...
# 6                       auction detail see 3-year note
# 7    brent crude sink barrel thursday libya prepare...
# 8    gauge u.s. factory activity hold 2-1/2-year hi...
# 9    work massive panama canal extension project ma...
# 10   increase december car sale france spain prompt...
# 11   federal reserve provide liquidity foreign cent...
# 12   new car sale spain rise percent year early car...
# 13   south korean auto maker hyundai motor co kia m...
# 14   u.s. manufacturing end year high note grow dec...
# 15   oil price fell more thursday libya prepare res...
# ...

# %%
run main.py
# Out:
# ---Warning: Word [13-13087] Vector Not Found ---
# Error: vec == NaN
# ---Warning: Word [13-cr-00073] Vector Not Found ---
# Error: vec == NaN
# ---Warning: Word [3] Vector Not Found ---
# Error: vec == NaN
# ---Warning: Word [3] Vector Not Found ---
# Error: vec == NaN
# ---Warning: Word [was] Vector Not Found ---
# Error: vec == NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/M2015eliu/cas/LaLSTM/main.py in <module>()
#     107 # For debug:
#     108
# --> 109 # Find vector
#     110 df_en_['transformation_en'] = \
#     111         df_en.en_article.apply(mapping_article,args=(model_en,))
#
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# ...

# %%
model_en

# %%
dir_txt_en
# Out:
# './data/news/sample_cleaned2_tag_en.txt'

# %%
df_en

# %%
df_en
