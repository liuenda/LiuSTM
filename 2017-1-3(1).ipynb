# %%
run main.py
# Out:
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# (4.1240959, 0.095272966, 0.046075466722721184)
# top: [] : 21
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  40 Cost  0.112757906318
# (2.0110817, 0.76414847, 0.75776556286056573)
# top: [199] : 199
# count    999.000000
# mean      52.060060
# std       68.136176
# min        1.000000
# 25%        7.500000
# 50%       28.000000
# 75%       63.000000
# max      370.500000
# dtype: float64
# epoch took: 40.8254339695
#
# Epoch 1 ...
# Epoch  1 Update  80 Cost  0.154227882624
# Epoch  1 Update  120 Cost  0.102236732841
# (1.8783286, 0.77263105, 0.7593900274694152)
# top: [199, 208] : 208
# count    999.000000
# mean      52.107608
# ...

# %%
a = {}
a[1] = 1
a[2]= 2

# %%
sorted(a)
# Out:
# [1, 2]

# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# (4.1240959, 0.095272966, 0.046075466722721184)
# top- 1 = [] : 3
# top- 5 = [] : 21
# top- 10 = [] : 30
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
#
# Epoch 0 ...
# Epoch  0 Update  40 Cost  0.112757906318
# (2.0110817, 0.76414847, 0.75776556286056573)
# top- 1 = [48] : 48
# top- 5 = [199] : 199
# ...

# %%
sls.tops[1]
# Out:
# [48,
#  50,
#  86,
#  76,
#  118,
#  93,
#  92,
#  202,
#  205,
#  225,
#  200,
#  161,
#  169,
#  186,
#  233,
#  259,
#  272,
#  263,
#  297,
#  274]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.tops[1],'ro-')
plt.plot(sls.tops[5],'bo-')
plt.plot(sls.tops[10],'go-')
plt.ylabel('Amount of documents belongs to @top*')
plt.xlabel('Epoches Times')
plt.show()

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#添加了testing data精度检测的测试结果

# %%
run main.py
# Out:
# /home/M2015eliu/.pyenv/versions/anaconda2-4.1.1/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 4007)
# Starting to training the model..., saving to weights/201612140109_e10_1k1k.p
# Training
# the length of the training data is  1998
# Before trianing, the error is:
# (4.1240959, 0.095272966, 0.046075466722721184)
# top- 1 = [] : 3
# top- 5 = [] : 21
# top- 10 = [] : 30
# Discription of evaluation (ranking) for training data:
# count    999.000000
# mean     501.754755
# std      264.648264
# min        1.000000
# 25%      290.500000
# 50%      541.500000
# 75%      711.000000
# max      978.000000
# dtype: float64
# top- 1 = [] : 1
# top- 5 = [] : 12
# top- 10 = [] : 24
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(sls.tops[1],'ro-')
plt.plot(sls.tops[5],'bo-')
plt.plot(sls.tops[10],'go-')
plt.plot(sls.tops_test[1],'ro--')
plt.plot(sls.tops_test[5],'bo--')
plt.plot(sls.tops_test[10],'go--')
plt.ylabel('Amount of documents belongs to @top*')
plt.xlabel('Epoches Times')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.plot(rank_results_test,'bo')
plt.xlabel('Document Number')
plt.ylabel('Accuracy distribution of Testing paris')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 7.5)
plt.title('Accuracy distribution of Training paris')
plt.plot(rank_results_train,'ro')
plt.xlabel('Document Number')
plt.ylabel('The ranking of the real pair')
plt.show()
